# %%
# -*- coding: utf-8 -*-
import os
import glob 
import pandas as pd
import string
import collections
from tqdm import tqdm
from PIL import Image
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
from torch.utils.data import DataLoader
import torch.optim as optim
from Gen.chinese_data import common_chinese_chars
# Out:
# 407

# %%
path = r'F:\project\python\OCR\Recognize\data\chinese\num6size32font3shape20050'
data = glob.glob(os.path.join(path, '*.png'))
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
DEVICE
# Out:
# device(type='cuda')

# %%
all_letters = common_chinese_chars
mapping = {}
mapping_inv = {}
i = 1
for x in all_letters:
    mapping[x] = i
    mapping_inv[i] = x
    i += 1

# %%
num_class = len(mapping)

# %%
mapping
# Out:
# {'的': 1,
#  '一': 2,
#  '是': 3,
#  '了': 4,
#  '我': 5,
#  '不': 6,
#  '在': 7,
#  '人': 8,
#  '们': 9,
#  '有': 10,
#  '来': 11,
#  '他': 12,
#  '这': 13,
#  '上': 14,
#  '着': 15,
#  '个': 16,
#  '为': 17,
#  '到': 18,
#  '说': 19,
#  '要': 20,
#  '就': 21,
#  '出': 22,
#  '会': 23,
#  '可': 24,
#  '也': 25,
#  '你': 26,
#  '对': 27,
#  '生': 28,
#  '能': 29,
#  '而': 30,
#  '子': 31,
#  '那': 32,
#  '得': 33,
#  '于': 34,
#  '下': 35,
#  '自': 36,
#  '之': 37,
#  '年': 38,
#  '过': 39,
#  '发': 40,
#  '后': 41,
#  '作': 42,
#  '里': 43,
#  '用': 44,
#  '道': 45,
#  '行': 46,
#  '所': 47,
#  '然': 48,
#  '家': 49,
#  '种': 50,
#  '事': 51,
#  '成': 52,
#  '方': 53,
#  '多': 54,
#  '经': 55,
#  '么': 56,
#  '去': 57,
#  '法': 58,
#  '学': 59,
#  '如': 60,
#  '都': 61,
#  '同': 62,
#  '现': 63,
#  '当': 64,
#  '没': 65,
#  '动': 66,
#  '面': 67,
#  '起': 68,
#  '看': 69,
#  '定': 70,
#  '天': 71,
#  '分': 72,
#  '还': 73,
#  '进': 74,
#  '好': 75,
#  '小': 76,
#  '部': 77,
#  '其': 78,
#  '些': 79,
#  '主': 80,
#  '样': 81,
#  '理': 82,
#  '心': 83,
#  '她': 84,
#  '本': 85,
#  '前': 86,
#  '开': 87,
#  '但': 88,
#  '因': 89,
#  '只': 90,
#  '从': 91,
#  '想': 92,
#  '实': 93,
#  '日': 94,
#  '军': 95,
#  '者': 96,
#  '意': 97,
#  '无': 98,
#  '力': 99,
#  '它': 100,
#  '与': 101,
#  '长': 102,
#  '把': 103,
#  '机': 104,
#  '十': 105,
#  '民': 106,
#  '第': 107,
#  '公': 108,
#  '此': 109,
#  '已': 110,
#  '工': 111,
#  '使': 112,
#  '情': 113,
#  '明': 114,
#  '性': 115,
#  '知': 116,
#  '全': 117,
#  '三': 118,
#  '又': 119,
#  '关': 120,
#  '点': 121,
#  '正': 122,
#  '业': 123,
#  '外': 124,
#  '将': 125,
#  '两': 126,
#  '高': 127,
#  '间': 128,
#  '由': 129,
#  '问': 130,
#  '很': 131,
#  '最': 132,
#  '重': 133,
#  '并': 134,
#  '物': 135,
#  '手': 136,
#  '应': 137,
#  '战': 138,
#  '向': 139,
#  '头': 140,
#  '文': 141,
#  '体': 142,
#  '政': 143,
#  '美': 144,
#  '相': 145,
#  '见': 146,
#  '被': 147,
#  '利': 148,
#  '什': 149,
#  '二': 150,
#  '等': 151,
#  '产': 152,
#  '或': 153,
#  '新': 154,
#  '己': 155,
#  '制': 156,
#  '身': 157,
#  '果': 158,
#  '加': 159,
#  '西': 160,
#  '斯': 161,
#  '月': 162,
#  '话': 163,
#  '合': 164,
#  '回': 165,
#  '特': 166,
#  '代': 167,
#  '内': 168,
#  '信': 169,
#  '表': 170,
#  '化': 171,
#  '老': 172,
#  '给': 173,
#  '世': 174,
#  '位': 175,
#  '次': 176,
#  '度': 177,
#  '门': 178,
#  '任': 179,
#  '常': 180,
#  '先': 181,
#  '海': 182,
#  '通': 183,
#  '教': 184,
#  '儿': 185,
#  '原': 186,
#  '东': 187,
#  '声': 188,
#  '提': 189,
#  '立': 190,
#  '及': 191,
#  '比': 192,
#  '员': 193,
#  '解': 194,
#  '水': 195,
#  '名': 196,
#  '真': 197,
#  '论': 198,
#  '处': 199,
#  '走': 200,
#  '义': 201,
#  '各': 202,
#  '入': 203,
#  '几': 204,
#  '口': 205,
#  '认': 206,
#  '条': 207,
#  '平': 208,
#  '系': 209,
#  '气': 210,
#  '题': 211,
#  '活': 212,
#  '尔': 213,
#  '更': 214,
#  '别': 215,
#  '打': 216,
#  '女': 217,
#  '变': 218,
#  '四': 219,
#  '神': 220,
#  '总': 221,
#  '何': 222,
#  '电': 223,
#  '数': 224,
#  '安': 225,
#  '少': 226,
#  '报': 227,
#  '才': 228,
#  '结': 229,
#  '反': 230,
#  '受': 231,
#  '目': 232,
#  '太': 233,
#  '量': 234,
#  '再': 235,
#  '感': 236,
#  '建': 237,
#  '务': 238,
#  '做': 239,
#  '接': 240,
#  '必': 241,
#  '场': 242,
#  '件': 243,
#  '计': 244,
#  '管': 245,
#  '期': 246,
#  '市': 247,
#  '直': 248,
#  '德': 249,
#  '资': 250,
#  '命': 251,
#  '山': 252,
#  '金': 253,
#  '指': 254,
#  '克': 255,
#  '许': 256,
#  '统': 257,
#  '区': 258,
#  '保': 259,
#  '至': 260,
#  '队': 261,
#  '形': 262,
#  '社': 263,
#  '便': 264,
#  '空': 265,
#  '决': 266,
#  '治': 267,
#  '展': 268,
#  '马': 269,
#  '科': 270,
#  '司': 271,
#  '五': 272,
#  '基': 273,
#  '眼': 274,
#  '书': 275,
#  '非': 276,
#  '则': 277,
#  '听': 278,
#  '白': 279,
#  '却': 280,
#  '界': 281,
#  '达': 282,
#  '光': 283,
#  '放': 284,
#  '强': 285,
#  '即': 286,
#  '像': 287,
#  '难': 288,
#  '且': 289,
#  '权': 290,
#  '思': 291,
#  '王': 292,
#  '象': 293,
#  '完': 294,
#  '设': 295,
#  '式': 296,
#  '色': 297,
#  '路': 298,
#  '记': 299,
#  '南': 300,
#  '品': 301,
#  '住': 302,
#  '告': 303,
#  '类': 304,
#  '求': 305,
#  '据': 306,
#  '程': 307,
#  '北': 308,
#  '边': 309,
#  '死': 310,
#  '张': 311,
#  '该': 312,
#  '交': 313,
#  '规': 314,
#  '万': 315,
#  '取': 316,
#  '拉': 317,
#  '格': 318,
#  '望': 319,
#  '觉': 320,
#  '术': 321,
#  '领': 322,
#  '共': 323,
#  '确': 324,
#  '传': 325,
#  '师': 326,
#  '观': 327,
#  '清': 328,
#  '今': 329,
#  '切': 330,
#  '院': 331,
#  '让': 332,
#  '识': 333,
#  '候': 334,
#  '带': 335,
#  '导': 336,
#  '争': 337,
#  '运': 338,
#  '笑': 339,
#  '飞': 340,
#  '风': 341,
#  '步': 342,
#  '改': 343,
#  '收': 344,
#  '根': 345,
#  '干': 346,
#  '造': 347,
#  '言': 348,
#  '联': 349,
#  '持': 350,
#  '组': 351,
#  '每': 352,
#  '济': 353,
#  '车': 354,
#  '亲': 355,
#  '极': 356,
#  '林': 357,
#  '服': 358,
#  '快': 359,
#  '办': 360,
#  '议': 361,
#  '往': 362,
#  '元': 363,
#  '英': 364,
#  '士': 365,
#  '证': 366,
#  '近': 367,
#  '律': 368,
#  '般': 369,
#  '尼': 370,
#  '构': 371,
#  '影': 372,
#  '层': 373,
#  '器': 374,
#  '效': 375,
#  '调': 376,
#  '团': 377,
#  '研': 378,
#  '超': 379,
#  '帮': 380,
#  '置': 381,
#  '积': 382,
#  '整': 383,
#  '罗': 384,
#  '参': 385,
#  '备': 386,
#  '维': 387,
#  '础': 388,
#  '值': 389,
#  '温': 390,
#  '落': 391,
#  '职': 392,
#  '流': 393,
#  '连': 394,
#  '镇': 395,
#  '互': 396,
#  '较': 397,
#  '华': 398,
#  '显': 399,
#  '刚': 400,
#  '标': 401,
#  '准': 402,
#  '攻': 403,
#  '推': 404,
#  '施': 405,
#  '究': 406,
#  '扩': 407}

# %%
mapping_inv
# Out:
# {1: '的',
#  2: '一',
#  3: '是',
#  4: '了',
#  5: '我',
#  6: '不',
#  7: '在',
#  8: '人',
#  9: '们',
#  10: '有',
#  11: '来',
#  12: '他',
#  13: '这',
#  14: '上',
#  15: '着',
#  16: '个',
#  17: '为',
#  18: '到',
#  19: '说',
#  20: '要',
#  21: '就',
#  22: '出',
#  23: '会',
#  24: '可',
#  25: '也',
#  26: '你',
#  27: '对',
#  28: '生',
#  29: '能',
#  30: '而',
#  31: '子',
#  32: '那',
#  33: '得',
#  34: '于',
#  35: '下',
#  36: '自',
#  37: '之',
#  38: '年',
#  39: '过',
#  40: '发',
#  41: '后',
#  42: '作',
#  43: '里',
#  44: '用',
#  45: '道',
#  46: '行',
#  47: '所',
#  48: '然',
#  49: '家',
#  50: '种',
#  51: '事',
#  52: '成',
#  53: '方',
#  54: '多',
#  55: '经',
#  56: '么',
#  57: '去',
#  58: '法',
#  59: '学',
#  60: '如',
#  61: '都',
#  62: '同',
#  63: '现',
#  64: '当',
#  65: '没',
#  66: '动',
#  67: '面',
#  68: '起',
#  69: '看',
#  70: '定',
#  71: '天',
#  72: '分',
#  73: '还',
#  74: '进',
#  75: '好',
#  76: '小',
#  77: '部',
#  78: '其',
#  79: '些',
#  80: '主',
#  81: '样',
#  82: '理',
#  83: '心',
#  84: '她',
#  85: '本',
#  86: '前',
#  87: '开',
#  88: '但',
#  89: '因',
#  90: '只',
#  91: '从',
#  92: '想',
#  93: '实',
#  94: '日',
#  95: '军',
#  96: '者',
#  97: '意',
#  98: '无',
#  99: '力',
#  100: '它',
#  101: '与',
#  102: '长',
#  103: '把',
#  104: '机',
#  105: '十',
#  106: '民',
#  107: '第',
#  108: '公',
#  109: '此',
#  110: '已',
#  111: '工',
#  112: '使',
#  113: '情',
#  114: '明',
#  115: '性',
#  116: '知',
#  117: '全',
#  118: '三',
#  119: '又',
#  120: '关',
#  121: '点',
#  122: '正',
#  123: '业',
#  124: '外',
#  125: '将',
#  126: '两',
#  127: '高',
#  128: '间',
#  129: '由',
#  130: '问',
#  131: '很',
#  132: '最',
#  133: '重',
#  134: '并',
#  135: '物',
#  136: '手',
#  137: '应',
#  138: '战',
#  139: '向',
#  140: '头',
#  141: '文',
#  142: '体',
#  143: '政',
#  144: '美',
#  145: '相',
#  146: '见',
#  147: '被',
#  148: '利',
#  149: '什',
#  150: '二',
#  151: '等',
#  152: '产',
#  153: '或',
#  154: '新',
#  155: '己',
#  156: '制',
#  157: '身',
#  158: '果',
#  159: '加',
#  160: '西',
#  161: '斯',
#  162: '月',
#  163: '话',
#  164: '合',
#  165: '回',
#  166: '特',
#  167: '代',
#  168: '内',
#  169: '信',
#  170: '表',
#  171: '化',
#  172: '老',
#  173: '给',
#  174: '世',
#  175: '位',
#  176: '次',
#  177: '度',
#  178: '门',
#  179: '任',
#  180: '常',
#  181: '先',
#  182: '海',
#  183: '通',
#  184: '教',
#  185: '儿',
#  186: '原',
#  187: '东',
#  188: '声',
#  189: '提',
#  190: '立',
#  191: '及',
#  192: '比',
#  193: '员',
#  194: '解',
#  195: '水',
#  196: '名',
#  197: '真',
#  198: '论',
#  199: '处',
#  200: '走',
#  201: '义',
#  202: '各',
#  203: '入',
#  204: '几',
#  205: '口',
#  206: '认',
#  207: '条',
#  208: '平',
#  209: '系',
#  210: '气',
#  211: '题',
#  212: '活',
#  213: '尔',
#  214: '更',
#  215: '别',
#  216: '打',
#  217: '女',
#  218: '变',
#  219: '四',
#  220: '神',
#  221: '总',
#  222: '何',
#  223: '电',
#  224: '数',
#  225: '安',
#  226: '少',
#  227: '报',
#  228: '才',
#  229: '结',
#  230: '反',
#  231: '受',
#  232: '目',
#  233: '太',
#  234: '量',
#  235: '再',
#  236: '感',
#  237: '建',
#  238: '务',
#  239: '做',
#  240: '接',
#  241: '必',
#  242: '场',
#  243: '件',
#  244: '计',
#  245: '管',
#  246: '期',
#  247: '市',
#  248: '直',
#  249: '德',
#  250: '资',
#  251: '命',
#  252: '山',
#  253: '金',
#  254: '指',
#  255: '克',
#  256: '许',
#  257: '统',
#  258: '区',
#  259: '保',
#  260: '至',
#  261: '队',
#  262: '形',
#  263: '社',
#  264: '便',
#  265: '空',
#  266: '决',
#  267: '治',
#  268: '展',
#  269: '马',
#  270: '科',
#  271: '司',
#  272: '五',
#  273: '基',
#  274: '眼',
#  275: '书',
#  276: '非',
#  277: '则',
#  278: '听',
#  279: '白',
#  280: '却',
#  281: '界',
#  282: '达',
#  283: '光',
#  284: '放',
#  285: '强',
#  286: '即',
#  287: '像',
#  288: '难',
#  289: '且',
#  290: '权',
#  291: '思',
#  292: '王',
#  293: '象',
#  294: '完',
#  295: '设',
#  296: '式',
#  297: '色',
#  298: '路',
#  299: '记',
#  300: '南',
#  301: '品',
#  302: '住',
#  303: '告',
#  304: '类',
#  305: '求',
#  306: '据',
#  307: '程',
#  308: '北',
#  309: '边',
#  310: '死',
#  311: '张',
#  312: '该',
#  313: '交',
#  314: '规',
#  315: '万',
#  316: '取',
#  317: '拉',
#  318: '格',
#  319: '望',
#  320: '觉',
#  321: '术',
#  322: '领',
#  323: '共',
#  324: '确',
#  325: '传',
#  326: '师',
#  327: '观',
#  328: '清',
#  329: '今',
#  330: '切',
#  331: '院',
#  332: '让',
#  333: '识',
#  334: '候',
#  335: '带',
#  336: '导',
#  337: '争',
#  338: '运',
#  339: '笑',
#  340: '飞',
#  341: '风',
#  342: '步',
#  343: '改',
#  344: '收',
#  345: '根',
#  346: '干',
#  347: '造',
#  348: '言',
#  349: '联',
#  350: '持',
#  351: '组',
#  352: '每',
#  353: '济',
#  354: '车',
#  355: '亲',
#  356: '极',
#  357: '林',
#  358: '服',
#  359: '快',
#  360: '办',
#  361: '议',
#  362: '往',
#  363: '元',
#  364: '英',
#  365: '士',
#  366: '证',
#  367: '近',
#  368: '律',
#  369: '般',
#  370: '尼',
#  371: '构',
#  372: '影',
#  373: '层',
#  374: '器',
#  375: '效',
#  376: '调',
#  377: '团',
#  378: '研',
#  379: '超',
#  380: '帮',
#  381: '置',
#  382: '积',
#  383: '整',
#  384: '罗',
#  385: '参',
#  386: '备',
#  387: '维',
#  388: '础',
#  389: '值',
#  390: '温',
#  391: '落',
#  392: '职',
#  393: '流',
#  394: '连',
#  395: '镇',
#  396: '互',
#  397: '较',
#  398: '华',
#  399: '显',
#  400: '刚',
#  401: '标',
#  402: '准',
#  403: '攻',
#  404: '推',
#  405: '施',
#  406: '究',
#  407: '扩'}

# %%
images = []
labels = []
datas = collections.defaultdict(list)
for d in data:
    x = d.split('\\')[-1]

    datas['image'].append(x)

    datas['label'].append([mapping[i] for i in x.split('.')[0]])
df = pd.DataFrame(datas)
df.head()
# Out:
#         image                         label
# 0  一不事义话表.png     [2, 6, 51, 201, 163, 170]
# 1  一交言点性落.png  [2, 313, 348, 121, 115, 391]
# 2  一从安利电小.png    [2, 91, 225, 148, 223, 76]
# 3  一体条去才头.png   [2, 142, 207, 57, 228, 140]
# 4  一公作系决了.png     [2, 108, 42, 209, 266, 4]

# %%
datas
# Out:
# defaultdict(list,
#             {'image': ['一不事义话表.png',
#               '一交言点性落.png',
#               '一从安利电小.png',
#               '一体条去才头.png',
#               '一公作系决了.png',
#               '一化证经尔者.png',
#               '一及化传律成.png',
#               '一口几争总变.png',
#               '一声想向老了.png',
#               '一如据手体告.png',
#               '一年往十实推.png',
#               '一开今方发持.png',
#               '一影着老导平.png',
#               '一很服理体么.png',
#               '一心机显温子.png',
#               '一快带着利值.png',
#               '一持尼说无入.png',
#               '一术个马意那.png',
#               '一权要已品战.png',
#               '一根整快打生.png',
#               '一次化子过事.png',
#               '一王名帮如资.png',
#               '一用告强共加.png',
#               '一电值张经许.png',
#               '一解公拉等司.png',
#               '一议口位华全.png',
#               '一资神使接说.png',
#               '万事置报多思.png',
#               '万作又院交利.png',
#               '万你代改头收.png',
#               '万克刚运如公.png',
#               '万分望此进治.png',
#               '万参术础立量.png',
#               '万合般正通把.png',
#               '万后候界车置.png',
#               '万多指下也罗.png',
#               '万好她话文其.png',
#               '万工什分个行.png',
#               '万最等上金极.png',
#               '万每指向扩走.png',
#               '万治名标极持.png',
#               '万直见于区定.png',
#               '万神权把分交.png',
#               '万笑格什落题.png',
#               '万组产将打一.png',
#               '万西便方备扩.png',
#               '万西更你何认.png',
#               '万进飞信让感.png',
#               '万那言平扩直.png',
#               '万队相快场小.png',
#               '三交整资才言.png',
#               '三位带几么制.png',
#               '三住组她们色.png',
#               '三体白路把种.png',
#               '三入才流攻老.png',
#               '三北日问步类.png',
#               '三即总务应难.png',
#               '三参往少像近.png',
#               '三反风切手知.png',
#               '三合准二门服.png',
#               '三员团的接对.png',
#               '三命种产其但.png',
#               '三四般化下形.png',
#               '三它多一资光.png',
#               '三对么己风团.png',
#               '三得资罗名体.png',
#               '三意已积步打.png',
#               '三感清变之就.png',
#               '三或成二造面.png',
#               '三据出拉尼亲.png',
#               '三推备职好显.png',
#               '三教品应马所.png',
#               '三民上根不理.png',
#               '三现争还科议.png',
#               '三至产言被民.png',
#               '三行调分连化.png',
#               '三规动步南那.png',
#               '三计什成少业.png',
#               '三让着加与头.png',
#               '三起她好十干.png',
#               '上下年强每数.png',
#               '上且代尼女所.png',
#               '上世落问导要.png',
#               '上两量像联显.png',
#               '上位去快子来.png',
#               '上元候言家得.png',
#               '上其应都用收.png',
#               '上办利则告刚.png',
#               '上基德公她义.png',
#               '上工关女显让.png',
#               '上开造马像再.png',
#               '上扩常万调超.png',
#               '上文都立标资.png',
#               '上斯反女清己.png',
#               '上是一不切认.png',
#               '上权去非公很.png',
#               '上比性往意几.png',
#               '上相入数实务.png',
#               '上眼么老那住.png',
#               '上知接会神道.png',
#               '上类起克万准.png',
#               '上统光置平将.png',
#               '上美都干反其.png',
#               '上边化调空观.png',
#               '上重里只连建.png',
#               '上镇术今活从.png',
#               '上长最心路用.png',
#               '下世里至联快.png',
#               '下什会张其运.png',
#               '下作标流利条.png',
#               '下口所电先点.png',
#               '下员行干开报.png',
#               '下在之里造给.png',
#               '下己科完眼非.png',
#               '下建王处教类.png',
#               '下开觉极教事.png',
#               '下往管要水西.png',
#               '下德关值至即.png',
#               '下提点件导走.png',
#               '下数利英没十.png',
#               '下斯镇社的究.png',
#               '下方超格动感.png',
#               '下有林见自方.png',
#               '下每基场取见.png',
#               '下每政决战用.png',
#               '下海基能施后.png',
#               '下白参通士身.png',
#               '下直最快我感.png',
#               '下知说团于很.png',
#               '下确本象维解.png',
#               '下者起根计觉.png',
#               '下较日住少后.png',
#               '下较而天司别.png',
#               '下连还间而元.png',
#               '不于民外题们.png',
#               '不从据造五化.png',
#               '不从明界回能.png',
#               '不们改听斯维.png',
#               '不信风程山任.png',
#               '不像头规望办.png',
#               '不南安二难品.png',
#               '不受尔表备很.png',
#               '不实团者温命.png',
#               '不开情分公且.png',
#               '不开真还律张.png',
#               '不成部由之或.png',
#               '不文象及英出.png',
#               '不样信三员后.png',
#               '不比它他区或.png',
#               '不础的何觉关.png',
#               '不确文定究老.png',
#               '不美施成放强.png',
#               '不议口了着笑.png',
#               '不议路改济题.png',
#               '与业变海话持.png',
#               '与亲身立会权.png',
#               '与什入保事备.png',
#               '与什给扩争十.png',
#               '与值见等则证.png',
#               '与入样司回言.png',
#               '与军带象提真.png',
#               '与准只门常让.png',
#               '与南由死第部.png',
#               '与因身三重下.png',
#               '与在必收目话.png',
#               '与带刚更部清.png',
#               '与打件听近得.png',
#               '与放象战研样.png',
#               '与果类书了员.png',
#               '与理被证民四.png',
#               '与由近意战光.png',
#               '与社流取因气.png',
#               '与科据华合式.png',
#               '与职方产格期.png',
#               '与认值老信不.png',
#               '与论她看她什.png',
#               '与都较己高带.png',
#               '与马比子走形.png',
#               '且使身人给人.png',
#               '且元共快儿下.png',
#               '且定刚者到推.png',
#               '且己证一基回.png',
#               '且应展很市由.png',
#               '且成前互工进.png',
#               '且战金位且外.png',
#               '且果论决路治.png',
#               '且没接华没各.png',
#               '且特身知代流.png',
#               '且理攻化就没.png',
#               '且真么是镇难.png',
#               '且知为特及学.png',
#               '且计德准强行.png',
#               '且许量行然军.png',
#               '且论其死强西.png',
#               '世们位五往先.png',
#               '世会几根两月.png',
#               '世到做解通子.png',
#               '世到神明什德.png',
#               '世变直真白各.png',
#               '世同走共扩定.png',
#               '世名入参只西.png',
#               '世回科光切展.png',
#               '世基管根己高.png',
#               '世天好将名资.png',
#               '世建根制制位.png',
#               '世拉层切没三.png',
#               '世数此政现学.png',
#               '世新服整保新.png',
#               '世构提手扩组.png',
#               '世物常标次造.png',
#               '世界得干西月.png',
#               '世系内意当女.png',
#               '世给每持了全.png',
#               '世罗动门名研.png',
#               '世美再开了如.png',
#               '世联建几有得.png',
#               '世认置已非传.png',
#               '世设形产个积.png',
#               '世近觉教员过.png',
#               '世进员意年子.png',
#               '业且每共后又.png',
#               '业今好本类空.png',
#               '业再义面受报.png',
#               '业十全年张效.png',
#               '业南又还战别.png',
#               '业却结改知提.png',
#               '业名果内导社.png',
#               '业告道应为候.png',
#               '业处王构步强.png',
#               '业尔常家位并.png',
#               '业层刚许东又.png',
#               '业应构还思得.png',
#               '业当置着报较.png',
#               '业民将应日般.png',
#               '业经体记东我.png',
#               '业见打与没罗.png',
#               '业让使事去超.png',
#               '业面难它信车.png',
#               '东争至直言持.png',
#               '东件工得了共.png',
#               '东任想不解华.png',
#               '东决华领体业.png',
#               '东别济或万立.png',
#               '东办制马飞非.png',
#               '东及较少人根.png',
#               '东同长然气果.png',
#               '东因重从马开.png',
#               '东外于就言然.png',
#               '东定起市种声.png',
#               '东小元一也互.png',
#               '东应该动近化.png',
#               '东式已英者目.png',
#               '东情海必果民.png',
#               '东是现他记快.png',
#               '东本影总战之.png',
#               '东标像互在程.png',
#               '东正任些积物.png',
#               '东没都光动全.png',
#               '东白名把造信.png',
#               '东研公天他下.png',
#               '东神象其事力.png',
#               '东结只极保手.png',
#               '东调感而律据.png',
#               '两三却类当律.png',
#               '两世安打华他.png',
#               '两业超又非她.png',
#               '两产觉实现元.png',
#               '两你便白内共.png',
#               '两候原该总内.png',
#               '两内参度元神.png',
#               '两南步权导器.png',
#               '两即相得海几.png',
#               '两取步南风团.png',
#               '两员几更还老.png',
#               '两回刚教的发.png',
#               '两就力日再同.png',
#               '两很天张月且.png',
#               '两心的保在指.png',
#               '两情你将走或.png',
#               '两政指此无走.png',
#               '两林二直会它.png',
#               '两次品往定内.png',
#               '两真意格比作.png',
#               '两置安体应见.png',
#               '两美于反区改.png',
#               '两间象利见海.png',
#               '个东备造过情.png',
#               '个人一各家落.png',
#               '个作收识现入.png',
#               '个先无万明死.png',
#               '个共马风般已.png',
#               '个准思决观罗.png',
#               '个化情不眼推.png',
#               '个北情明前处.png',
#               '个华求确英认.png',
#               '个只她常第北.png',
#               '个司合产传近.png',
#               '个同海开白原.png',
#               '个就走完华界.png',
#               '个式而北斯才.png',
#               '个当效联物置.png',
#               '个必无建造名.png',
#               '个感类现望任.png',
#               '个文光影清想.png',
#               '个次认所传身.png',
#               '个死效那老则.png',
#               '个理关者理团.png',
#               '个自极第像他.png',
#               '个要理就张义.png',
#               '个观成调能社.png',
#               '个规飞经组般.png',
#               '个话直共极数.png',
#               '个部种文感为.png',
#               '个风飞据但即.png',
#               '为任该它二部.png',
#               '为住己且罗代.png',
#               '为入真这数主.png',
#               '为公从被式程.png',
#               '为则确儿导言.png',
#               '为制常接多活.png',
#               '为办步一然空.png',
#               '为南置年它标.png',
#               '为司今话华等.png',
#               '为因学度应安.png',
#               '为女界些完调.png',
#               '为她去产资下.png',
#               '为小多往那发.png',
#               '为市使统形第.png',
#               '为帮命观且口.png',
#               '为影温想代亲.png',
#               '为得所制感快.png',
#               '为整全理比现.png',
#               '为最理品准超.png',
#               '为月机更了因.png',
#               '为服们们效文.png',
#               '为望长万建已.png',
#               '为来器为着万.png',
#               '为理像快口目.png',
#               '为界进强心研.png',
#               '为研更在发层.png',
#               '为社期言组达.png',
#               '为社没看些两.png',
#               '为立义明实准.png',
#               '为立觉意象住.png',
#               '为观儿整张扩.png',
#               '为论领准利问.png',
#               '为调月气又施.png',
#               '为进争难出基.png',
#               '为部英做小飞.png',
#               '主了清设工无.png',
#               '主但工通经眼.png',
#               '主准调连利们.png',
#               '主又经人科联.png',
#               '主口社帮师来.png',
#               '主回品保造色.png',
#               '主场推定无想.png',
#               '主多科院程通.png',
#               '主山人知社所.png',
#               '主师类长海感.png',
#               '主平水你镇想.png',
#               '主应平术清者.png',
#               '主德可界切象.png',
#               '主手与明常出.png',
#               '主攻资当接度.png',
#               '主水听准罗确.png',
#               '主点互听刚作.png',
#               '主由攻好则说.png',
#               '主确这区第用.png',
#               '主种今上后象.png',
#               '主种机至到别.png',
#               '主空也超来感.png',
#               '主者山传资给.png',
#               '主被如老定组.png',
#               '主象过万才何.png',
#               '主门同统很由.png',
#               '主问二把参部.png',
#               '主问里且放学.png',
#               '主难据每问法.png',
#               '么会常该信品.png',
#               '么出公目积白.png',
#               '么动后实何想.png',
#               '么华平效两话.png',
#               '么南保如治内.png',
#               '么原么更么听.png',
#               '么取三主基通.png',
#               '么可真住海笑.png',
#               '么品教报那交.png',
#               '么回政为会五.png',
#               '么多外争立物.png',
#               '么定显己觉也.png',
#               '么帮些题可则.png',
#               '么影分先类方.png',
#               '么条出因记过.png',
#               '么社五根通标.png',
#               '么罗术当一平.png',
#               '么般究决期加.png',
#               '么言子法说山.png',
#               '么身位海提方.png',
#               '么过年立作之.png',
#               '么过第平王而.png',
#               '义些去者帮市.png',
#               '义元光应十作.png',
#               '义关立后社原.png',
#               '义加门接员成.png',
#               '义务手表务究.png',
#               '义受眼回并员.png',
#               '义命道听气且.png',
#               '义基都权确交.png',
#               '义建来论由物.png',
#               '义往白候数思.png',
#               '义拉今次那无.png',
#               '义持规指用全.png',
#               '义林女山产或.png',
#               '义没非近神工.png',
#               '义看往又共义.png',
#               '义真进位据门.png',
#               '义社物信制设.png',
#               '义老治子效运.png',
#               '义被现温目情.png',
#               '义要器如着成.png',
#               '义象开连度子.png',
#               '之不活么并的.png',
#               '之为直最眼报.png',
#               '之交光义本物.png',
#               '之今同程王司.png',
#               '之军接类区天.png',
#               '之出而数路院.png',
#               '之命实思了效.png',
#               '之多制全拉础.png',
#               '之子声马那公.png',
#               '之定数做法山.png',
#               '之家道值格放.png',
#               '之山你那书认.png',
#               '之市组入也只.png',
#               '之意空运却职.png',
#               '之把队律教们.png',
#               '之据义统部务.png',
#               '之根方础些构.png',
#               '之水确职如发.png',
#               '之能标从如安.png',
#               '之表太全被点.png',
#               '之论海很定德.png',
#               '之非着们像因.png',
#               '也业效过空积.png',
#               '也事带世般起.png',
#               '也候走因施整.png',
#               '也克表所眼帮.png',
#               '也再其规与拉.png',
#               '也前究反互西.png',
#               '也员情处义三.png',
#               '也学公构可前.png',
#               '也对任作长系.png',
#               '也提关或社院.png',
#               '也攻月将团生.png',
#               '也放样士电斯.png',
#               '也新计处记与.png',
#               '也最比做只用.png',
#               '也死长达区传.png',
#               '也求拉不二切.png',
#               '也直民部二总.png',
#               '也落取张积有.png',
#               '也走便效看子.png',
#               '也风求即利命.png',
#               '书下现比办话.png',
#               '书之风快被治.png',
#               '书保克已是军.png',
#               '书元调让儿意.png',
#               '书司认口也事.png',
#               '书声门像也已.png',
#               '书市条英所推.png',
#               '书式调命好面.png',
#               '书王每带民再.png',
#               '书电己观社器.png',
#               '书道军儿看何.png',
#               '书那提当证再.png',
#               '书长建三年美.png',
#               '书飞行然别影.png',
#               '了三书往太加.png',
#               '了两却神任两.png',
#               '了五则难目科.png',
#               '了传神到统做.png',
#               '了却能清很准.png',
#               '了变常先先类.png',
#               '了实入尔改强.png',
#               '了工题运原三.png',
#               '了师日们色这.png',
#               '了常华通美起.png',
#               '了开但更它美.png',
#               '了式何声实己.png',
#               '了式处小子几.png',
#               '了据山科统去.png',
#               '了无心五理全.png',
#               '了权次接现非.png',
#               '了死然去准子.png',
#               '了法作保头总.png',
#               '了白小都水及.png',
#               '了础法较电记.png',
#               '了结形件等可.png',
#               '了维切务处明.png',
#               '了维类极团像.png',
#               '了老没东好身.png',
#               '了般流代能力.png',
#               '了觉王政万平.png',
#               '了造传能学达.png',
#               '了那何观公面.png',
#               '争与原果且文.png',
#               '争什现己规攻.png',
#               '争住可王维种.png',
#               '争何风么解活.png',
#               '争儿每成决西.png',
#               '争动到治共又.png',
#               '争北拉等此温.png',
#               '争原指科南克.png',
#               '争在切主件如.png',
#               '争女老外类声.png',
#               '争完四系推现.png',
#               '争将切好利数.png',
#               '争少导团此很.png',
#               '争层声才美积.png',
#               '争形只应直可.png',
#               '争往反我性律.png',
#               '争扩文造术感.png',
#               '争放立导放过.png',
#               '争整报白说五.png',
#               '争方文置空调.png',
#               '争有求干因着.png',
#               '争然管区础行.png',
#               '争物进他构性.png',
#               '争电电路或些.png',
#               '争联整再着造.png',
#               '争识电业克许.png',
#               '争部化与体克.png',
#               '事世物会的思.png',
#               '事交在题在相.png',
#               '事体死难水表.png',
#               '事反里长山所.png',
#               '事向产影把次.png',
#               '事命记因该光.png',
#               '事头象落从只.png',
#               '事层清据提回.png',
#               '事构院任林便.png',
#               '事济指么规部.png',
#               '事电或西还所.png',
#               '事白打该镇研.png',
#               '事眼科东比后.png',
#               '事联备标五界.png',
#               '事计义变问别.png',
#               '事道本让得进.png',
#               '二一入前非种.png',
#               '二亲斯是联系.png',
#               '二但电不点觉.png',
#               '二便则金管原.png',
#               '二候条于相张.png',
#               '二共职笑听回.png',
#               '二司发应里感.png',
#               '二定般战林原.png',
#               '二对制社入数.png',
#               '二尼展必基美.png',
#               '二年然什南力.png',
#               '二并感体第种.png',
#               '二并说从的区.png',
#               '二快近即别可.png',
#               '二总置下根同.png',
#               '二扩门意度罗.png',
#               '二接建十度积.png',
#               '二教市让基英.png',
#               '二没马你象设.png',
#               '二流服会能准.png',
#               '二海言政规定.png',
#               '二温收温治的.png',
#               '二社化小度市.png',
#               '二管式值开师.png',
#               '二许你们什认.png',
#               '二都名东争切.png',
#               '二镇士人带件.png',
#               '二间身业自义.png',
#               '二队给发再已.png',
#               '于世动军义之.png',
#               '于义美有身长.png',
#               '于事目军将变.png',
#               '于产点可月师.png',
#               '于亲再下系置.png',
#               '于件二究这尼.png',
#               '于原解准放据.png',
#               '于因计术现神.png',
#               '于在本导帮道.png',
#               '于帮求将联每.png',
#               '于快罗方声儿.png',
#               '于情笑平持听.png',
#               '于改罗水边区.png',
#               '于攻从我口些.png',
#               '于月目标像度.png',
#               '于果法是笑任.png',
#               '于样常思准化.png',
#               '于根维或影定.png',
#               '于次事构制用.png',
#               '于民程定尼尔.png',
#               '于水义去们政.png',
#               '于温德期部反.png',
#               '于相平士眼相.png',
#               '于置政所对都.png',
#               '于老或层马刚.png',
#               '于者组什刚指.png',
#               '于色达较量方.png',
#               '互也把研如实.png',
#               '互们类住从要.png',
#               '互几应区本后.png',
#               '互分信办点系.png',
#               '互听指一高攻.png',
#               '互因积期二点.png',
#               '互头意回活些.png',
#               '互实军名林数.png',
#               '互尼看小直很.png',
#               '互当快任心传.png',
#               '互情到候联子.png',
#               '互成得者公清.png',
#               '互才成器在切.png',
#               '互拉式头他定.png',
#               '互收意值较让.png',
#               '互整别共同建.png',
#               '互条共争还求.png',
#               '互温快品法然.png',
#               '互现教度各切.png',
#               '互觉先团进互.png',
#               '互言年极前设.png',
#               '互让内那管里.png',
#               '互议作特安用.png',
#               '互该高信么感.png',
#               '互过求己体再.png',
#               '互都切即平于.png',
#               '五三施做了色.png',
#               '五信则华把个.png',
#               '五北条应活打.png',
#               '五基济个手老.png',
#               '五定步极表美.png',
#               '五师变克社电.png',
#               '五干领看海件.png',
#               '五或产至先说.png',
#               '五指光报感物.png',
#               '五更什让从观.png',
#               '五次果像究利.png',
#               '五民尼构人真.png',
#               '五生任推全起.png',
#               '五界十市明至.png',
#               '五科队次服人.png',
#               '五组日及很界.png',
#               '五维极整了年.png',
#               '五置部整往车.png',
#               '五英调全尔象.png',
#               '五英风被只目.png',
#               '五言据德工西.png',
#               '五这点美两件.png',
#               '五通北工合建.png',
#               '五造他政克受.png',
#               '五部去战传老.png',
#               '些主性经年备.png',
#               '些义儿被决十.png',
#               '些互金争干调.png',
#               '些任家它新太.png',
#               '些便规影空多.png',
#               '些值命达系争.png',
#               '些元构界建电.png',
#               '些克少相笑都.png',
#               '些几准难持进.png',
#               '些分候机件望.png',
#               '些利方斯比就.png',
#               '些利权张次及.png',
#               '些加问及队山.png',
#               '些向事次议员.png',
#               '些女很作报己.png',
#               '些往种解规关.png',
#               '些战文快作般.png',
#               '些显基及职世.png',
#               '些林影论马己.png',
#               '些民又科天带.png',
#               '些用要次马战.png',
#               '些相车克光子.png',
#               '些统候进么带.png',
#               '些般院却向服.png',
#               '些连告笑多或.png',
#               '交不区军安务.png',
#               '交了身共亲又.png',
#               '交刚类见神所.png',
#               '交加儿识市经.png',
#               '交区建书论所.png',
#               '交只书代王重.png',
#               '交命下拉新区.png',
#               '交器生林当当.png',
#               '交场电头维表.png',
#               '交女共然合使.png',
#               '交它女领目用.png',
#               '交帮究什没造.png',
#               '交必什施说气.png',
#               '交手开觉施院.png',
#               '交指动做打确.png',
#               '交提进看内无.png',
#               '交斯活第我生.png',
#               '交无流也争用.png',
#               '交明报论两领.png',
#               '交术道入近证.png',
#               '交现本又学车.png',
#               '交至方础往教.png',
#               '交般期己别美.png',
#               '交要数处金罗.png',
#               '交言美特气听.png',
#               '交论走水位展.png',
#               '交连度听文般.png',
#               '交题打互高题.png',
#               '产世使是还下.png',
#               '产会或代些领.png',
#               '产准进化础般.png',
#               '产取里立都性.png',
#               '产士超准攻化.png',
#               '产女身整标部.png',
#               '产定也落条万.png',
#               '产尼政其明所.png',
#               '产干个来不活.png',
#               '产影东备收条.png',
#               '产很影近层识.png',
#               '产心尼生带领.png',
#               '产快因标导这.png',
#               '产战无连二反.png',
#               '产指交所放可.png',
#               '产施边公那置.png',
#               '产望基则生效.png',
#               '产格话界推观.png',
#               '产种则业高持.png',
#               '产空话对色果.png',
#               '产笑服张极我.png',
#               '产系本决飞认.png',
#               '产色确身论特.png',
#               '产设受上也每.png',
#               '亲事告难重比.png',
#               '亲公风事军又.png',
#               '亲制合超区神.png',
#               '亲区要现超生.png',
#               '亲口被展生运.png',
#               '亲司治无认边.png',
#               '亲尔格变风生.png',
#               '亲强由般要别.png',
#               '亲教第层有第.png',
#               '亲水却系年产.png',
#               '亲电南气天联.png',
#               '亲积理师学置.png',
#               '亲英什可意究.png',
#               '亲落三什作治.png',
#               '亲被程超象科.png',
#               '亲门回问服作.png',
#               '亲风南打主争.png',
#               '亲马干领主此.png',
#               '人与或积心参.png',
#               '人且互或或达.png',
#               '人书制德攻快.png',
#               '人互求术刚明.png',
#               '人再施我山政.png',
#               '人军础进命战.png',
#               '人准南门德层.png',
#               '人到但般新气.png',
#               '人回象色该女.png',
#               '人她交互与观.png',
#               '人对间务由部.png',
#               '人尼气研系基.png',
#               '人所尼还言求.png',
#               '人收想理战师.png',
#               '人改生系法据.png',
#               '人构在重重变.png',
#               '人求意由出子.png',
#               '人究产被业说.png',
#               '人能界施运者.png',
#               '人落提者且务.png',
#               '人言现无能只.png',
#               '人道法识度使.png',
#               '人门帮尼让务.png',
#               '人马明济金间.png',
#               '什互得格准子.png',
#               '什人拉取格前.png',
#               '什使较望么达.png',
#               '什保身过己刚.png',
#               '什值来神领因.png',
#               '什全何解下队.png',
#               '什准度家系当.png',
#               '什即发成展确.png',
#               '什听东来运报.png',
#               '什回告常司日.png',
#               '什她落让日义.png',
#               '什子帮两于法.png',
#               '什安且争克女.png',
#               '什常们过山其.png',
#               '什常活议应管.png',
#               '什应动统安面.png',
#               '什当话着即社.png',
#               '什水光持进做.png',
#               '什科身识温学.png',
#               '什系般风有加.png',
#               '什者王现身与.png',
#               '什联经及那还.png',
#               '什落那数它多.png',
#               '什镇使性真器.png',
#               '什长好太身表.png',
#               '什长电量应或.png',
#               '什问天想究士.png',
#               '今作路么感值.png',
#               '今入色础战的.png',
#               '今军电定近没.png',
#               '今到取重层感.png',
#               '今又我关白合.png',
#               '今又走可必还.png',
#               '今在解几文亲.png',
#               '今多传告十想.png',
#               '今尔又本问觉.png',
#               '今常美民保者.png',
#               '今建式收气刚.png',
#               '今律至可参象.png',
#               '今所题代非活.png',
#               '今政听感义结.png',
#               '今期共好并明.png',
#               '今条小子积产.png',
#               '今林意职与上.png',
#               '今正光程色而.png',
#               '今然备但联才.png',
#               '今界就要边华.png',
#               '今的界区色她.png',
#               '今社决成应十.png',
#               '今程温回及告.png',
#               '今给亲效走为.png',
#               '今而走开根看.png',
#               '今自影起眼那.png',
#               '今被如如真界.png',
#               '今识规识且管.png',
#               '今都开交海理.png',
#               '今难里团立安.png',
#               '今面长他的声.png',
#               '今马白至求话.png',
#               '从互一告建非.png',
#               '从互东听效克.png',
#               '从产亲品有华.png',
#               '从候量新数反.png',
#               '从几非议界才.png',
#               '从切其很海观.png',
#               '从北气元住展.png',
#               '从区之拉计难.png',
#               '从区础扩下整.png',
#               '从口先你难书.png',
#               '从少后资快业.png',
#               '从接建如走求.png',
#               '从提高互动持.png',
#               '从放根术司便.png',
#               '从效色通两尼.png',
#               '从望保导工处.png',
#               '从次入产术开.png',
#               '从步式天超合.png',
#               '从神争新很军.png',
#               '从统即出且出.png',
#               '从职我格取互.png',
#               '从英尔尔觉政.png',
#               '从见显放如值.png',
#               '从解较去听所.png',
#               '从议起导格互.png',
#               '从身师师太尼.png',
#               '从都想特职出.png',
#               '从领服后师领.png',
#               '从风了第思有.png',
#               '他一值由完说.png',
#               '他之经活表光.png',
#               '他书金无头完.png',
#               '他人切光维作.png',
#               '他传种件活开.png',
#               '他保落司数件.png',
#               '他值那日自基.png',
#               '他元死界施化.png',
#               '他元通们该名.png',
#               '他其马义最司.png',
#               '他利文政点却.png',
#               '他司合然先许.png',
#               '他司德儿题从.png',
#               '他合办场四下.png',
#               '他将理扩口效.png',
#               '他德显五教造.png',
#               '他总言亲管至.png',
#               '他数声几给领.png',
#               '他权无资近放.png',
#               '他果面士导改.png',
#               '他清告声自成.png',
#               '他被万后言提.png',
#               '他解尼手好女.png',
#               '他言点五长导.png',
#               '他资带决并海.png',
#               '代且望然正一.png',
#               '代住尔落程回.png',
#               '代像业解他小.png',
#               '代内职年类成.png',
#               '代准元什回第.png',
#               '代刚克研学教.png',
#               '代司取推四连.png',
#               '代四一女力系.png',
#               '代多准业三王.png',
#               '代强三想少如.png',
#               '代德往事许然.png',
#               '代施并海总期.png',
#               '代更回主设去.png',
#               '代比些所提世.png',
#               '代研达面标师.png',
#               '代种受备候体.png',
#               '代行清放意达.png',
#               '代该德四超基.png',
#               '们主证温处职.png',
#               '们义分观风自.png',
#               '们书特却月清.png',
#               '们些且社原手.png',
#               '们何利长程识.png',
#               '们做高去万数.png',
#               '们合家水施王.png',
#               '们备有司飞收.png',
#               '们尔力步立加.png',
#               '们意代他流切.png',
#               '们拉造扩点代.png',
#               '们接文件德难.png',
#               '们斯什信老资.png',
#               '们比两同事打.png',
#               '们没笑风且分.png',
#               '们海已那且整.png',
#               '们然强接方拉.png',
#               '们现识新身今.png',
#               '们英每十新让.png',
#               '们让斯建记小.png',
#               '们论住件他会.png',
#               '们起信则因打.png',
#               '们量形计处师.png',
#               '件与队区造马.png',
#               '件两决本经建.png',
#               '件为活已较太.png',
#               '件他强完名外.png',
#               '件件五帮变职.png',
#               '件光则立造儿.png',
#               '件再生术基该.png',
#               '件只当几影市.png',
#               '件它西便后力.png',
#               '件来比术主南.png',
#               '件步根真行争.png',
#               '件法子放处清.png',
#               '件海证尔变联.png',
#               '件用空变前超.png',
#               '件自少身直也.png',
#               '件被者人制反.png',
#               '件论切再一新.png',
#               '件话及也西表.png',
#               '件资样我置处.png',
#               '件近较互飞解.png',
#               '件进名很信及.png',
#               '件连值处次月.png',
#               '件通理镇后快.png',
#               '件道着家张持.png',
#               '任什学它收传.png',
#               '任便参尔现去.png',
#               '任关义十这听.png',
#               '任几非报物新.png',
#               '任去书听较效.png',
#               '任及连快气济.png',
#               '任团也重只受.png',
#               '任备命看济它.png',
#               '任头别调导或.png',
#               '任安务流没民.png',
#               '任形化造方干.png',
#               '任性神极见社.png',
#               '任情层当到值.png',
#               '任感由先员些.png',
#               '任持及样议问.png',
#               '任极求应有且.png',
#               '任标手意据或.png',
#               '任王究温于产.png',
#               '任着给计我值.png',
#               '任研后就及带.png',
#               '任研成知服老.png',
#               '任社带根王车.png',
#               '任美备比则取.png',
#               '任言务直准政.png',
#               '任进已刚路市.png',
#               '任进由量死根.png',
#               '会们斯切年造.png',
#               '会任心华何马.png',
#               '会使斯区先区.png',
#               '会信展还没期.png',
#               '会共争争管司.png',
#               '会前超言等金.png',
#               '会化对东科笑.png',
#               '会回位期两二.png',
#               '会律是并或导.png',
#               '会手风电公加.png',
#               '会收明因老作.png',
#               '会数或话权你.png',
#               '会治研打三条.png',
#               '会活十像实二.png',
#               '会海这手斯但.png',
#               '会特用由领决.png',
#               '会白各可提正.png',
#               '会究后金置应.png',
#               '会老办斯美体.png',
#               '会规真备要但.png',
#               '会觉它士扩人.png',
#               '会言发克间西.png',
#               ...],
#              'label': [[2, 6, 51, 201, 163, 170],
#               [2, 313, 348, 121, 115, 391],
#               [2, 91, 225, 148, 223, 76],
#               [2, 142, 207, 57, 228, 140],
#               [2, 108, 42, 209, 266, 4],
#               [2, 171, 366, 55, 213, 96],
#               [2, 191, 171, 325, 368, 52],
#               [2, 205, 204, 337, 221, 218],
#               [2, 188, 92, 139, 172, 4],
#               [2, 60, 306, 136, 142, 303],
#               [2, 38, 362, 105, 93, 404],
#               [2, 87, 329, 53, 40, 350],
#               [2, 372, 15, 172, 336, 208],
#               [2, 131, 358, 82, 142, 56],
#               [2, 83, 104, 399, 390, 31],
#               [2, 359, 335, 15, 148, 389],
#               [2, 350, 370, 19, 98, 203],
#               [2, 321, 16, 269, 97, 32],
#               [2, 290, 20, 110, 301, 138],
#               [2, 345, 383, 359, 216, 28],
#               [2, 176, 171, 31, 39, 51],
#               [2, 292, 196, 380, 60, 250],
#               [2, 44, 303, 285, 323, 159],
#               [2, 223, 389, 311, 55, 256],
#               [2, 194, 108, 317, 151, 271],
#               [2, 361, 205, 175, 398, 117],
#               [2, 250, 220, 112, 240, 19],
#               [315, 51, 381, 227, 54, 291],
#               [315, 42, 119, 331, 313, 148],
#               [315, 26, 167, 343, 140, 344],
#               [315, 255, 400, 338, 60, 108],
#               [315, 72, 319, 109, 74, 267],
#               [315, 385, 321, 388, 190, 234],
#               [315, 164, 369, 122, 183, 103],
#               [315, 41, 334, 281, 354, 381],
#               [315, 54, 254, 35, 25, 384],
#               [315, 75, 84, 163, 141, 78],
#               [315, 111, 149, 72, 16, 46],
#               [315, 132, 151, 14, 253, 356],
#               [315, 352, 254, 139, 407, 200],
#               [315, 267, 196, 401, 356, 350],
#               [315, 248, 146, 34, 258, 70],
#               [315, 220, 290, 103, 72, 313],
#               [315, 339, 318, 149, 391, 211],
#               [315, 351, 152, 125, 216, 2],
#               [315, 160, 264, 53, 386, 407],
#               [315, 160, 214, 26, 222, 206],
#               [315, 74, 340, 169, 332, 236],
#               [315, 32, 348, 208, 407, 248],
#               [315, 261, 145, 359, 242, 76],
#               [118, 313, 383, 250, 228, 348],
#               [118, 175, 335, 204, 56, 156],
#               [118, 302, 351, 84, 9, 297],
#               [118, 142, 279, 298, 103, 50],
#               [118, 203, 228, 393, 403, 172],
#               [118, 308, 94, 130, 342, 304],
#               [118, 286, 221, 238, 137, 288],
#               [118, 385, 362, 226, 287, 367],
#               [118, 230, 341, 330, 136, 116],
#               [118, 164, 402, 150, 178, 358],
#               [118, 193, 377, 1, 240, 27],
#               [118, 251, 50, 152, 78, 88],
#               [118, 219, 369, 171, 35, 262],
#               [118, 100, 54, 2, 250, 283],
#               [118, 27, 56, 155, 341, 377],
#               [118, 33, 250, 384, 196, 142],
#               [118, 97, 110, 382, 342, 216],
#               [118, 236, 328, 218, 37, 21],
#               [118, 153, 52, 150, 347, 67],
#               [118, 306, 22, 317, 370, 355],
#               [118, 404, 386, 392, 75, 399],
#               [118, 184, 301, 137, 269, 47],
#               [118, 106, 14, 345, 6, 82],
#               [118, 63, 337, 73, 270, 361],
#               [118, 260, 152, 348, 147, 106],
#               [118, 46, 376, 72, 394, 171],
#               [118, 314, 66, 342, 300, 32],
#               [118, 244, 149, 52, 226, 123],
#               [118, 332, 15, 159, 101, 140],
#               [118, 68, 84, 75, 105, 346],
#               [14, 35, 38, 285, 352, 224],
#               [14, 289, 167, 370, 217, 47],
#               [14, 174, 391, 130, 336, 20],
#               [14, 126, 234, 287, 349, 399],
#               [14, 175, 57, 359, 31, 11],
#               [14, 363, 334, 348, 49, 33],
#               [14, 78, 137, 61, 44, 344],
#               [14, 360, 148, 277, 303, 400],
#               [14, 273, 249, 108, 84, 201],
#               [14, 111, 120, 217, 399, 332],
#               [14, 87, 347, 269, 287, 235],
#               [14, 407, 180, 315, 376, 379],
#               [14, 141, 61, 190, 401, 250],
#               [14, 161, 230, 217, 328, 155],
#               [14, 3, 2, 6, 330, 206],
#               [14, 290, 57, 276, 108, 131],
#               [14, 192, 115, 362, 97, 204],
#               [14, 145, 203, 224, 93, 238],
#               [14, 274, 56, 172, 32, 302],
#               [14, 116, 240, 23, 220, 45],
#               [14, 304, 68, 255, 315, 402],
#               [14, 257, 283, 381, 208, 125],
#               [14, 144, 61, 346, 230, 78],
#               [14, 309, 171, 376, 265, 327],
#               [14, 133, 43, 90, 394, 237],
#               [14, 395, 321, 329, 212, 91],
#               [14, 102, 132, 83, 298, 44],
#               [35, 174, 43, 260, 349, 359],
#               [35, 149, 23, 311, 78, 338],
#               [35, 42, 401, 393, 148, 207],
#               [35, 205, 47, 223, 181, 121],
#               [35, 193, 46, 346, 87, 227],
#               [35, 7, 37, 43, 347, 173],
#               [35, 155, 270, 294, 274, 276],
#               [35, 237, 292, 199, 184, 304],
#               [35, 87, 320, 356, 184, 51],
#               [35, 362, 245, 20, 195, 160],
#               [35, 249, 120, 389, 260, 286],
#               [35, 189, 121, 243, 336, 200],
#               [35, 224, 148, 364, 65, 105],
#               [35, 161, 395, 263, 1, 406],
#               [35, 53, 379, 318, 66, 236],
#               [35, 10, 357, 146, 36, 53],
#               [35, 352, 273, 242, 316, 146],
#               [35, 352, 143, 266, 138, 44],
#               [35, 182, 273, 29, 405, 41],
#               [35, 279, 385, 183, 365, 157],
#               [35, 248, 132, 359, 5, 236],
#               [35, 116, 19, 377, 34, 131],
#               [35, 324, 85, 293, 387, 194],
#               [35, 96, 68, 345, 244, 320],
#               [35, 397, 94, 302, 226, 41],
#               [35, 397, 30, 71, 271, 215],
#               [35, 394, 73, 128, 30, 363],
#               [6, 34, 106, 124, 211, 9],
#               [6, 91, 306, 347, 272, 171],
#               [6, 91, 114, 281, 165, 29],
#               [6, 9, 343, 278, 161, 387],
#               [6, 169, 341, 307, 252, 179],
#               [6, 287, 140, 314, 319, 360],
#               [6, 300, 225, 150, 288, 301],
#               [6, 231, 213, 170, 386, 131],
#               [6, 93, 377, 96, 390, 251],
#               [6, 87, 113, 72, 108, 289],
#               [6, 87, 197, 73, 368, 311],
#               [6, 52, 77, 129, 37, 153],
#               [6, 141, 293, 191, 364, 22],
#               [6, 81, 169, 118, 193, 41],
#               [6, 192, 100, 12, 258, 153],
#               [6, 388, 1, 222, 320, 120],
#               [6, 324, 141, 70, 406, 172],
#               [6, 144, 405, 52, 284, 285],
#               [6, 361, 205, 4, 15, 339],
#               [6, 361, 298, 343, 353, 211],
#               [101, 123, 218, 182, 163, 350],
#               [101, 355, 157, 190, 23, 290],
#               [101, 149, 203, 259, 51, 386],
#               [101, 149, 173, 407, 337, 105],
#               [101, 389, 146, 151, 277, 366],
#               [101, 203, 81, 271, 165, 348],
#               [101, 95, 335, 293, 189, 197],
#               [101, 402, 90, 178, 180, 332],
#               [101, 300, 129, 310, 107, 77],
#               [101, 89, 157, 118, 133, 35],
#               [101, 7, 241, 344, 232, 163],
#               [101, 335, 400, 214, 77, 328],
#               [101, 216, 243, 278, 367, 33],
#               [101, 284, 293, 138, 378, 81],
#               [101, 158, 304, 275, 4, 193],
#               [101, 82, 147, 366, 106, 219],
#               [101, 129, 367, 97, 138, 283],
#               [101, 263, 393, 316, 89, 210],
#               [101, 270, 306, 398, 164, 296],
#               [101, 392, 53, 152, 318, 246],
#               [101, 206, 389, 172, 169, 6],
#               [101, 198, 84, 69, 84, 149],
#               [101, 61, 397, 155, 127, 335],
#               [101, 269, 192, 31, 200, 262],
#               [289, 112, 157, 8, 173, 8],
#               [289, 363, 323, 359, 185, 35],
#               [289, 70, 400, 96, 18, 404],
#               [289, 155, 366, 2, 273, 165],
#               [289, 137, 268, 131, 247, 129],
#               [289, 52, 86, 396, 111, 74],
#               [289, 138, 253, 175, 289, 124],
#               [289, 158, 198, 266, 298, 267],
#               [289, 65, 240, 398, 65, 202],
#               [289, 166, 157, 116, 167, 393],
#               [289, 82, 403, 171, 21, 65],
#               [289, 197, 56, 3, 395, 288],
#               [289, 116, 17, 166, 191, 59],
#               [289, 244, 249, 402, 285, 46],
#               [289, 256, 234, 46, 48, 95],
#               [289, 198, 78, 310, 285, 160],
#               [174, 9, 175, 272, 362, 181],
#               [174, 23, 204, 345, 126, 162],
#               [174, 18, 239, 194, 183, 31],
#               [174, 18, 220, 114, 149, 249],
#               [174, 218, 248, 197, 279, 202],
#               [174, 62, 200, 323, 407, 70],
#               [174, 196, 203, 385, 90, 160],
#               [174, 165, 270, 283, 330, 268],
#               [174, 273, 245, 345, 155, 127],
#               [174, 71, 75, 125, 196, 250],
#               [174, 237, 345, 156, 156, 175],
#               [174, 317, 373, 330, 65, 118],
#               [174, 224, 109, 143, 63, 59],
#               [174, 154, 358, 383, 259, 154],
#               [174, 371, 189, 136, 407, 351],
#               [174, 135, 180, 401, 176, 347],
#               [174, 281, 33, 346, 160, 162],
#               [174, 209, 168, 97, 64, 217],
#               [174, 173, 352, 350, 4, 117],
#               [174, 384, 66, 178, 196, 378],
#               [174, 144, 235, 87, 4, 60],
#               [174, 349, 237, 204, 10, 33],
#               [174, 206, 381, 110, 276, 325],
#               [174, 295, 262, 152, 16, 382],
#               [174, 367, 320, 184, 193, 39],
#               [174, 74, 193, 97, 38, 31],
#               [123, 289, 352, 323, 41, 119],
#               [123, 329, 75, 85, 304, 265],
#               [123, 235, 201, 67, 231, 227],
#               [123, 105, 117, 38, 311, 375],
#               [123, 300, 119, 73, 138, 215],
#               [123, 280, 229, 343, 116, 189],
#               [123, 196, 158, 168, 336, 263],
#               [123, 303, 45, 137, 17, 334],
#               [123, 199, 292, 371, 342, 285],
#               [123, 213, 180, 49, 175, 134],
#               [123, 373, 400, 256, 187, 119],
#               [123, 137, 371, 73, 291, 33],
#               [123, 64, 381, 15, 227, 397],
#               [123, 106, 125, 137, 94, 369],
#               [123, 55, 142, 299, 187, 5],
#               [123, 146, 216, 101, 65, 384],
#               [123, 332, 112, 51, 57, 379],
#               [123, 67, 288, 100, 169, 354],
#               [187, 337, 260, 248, 348, 350],
#               [187, 243, 111, 33, 4, 323],
#               [187, 179, 92, 6, 194, 398],
#               [187, 266, 398, 322, 142, 123],
#               [187, 215, 353, 153, 315, 190],
#               [187, 360, 156, 269, 340, 276],
#               [187, 191, 397, 226, 8, 345],
#               [187, 62, 102, 48, 210, 158],
#               [187, 89, 133, 91, 269, 87],
#               [187, 124, 34, 21, 348, 48],
#               [187, 70, 68, 247, 50, 188],
#               [187, 76, 363, 2, 25, 396],
#               [187, 137, 312, 66, 367, 171],
#               [187, 296, 110, 364, 96, 232],
#               [187, 113, 182, 241, 158, 106],
#               [187, 3, 63, 12, 299, 359],
#               [187, 85, 372, 221, 138, 37],
#               [187, 401, 287, 396, 7, 307],
#               [187, 122, 179, 79, 382, 135],
#               [187, 65, 61, 283, 66, 117],
#               [187, 279, 196, 103, 347, 169],
#               [187, 378, 108, 71, 12, 35],
#               [187, 220, 293, 78, 51, 99],
#               [187, 229, 90, 356, 259, 136],
#               [187, 376, 236, 30, 368, 306],
#               [126, 118, 280, 304, 64, 368],
#               [126, 174, 225, 216, 398, 12],
#               [126, 123, 379, 119, 276, 84],
#               [126, 152, 320, 93, 63, 363],
#               [126, 26, 264, 279, 168, 323],
#               [126, 334, 186, 312, 221, 168],
#               [126, 168, 385, 177, 363, 220],
#               [126, 300, 342, 290, 336, 374],
#               [126, 286, 145, 33, 182, 204],
#               [126, 316, 342, 300, 341, 377],
#               [126, 193, 204, 214, 73, 172],
#               [126, 165, 400, 184, 1, 40],
#               [126, 21, 99, 94, 235, 62],
#               [126, 131, 71, 311, 162, 289],
#               [126, 83, 1, 259, 7, 254],
#               [126, 113, 26, 125, 200, 153],
#               [126, 143, 254, 109, 98, 200],
#               [126, 357, 150, 248, 23, 100],
#               [126, 176, 301, 362, 70, 168],
#               [126, 197, 97, 318, 192, 42],
#               [126, 381, 225, 142, 137, 146],
#               [126, 144, 34, 230, 258, 343],
#               [126, 128, 293, 148, 146, 182],
#               [16, 187, 386, 347, 39, 113],
#               [16, 8, 2, 202, 49, 391],
#               [16, 42, 344, 333, 63, 203],
#               [16, 181, 98, 315, 114, 310],
#               [16, 323, 269, 341, 369, 110],
#               [16, 402, 291, 266, 327, 384],
#               [16, 171, 113, 6, 274, 404],
#               [16, 308, 113, 114, 86, 199],
#               [16, 398, 305, 324, 364, 206],
#               [16, 90, 84, 180, 107, 308],
#               [16, 271, 164, 152, 325, 367],
#               [16, 62, 182, 87, 279, 186],
#               [16, 21, 200, 294, 398, 281],
#               [16, 296, 30, 308, 161, 228],
#               [16, 64, 375, 349, 135, 381],
#               [16, 241, 98, 237, 347, 196],
#               [16, 236, 304, 63, 319, 179],
#               [16, 141, 283, 372, 328, 92],
#               [16, 176, 206, 47, 325, 157],
#               [16, 310, 375, 32, 172, 277],
#               [16, 82, 120, 96, 82, 377],
#               [16, 36, 356, 107, 287, 12],
#               [16, 20, 82, 21, 311, 201],
#               [16, 327, 52, 376, 29, 263],
#               [16, 314, 340, 55, 351, 369],
#               [16, 163, 248, 323, 356, 224],
#               [16, 77, 50, 141, 236, 17],
#               [16, 341, 340, 306, 88, 286],
#               [17, 179, 312, 100, 150, 77],
#               [17, 302, 155, 289, 384, 167],
#               [17, 203, 197, 13, 224, 80],
#               [17, 108, 91, 147, 296, 307],
#               [17, 277, 324, 185, 336, 348],
#               [17, 156, 180, 240, 54, 212],
#               [17, 360, 342, 2, 48, 265],
#               [17, 300, 381, 38, 100, 401],
#               [17, 271, 329, 163, 398, 151],
#               [17, 89, 59, 177, 137, 225],
#               [17, 217, 281, 79, 294, 376],
#               [17, 84, 57, 152, 250, 35],
#               [17, 76, 54, 362, 32, 40],
#               [17, 247, 112, 257, 262, 107],
#               [17, 380, 251, 327, 289, 205],
#               [17, 372, 390, 92, 167, 355],
#               [17, 33, 47, 156, 236, 359],
#               [17, 383, 117, 82, 192, 63],
#               [17, 132, 82, 301, 402, 379],
#               [17, 162, 104, 214, 4, 89],
#               [17, 358, 9, 9, 375, 141],
#               [17, 319, 102, 315, 237, 110],
#               [17, 11, 374, 17, 15, 315],
#               [17, 82, 287, 359, 205, 232],
#               [17, 281, 74, 285, 83, 378],
#               [17, 378, 214, 7, 40, 373],
#               [17, 263, 246, 348, 351, 282],
#               [17, 263, 65, 69, 79, 126],
#               [17, 190, 201, 114, 93, 402],
#               [17, 190, 320, 97, 293, 302],
#               [17, 327, 185, 383, 311, 407],
#               [17, 198, 322, 402, 148, 130],
#               [17, 376, 162, 210, 119, 405],
#               [17, 74, 337, 288, 22, 273],
#               [17, 77, 364, 239, 76, 340],
#               [80, 4, 328, 295, 111, 98],
#               [80, 88, 111, 183, 55, 274],
#               [80, 402, 376, 394, 148, 9],
#               [80, 119, 55, 8, 270, 349],
#               [80, 205, 263, 380, 326, 11],
#               [80, 165, 301, 259, 347, 297],
#               [80, 242, 404, 70, 98, 92],
#               [80, 54, 270, 331, 307, 183],
#               [80, 252, 8, 116, 263, 47],
#               [80, 326, 304, 102, 182, 236],
#               [80, 208, 195, 26, 395, 92],
#               [80, 137, 208, 321, 328, 96],
#               [80, 249, 24, 281, 330, 293],
#               [80, 136, 101, 114, 180, 22],
#               [80, 403, 250, 64, 240, 177],
#               [80, 195, 278, 402, 384, 324],
#               [80, 121, 396, 278, 400, 42],
#               [80, 129, 403, 75, 277, 19],
#               [80, 324, 13, 258, 107, 44],
#               [80, 50, 329, 14, 41, 293],
#               [80, 50, 104, 260, 18, 215],
#               [80, 265, 25, 379, 11, 236],
#               [80, 96, 252, 325, 250, 173],
#               [80, 147, 60, 172, 70, 351],
#               [80, 293, 39, 315, 228, 222],
#               [80, 178, 62, 257, 131, 129],
#               [80, 130, 150, 103, 385, 77],
#               [80, 130, 43, 289, 284, 59],
#               [80, 288, 306, 352, 130, 58],
#               [56, 23, 180, 312, 169, 301],
#               [56, 22, 108, 232, 382, 279],
#               [56, 66, 41, 93, 222, 92],
#               [56, 398, 208, 375, 126, 163],
#               [56, 300, 259, 60, 267, 168],
#               [56, 186, 56, 214, 56, 278],
#               [56, 316, 118, 80, 273, 183],
#               [56, 24, 197, 302, 182, 339],
#               [56, 301, 184, 227, 32, 313],
#               [56, 165, 143, 17, 23, 272],
#               [56, 54, 124, 337, 190, 135],
#               [56, 70, 399, 155, 320, 25],
#               [56, 380, 79, 211, 24, 277],
#               [56, 372, 72, 181, 304, 53],
#               [56, 207, 22, 89, 299, 39],
#               [56, 263, 272, 345, 183, 401],
#               [56, 384, 321, 64, 2, 208],
#               [56, 369, 406, 266, 246, 159],
#               [56, 348, 31, 58, 19, 252],
#               [56, 157, 175, 182, 189, 53],
#               [56, 39, 38, 190, 42, 37],
#               [56, 39, 107, 208, 292, 30],
#               [201, 79, 57, 96, 380, 247],
#               [201, 363, 283, 137, 105, 42],
#               [201, 120, 190, 41, 263, 186],
#               [201, 159, 178, 240, 193, 52],
#               [201, 238, 136, 170, 238, 406],
#               [201, 231, 274, 165, 134, 193],
#               [201, 251, 45, 278, 210, 289],
#               [201, 273, 61, 290, 324, 313],
#               [201, 237, 11, 198, 129, 135],
#               [201, 362, 279, 334, 224, 291],
#               [201, 317, 329, 176, 32, 98],
#               [201, 350, 314, 254, 44, 117],
#               [201, 357, 217, 252, 152, 153],
#               [201, 65, 276, 367, 220, 111],
#               [201, 69, 362, 119, 323, 201],
#               [201, 197, 74, 175, 306, 178],
#               [201, 263, 135, 169, 156, 295],
#               [201, 172, 267, 31, 375, 338],
#               [201, 147, 63, 390, 232, 113],
#               [201, 20, 374, 60, 15, 52],
#               [201, 293, 87, 394, 177, 31],
#               [37, 6, 212, 56, 134, 1],
#               [37, 17, 248, 132, 274, 227],
#               [37, 313, 283, 201, 85, 135],
#               [37, 329, 62, 307, 292, 271],
#               [37, 95, 240, 304, 258, 71],
#               [37, 22, 30, 224, 298, 331],
#               [37, 251, 93, 291, 4, 375],
#               [37, 54, 156, 117, 317, 388],
#               [37, 31, 188, 269, 32, 108],
#               [37, 70, 224, 239, 58, 252],
#               [37, 49, 45, 389, 318, 284],
#               [37, 252, 26, 32, 275, 206],
#               [37, 247, 351, 203, 25, 90],
#               [37, 97, 265, 338, 280, 392],
#               [37, 103, 261, 368, 184, 9],
#               [37, 306, 201, 257, 77, 238],
#               [37, 345, 53, 388, 79, 371],
#               [37, 195, 324, 392, 60, 40],
#               [37, 29, 401, 91, 60, 225],
#               [37, 170, 233, 117, 147, 121],
#               [37, 198, 182, 131, 70, 249],
#               [37, 276, 15, 9, 287, 89],
#               [25, 123, 375, 39, 265, 382],
#               [25, 51, 335, 174, 369, 68],
#               [25, 334, 200, 89, 405, 383],
#               [25, 255, 170, 47, 274, 380],
#               [25, 235, 78, 314, 101, 317],
#               [25, 86, 406, 230, 396, 160],
#               [25, 193, 113, 199, 201, 118],
#               [25, 59, 108, 371, 24, 86],
#               [25, 27, 179, 42, 102, 209],
#               [25, 189, 120, 153, 263, 331],
# ...
#               [272, 214, 149, 332, 91, 327],
#               [272, 176, 158, 287, 406, 148],
#               [272, 106, 370, 371, 8, 197],
#               [272, 28, 179, 404, 117, 68],
#               [272, 281, 105, 247, 114, 260],
#               [272, 270, 261, 176, 358, 8],
#               [272, 351, 94, 191, 131, 281],
#               [272, 387, 356, 383, 4, 38],
#               [272, 381, 77, 383, 362, 354],
#               [272, 364, 376, 117, 213, 293],
#               [272, 364, 341, 147, 90, 232],
#               [272, 348, 306, 249, 111, 160],
#               [272, 13, 121, 144, 126, 243],
#               [272, 183, 308, 111, 164, 237],
#               [272, 347, 12, 143, 255, 231],
#               [272, 77, 57, 138, 325, 172],
#               [79, 80, 115, 55, 38, 386],
#               [79, 201, 185, 147, 266, 105],
#               [79, 396, 253, 337, 346, 376],
#               [79, 179, 49, 100, 154, 233],
#               [79, 264, 314, 372, 265, 54],
#               [79, 389, 251, 282, 209, 337],
#               [79, 363, 371, 281, 237, 223],
#               [79, 255, 226, 145, 339, 61],
#               [79, 204, 402, 288, 350, 74],
#               [79, 72, 334, 104, 243, 319],
#               [79, 148, 53, 161, 192, 21],
#               [79, 148, 290, 311, 176, 191],
#               [79, 159, 130, 191, 261, 252],
#               [79, 139, 51, 176, 361, 193],
#               [79, 217, 131, 42, 227, 155],
#               [79, 362, 50, 194, 314, 120],
#               [79, 138, 141, 359, 42, 369],
#               [79, 399, 273, 191, 392, 174],
#               [79, 357, 372, 198, 269, 155],
#               [79, 106, 119, 270, 71, 335],
#               [79, 44, 20, 176, 269, 138],
#               [79, 145, 354, 255, 283, 31],
#               [79, 257, 334, 74, 56, 335],
#               [79, 369, 331, 280, 139, 358],
#               [79, 394, 303, 339, 54, 153],
#               [313, 6, 258, 95, 225, 238],
#               [313, 4, 157, 323, 355, 119],
#               [313, 400, 304, 146, 220, 47],
#               [313, 159, 185, 333, 247, 55],
#               [313, 258, 237, 275, 198, 47],
#               [313, 90, 275, 167, 292, 133],
#               [313, 251, 35, 317, 154, 258],
#               [313, 374, 28, 357, 64, 64],
#               [313, 242, 223, 140, 387, 170],
#               [313, 217, 323, 48, 164, 112],
#               [313, 100, 217, 322, 232, 44],
#               [313, 380, 406, 149, 65, 347],
#               [313, 241, 149, 405, 19, 210],
#               [313, 136, 87, 320, 405, 331],
#               [313, 254, 66, 239, 216, 324],
#               [313, 189, 74, 69, 168, 98],
#               [313, 161, 212, 107, 5, 28],
#               [313, 98, 393, 25, 337, 44],
#               [313, 114, 227, 198, 126, 322],
#               [313, 321, 45, 203, 367, 366],
#               [313, 63, 85, 119, 59, 354],
#               [313, 260, 53, 388, 362, 184],
#               [313, 369, 246, 155, 215, 144],
#               [313, 20, 224, 199, 253, 384],
#               [313, 348, 144, 166, 210, 278],
#               [313, 198, 200, 195, 175, 268],
#               [313, 394, 177, 278, 141, 369],
#               [313, 211, 216, 396, 127, 211],
#               [152, 174, 112, 3, 73, 35],
#               [152, 23, 153, 167, 79, 322],
#               [152, 402, 74, 171, 388, 369],
#               [152, 316, 43, 190, 61, 115],
#               [152, 365, 379, 402, 403, 171],
#               [152, 217, 157, 383, 401, 77],
#               [152, 70, 25, 391, 207, 315],
#               [152, 370, 143, 78, 114, 47],
#               [152, 346, 16, 11, 6, 212],
#               [152, 372, 187, 386, 344, 207],
#               [152, 131, 372, 367, 373, 333],
#               [152, 83, 370, 28, 335, 322],
#               [152, 359, 89, 401, 336, 13],
#               [152, 138, 98, 394, 150, 230],
#               [152, 254, 313, 47, 284, 24],
#               [152, 405, 309, 108, 32, 381],
#               [152, 319, 273, 277, 28, 375],
#               [152, 318, 163, 281, 404, 327],
#               [152, 50, 277, 123, 127, 350],
#               [152, 265, 163, 27, 297, 158],
#               [152, 339, 358, 311, 356, 5],
#               [152, 209, 85, 266, 340, 206],
#               [152, 297, 324, 157, 198, 166],
#               [152, 295, 231, 14, 25, 352],
#               [355, 51, 303, 288, 133, 192],
#               [355, 108, 341, 51, 95, 119],
#               [355, 156, 164, 379, 258, 220],
#               [355, 258, 20, 63, 379, 28],
#               [355, 205, 147, 268, 28, 338],
#               [355, 271, 267, 98, 206, 309],
#               [355, 213, 318, 218, 341, 28],
#               [355, 285, 129, 369, 20, 215],
#               [355, 184, 107, 373, 10, 107],
#               [355, 195, 280, 209, 38, 152],
#               [355, 223, 300, 210, 71, 349],
#               [355, 382, 82, 326, 59, 381],
#               [355, 364, 149, 24, 97, 406],
#               [355, 391, 118, 149, 42, 267],
#               [355, 147, 307, 379, 293, 270],
#               [355, 178, 165, 130, 358, 42],
#               [355, 341, 300, 216, 80, 337],
#               [355, 269, 346, 322, 80, 109],
#               [8, 101, 153, 382, 83, 385],
#               [8, 289, 396, 153, 153, 282],
#               [8, 275, 156, 249, 403, 359],
#               [8, 396, 305, 321, 400, 114],
#               [8, 235, 405, 5, 252, 143],
#               [8, 95, 388, 74, 251, 138],
#               [8, 402, 300, 178, 249, 373],
#               [8, 18, 88, 369, 154, 210],
#               [8, 165, 293, 297, 312, 217],
#               [8, 84, 313, 396, 101, 327],
#               [8, 27, 128, 238, 129, 77],
#               [8, 370, 210, 378, 209, 273],
#               [8, 47, 370, 73, 348, 305],
#               [8, 344, 92, 82, 138, 326],
#               [8, 343, 28, 209, 58, 306],
#               [8, 371, 7, 133, 133, 218],
#               [8, 305, 97, 129, 22, 31],
#               [8, 406, 152, 147, 123, 19],
#               [8, 29, 281, 405, 338, 96],
#               [8, 391, 189, 96, 289, 238],
#               [8, 348, 63, 98, 29, 90],
#               [8, 45, 58, 333, 177, 112],
#               [8, 178, 380, 370, 332, 238],
#               [8, 269, 114, 353, 253, 128],
#               [149, 396, 33, 318, 402, 31],
#               [149, 8, 317, 316, 318, 86],
#               [149, 112, 397, 319, 56, 282],
#               [149, 259, 157, 39, 155, 400],
#               [149, 389, 11, 220, 322, 89],
#               [149, 117, 222, 194, 35, 261],
#               [149, 402, 177, 49, 209, 64],
#               [149, 286, 40, 52, 268, 324],
#               [149, 278, 187, 11, 338, 227],
#               [149, 165, 303, 180, 271, 94],
#               [149, 84, 391, 332, 94, 201],
#               [149, 31, 380, 126, 34, 58],
#               [149, 225, 289, 337, 255, 217],
#               [149, 180, 9, 39, 252, 78],
#               [149, 180, 212, 361, 137, 245],
#               [149, 137, 66, 257, 225, 67],
#               [149, 64, 163, 15, 286, 263],
#               [149, 195, 283, 350, 74, 239],
#               [149, 270, 157, 333, 390, 59],
#               [149, 209, 369, 341, 10, 159],
#               [149, 96, 292, 63, 157, 101],
#               [149, 349, 55, 191, 32, 73],
#               [149, 391, 32, 224, 100, 54],
#               [149, 395, 112, 115, 197, 374],
#               [149, 102, 75, 233, 157, 170],
#               [149, 102, 223, 234, 137, 153],
#               [149, 130, 71, 92, 406, 365],
#               [329, 42, 298, 56, 236, 389],
#               [329, 203, 297, 388, 138, 1],
#               [329, 95, 223, 70, 367, 65],
#               [329, 18, 316, 133, 373, 236],
#               [329, 119, 5, 120, 279, 164],
#               [329, 119, 200, 24, 241, 73],
#               [329, 7, 194, 204, 141, 355],
#               [329, 54, 325, 303, 105, 92],
#               [329, 213, 119, 85, 130, 320],
#               [329, 180, 144, 106, 259, 96],
#               [329, 237, 296, 344, 210, 400],
#               [329, 368, 260, 24, 385, 293],
#               [329, 47, 211, 167, 276, 212],
#               [329, 143, 278, 236, 201, 229],
#               [329, 246, 323, 75, 134, 114],
#               [329, 207, 76, 31, 382, 152],
#               [329, 357, 97, 392, 101, 14],
#               [329, 122, 283, 307, 297, 30],
#               [329, 48, 386, 88, 349, 228],
#               [329, 281, 21, 20, 309, 398],
#               [329, 1, 281, 258, 297, 84],
#               [329, 263, 266, 52, 137, 105],
#               [329, 307, 390, 165, 191, 303],
#               [329, 173, 355, 375, 200, 17],
#               [329, 30, 200, 87, 345, 69],
#               [329, 36, 372, 68, 274, 32],
#               [329, 147, 60, 60, 197, 281],
#               [329, 333, 314, 333, 289, 245],
#               [329, 61, 87, 313, 182, 82],
#               [329, 288, 43, 377, 190, 225],
#               [329, 67, 102, 12, 1, 188],
#               [329, 269, 279, 260, 305, 163],
#               [91, 396, 2, 303, 237, 276],
#               [91, 396, 187, 278, 375, 255],
#               [91, 152, 355, 301, 10, 398],
#               [91, 334, 234, 154, 224, 230],
#               [91, 204, 276, 361, 281, 228],
#               [91, 330, 78, 131, 182, 327],
#               [91, 308, 210, 363, 302, 268],
#               [91, 258, 37, 317, 244, 288],
#               [91, 258, 388, 407, 35, 383],
#               [91, 205, 181, 26, 288, 275],
#               [91, 226, 41, 250, 359, 123],
#               [91, 240, 237, 60, 200, 305],
#               [91, 189, 127, 396, 66, 350],
#               [91, 284, 345, 321, 271, 264],
#               [91, 375, 297, 183, 126, 370],
#               [91, 319, 259, 336, 111, 199],
#               [91, 176, 203, 152, 321, 87],
#               [91, 342, 296, 71, 379, 164],
#               [91, 220, 337, 154, 131, 95],
#               [91, 257, 286, 22, 289, 22],
#               [91, 392, 5, 318, 316, 396],
#               [91, 364, 213, 213, 320, 143],
#               [91, 146, 399, 284, 60, 389],
#               [91, 194, 397, 57, 278, 47],
#               [91, 361, 68, 336, 318, 396],
#               [91, 157, 326, 326, 233, 370],
#               [91, 61, 92, 166, 392, 22],
#               [91, 322, 358, 41, 326, 322],
#               [91, 341, 4, 107, 291, 10],
#               [12, 2, 389, 129, 294, 19],
#               [12, 37, 55, 212, 170, 283],
#               [12, 275, 253, 98, 140, 294],
#               [12, 8, 330, 283, 387, 42],
#               [12, 325, 50, 243, 212, 87],
#               [12, 259, 391, 271, 224, 243],
#               [12, 389, 32, 94, 36, 273],
#               [12, 363, 310, 281, 405, 171],
#               [12, 363, 183, 9, 312, 196],
#               [12, 78, 269, 201, 132, 271],
#               [12, 148, 141, 143, 121, 280],
#               [12, 271, 164, 48, 181, 256],
#               [12, 271, 249, 185, 211, 91],
#               [12, 164, 360, 242, 219, 35],
#               [12, 125, 82, 407, 205, 375],
#               [12, 249, 399, 272, 184, 347],
#               [12, 221, 348, 355, 245, 260],
#               [12, 224, 188, 204, 173, 322],
#               [12, 290, 98, 250, 367, 284],
#               [12, 158, 67, 365, 336, 343],
#               [12, 328, 303, 188, 36, 52],
#               [12, 147, 315, 41, 348, 189],
#               [12, 194, 370, 136, 75, 217],
#               [12, 348, 121, 272, 102, 336],
#               [12, 250, 335, 266, 134, 182],
#               [167, 289, 319, 48, 122, 2],
#               [167, 302, 213, 391, 307, 165],
#               [167, 287, 123, 194, 12, 76],
#               [167, 168, 392, 38, 304, 52],
#               [167, 402, 363, 149, 165, 107],
#               [167, 400, 255, 378, 59, 184],
#               [167, 271, 316, 404, 219, 394],
#               [167, 219, 2, 217, 99, 209],
#               [167, 54, 402, 123, 118, 292],
#               [167, 285, 118, 92, 226, 60],
#               [167, 249, 362, 51, 256, 48],
#               [167, 405, 134, 182, 221, 246],
#               [167, 214, 165, 80, 295, 57],
#               [167, 192, 79, 47, 189, 174],
#               [167, 378, 282, 67, 401, 326],
#               [167, 50, 231, 386, 334, 142],
#               [167, 46, 328, 284, 97, 282],
#               [167, 312, 249, 219, 379, 273],
#               [9, 80, 366, 390, 199, 392],
#               [9, 201, 72, 327, 341, 36],
#               [9, 275, 166, 280, 162, 328],
#               [9, 79, 289, 263, 186, 136],
#               [9, 222, 148, 102, 307, 333],
#               [9, 239, 127, 57, 315, 224],
#               [9, 164, 49, 195, 405, 292],
#               [9, 386, 10, 271, 340, 344],
#               [9, 213, 99, 342, 190, 159],
#               [9, 97, 167, 12, 393, 330],
#               [9, 317, 347, 407, 121, 167],
#               [9, 240, 141, 243, 249, 288],
#               [9, 161, 149, 169, 172, 250],
#               [9, 192, 126, 62, 51, 216],
#               [9, 65, 339, 341, 289, 72],
#               [9, 182, 110, 32, 289, 383],
#               [9, 48, 285, 240, 53, 317],
#               [9, 63, 333, 154, 157, 329],
#               [9, 364, 352, 105, 154, 332],
#               [9, 332, 161, 237, 299, 76],
#               [9, 198, 302, 243, 12, 23],
#               [9, 68, 169, 277, 89, 216],
#               [9, 234, 262, 244, 199, 326],
#               [243, 101, 261, 258, 347, 269],
#               [243, 126, 266, 85, 55, 237],
#               [243, 17, 212, 110, 397, 233],
#               [243, 12, 285, 294, 196, 124],
#               [243, 243, 272, 380, 218, 392],
#               [243, 283, 277, 190, 347, 185],
#               [243, 235, 28, 321, 273, 312],
#               [243, 90, 64, 204, 372, 247],
#               [243, 100, 160, 264, 41, 99],
#               [243, 11, 192, 321, 80, 300],
#               [243, 342, 345, 197, 46, 337],
#               [243, 58, 31, 284, 199, 328],
#               [243, 182, 366, 213, 218, 349],
#               [243, 44, 265, 218, 86, 379],
#               [243, 36, 226, 157, 248, 25],
#               [243, 147, 96, 8, 156, 230],
#               [243, 198, 330, 235, 2, 154],
#               [243, 163, 191, 25, 160, 170],
#               [243, 250, 81, 5, 381, 199],
#               [243, 367, 397, 396, 340, 194],
#               [243, 74, 196, 131, 169, 191],
#               [243, 394, 389, 199, 176, 162],
#               [243, 183, 82, 395, 41, 359],
#               [243, 45, 15, 49, 311, 350],
#               [179, 149, 59, 100, 344, 325],
#               [179, 264, 385, 213, 63, 57],
#               [179, 120, 201, 105, 13, 278],
#               [179, 204, 276, 227, 135, 154],
#               [179, 57, 275, 278, 397, 375],
#               [179, 191, 394, 359, 210, 353],
#               [179, 377, 25, 133, 90, 231],
#               [179, 386, 251, 69, 353, 100],
#               [179, 140, 215, 376, 336, 153],
#               [179, 225, 238, 393, 65, 106],
#               [179, 262, 171, 347, 53, 346],
#               [179, 115, 220, 356, 146, 263],
#               [179, 113, 373, 64, 18, 389],
#               [179, 236, 129, 181, 193, 79],
#               [179, 350, 191, 81, 361, 130],
#               [179, 356, 305, 137, 10, 289],
#               [179, 401, 136, 97, 306, 153],
#               [179, 292, 406, 390, 34, 152],
#               [179, 15, 173, 244, 5, 389],
#               [179, 378, 41, 21, 191, 335],
#               [179, 378, 52, 116, 358, 172],
#               [179, 263, 335, 345, 292, 354],
#               [179, 144, 386, 192, 277, 316],
#               [179, 348, 238, 248, 402, 143],
#               [179, 74, 110, 400, 298, 247],
#               [179, 74, 129, 234, 310, 345],
#               [23, 9, 161, 330, 38, 347],
#               [23, 179, 83, 398, 222, 269],
#               [23, 112, 161, 258, 181, 258],
#               [23, 169, 268, 73, 65, 246],
#               [23, 323, 337, 337, 245, 271],
#               [23, 86, 379, 348, 151, 253],
#               [23, 171, 27, 187, 270, 339],
#               [23, 165, 175, 246, 126, 150],
#               [23, 368, 3, 134, 153, 336],
#               [23, 136, 341, 223, 108, 159],
#               [23, 344, 114, 89, 172, 42],
#               [23, 224, 153, 163, 290, 26],
#               [23, 267, 378, 216, 118, 207],
#               [23, 212, 105, 287, 93, 150],
#               [23, 182, 13, 136, 161, 88],
#               [23, 166, 44, 129, 322, 266],
#               [23, 279, 202, 24, 189, 122],
#               [23, 406, 41, 253, 381, 137],
#               [23, 172, 360, 161, 144, 142],
#               [23, 314, 197, 386, 20, 88],
#               [23, 320, 100, 365, 407, 8],
#               [23, 348, 40, 255, 128, 160],
#               ...]})

# %%
df_train, df_test = train_test_split(df, test_size=0.2, shuffle=True)

# %%
class CaptchaDataset:
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        data = self.df.iloc[idx]
        image = Image.open(os.path.join(path, data['image'])).convert('L')
        label = torch.tensor(data['label'], dtype=torch.int32)
        
        if self.transform is not None:
            image = self.transform(image)
        
        return image, label
        
        
transform = T.Compose([
    T.ToTensor()
])

train_data = CaptchaDataset(df_train, transform)
test_data = CaptchaDataset(df_test, transform)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True)
test_loader = DataLoader(test_data, batch_size=8)

# %%
class Bidirectional(nn.Module):
    def __init__(self, inp, hidden, out, lstm=True):
        super(Bidirectional, self).__init__()
        if lstm:
            self.rnn = nn.LSTM(inp, hidden, bidirectional=True)
        else:
            self.rnn = nn.GRU(inp, hidden, bidirectional=True)
        self.embedding = nn.Linear(hidden*2, out)
    def forward(self, X):
        recurrent, _ = self.rnn(X)
        out = self.embedding(recurrent)     
        return out
    
    
class CRNN(nn.Module):
    def __init__(self, in_channels, output):
        super(CRNN, self).__init__()

        self.cnn = nn.Sequential(
                nn.Conv2d(in_channels, 256, 9, stride=1, padding=1),
                nn.ReLU(),
                nn.BatchNorm2d(256),
                nn.MaxPool2d(3, 3),
                nn.Conv2d(256, 256, (4, 3), stride=1, padding=1),
                nn.ReLU(),
                nn.BatchNorm2d(256))
        
        self.linear = nn.Linear(3328, 256)
        self.bn1 = nn.BatchNorm1d(256)
        self.rnn = Bidirectional(256, 1024, output+1)

    def forward(self, X, y=None, criterion = None):
        out = self.cnn(X)
        N, C, w, h = out.size()
        out = out.view(N, -1, h)
        out = out.permute(0, 2, 1)
        out = self.linear(out)

        out = out.permute(1, 0, 2)
        out = self.rnn(out)
            
        if y is not None:
            T = out.size(0)
            N = out.size(1)
        
            input_lengths = torch.full(size=(N,), fill_value=T, dtype=torch.int32)
            target_lengths = torch.full(size=(N,), fill_value=6, dtype=torch.int32)
        
            loss = criterion(out, y, input_lengths, target_lengths)
            
            return out, loss
        
        return out, None
    
    def _ConvLayer(self, inp, out, kernel, stride, padding, bn=False):
        if bn:
            conv = [
                nn.Conv2d(inp, out, kernel, stride=stride, padding=padding),
                nn.ReLU(),
                nn.BatchNorm2d(out)
            ]
        else:
            conv = [
                nn.Conv2d(inp, out, kernel, stride=stride, padding=padding),
                nn.ReLU()
            ]
        return nn.Sequential(*conv)

# %%
class Engine:
    def __init__(self, model, optimizer, criterion, epochs=30, early_stop=False, device='cpu'):
        self.model = model
        self.optimizer = optimizer
        self.criterion = criterion
        self.epochs = epochs
        self.early_stop = early_stop
        self.device = device
        
    def fit(self, dataloader):
        hist_loss = []
        for epoch in range(self.epochs):
            self.model.train()
            tk = tqdm(dataloader, total=len(dataloader))
            for data, target in tk:
                data = data.to(device=self.device)
                target = target.to(device=self.device)

                self.optimizer.zero_grad()

                out, loss = self.model(data, target, criterion=self.criterion)

                loss.backward()

                self.optimizer.step()


                tk.set_postfix({'Epoch':epoch+1, 'Loss' : loss.item()})
                
    def evaluate(self, dataloader):
        self.model.eval()
        loss = 0
        hist_loss = []
        outs = collections.defaultdict(list)
        tk = tqdm(dataloader, total=len(dataloader))
        with torch.no_grad():
            for data, target in tk:
                data = data.to(device=self.device)
                target = target.to(device=self.device)

                out, loss = self.model(data, target, criterion=self.criterion)
               
                target=target.cpu().detach().numpy()
                outs['pred'].append(out)
                outs['target'].append(target)


                hist_loss.append(loss)

                tk.set_postfix({'Loss':loss.item()})
                
        return outs, hist_loss
    
    def predict(self, image):
        image = Image.open(image).convert('L')
        image_tensor = T.ToTensor()(image)
        image_tensor = image_tensor.unsqueeze(0)        
        out, _ = self.model(image_tensor.to(device=self.device))
        out = out.permute(1, 0, 2)
        out = out.log_softmax(2)
        out = out.argmax(2)
        out = out.cpu().detach().numpy()
        
        return out

# %%
model = CRNN(in_channels=1, output=num_class).to(DEVICE)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.CTCLoss()

engine = Engine(model, optimizer, criterion, device=DEVICE)

# %%
engine.fit(train_loader)
outs, loss = engine.evaluate(test_loader)
# Out:
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.41it/s, Epoch=1, Loss=5.98]
# 100%|█████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.50it/s, Epoch=2, Loss=6.3]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.46it/s, Epoch=3, Loss=6.31]
# 100%|█████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.43it/s, Epoch=4, Loss=6.3]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.35it/s, Epoch=5, Loss=6.29]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.33it/s, Epoch=6, Loss=6.32]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.22it/s, Epoch=7, Loss=6.33]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.28it/s, Epoch=8, Loss=6.31]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.27it/s, Epoch=9, Loss=6.27]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.25it/s, Epoch=10, Loss=6.34]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.23it/s, Epoch=11, Loss=6.25]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.21it/s, Epoch=12, Loss=6.34]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.20it/s, Epoch=13, Loss=5.72]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.16it/s, Epoch=14, Loss=5.95]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.13it/s, Epoch=15, Loss=5.23]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.15it/s, Epoch=16, Loss=2.28]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.12it/s, Epoch=17, Loss=0.813]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.01it/s, Epoch=18, Loss=0.481]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.12it/s, Epoch=19, Loss=0.411]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.00it/s, Epoch=20, Loss=0.363]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.09it/s, Epoch=21, Loss=0.131]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 23.88it/s, Epoch=22, Loss=0.166]
# 100%|████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.02it/s, Epoch=23, Loss=-0.0306]
# 100%|█████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 23.99it/s, Epoch=24, Loss=0.0838]
# 100%|█████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.04it/s, Epoch=25, Loss=0.0136]
# 100%|█████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 23.94it/s, Epoch=26, Loss=0.0253]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 23.90it/s, Epoch=27, Loss=0.172]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 23.87it/s, Epoch=28, Loss=0.109]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 23.88it/s, Epoch=29, Loss=-0.1]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 23.87it/s, Epoch=30, Loss=0.154]
# 100%|██████████████████████████████████████████████████████████████████| 250/250 [00:03<00:00, 73.36it/s, Loss=-0.0218]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties

# 指定中文字体文件的路径
font_path = "F:\\project\\python\\OCR\\Recognize\\Gen\\font\\SimHei.ttf"  # 替换成你的中文字体文件路径

# 加载中文字体
myfont = FontProperties(fname=font_path)

ids = np.random.randint(len(data))

image = data[ids]
out = engine.predict(image)[0]

def show_prediction(out, image):
    gt = image.split('/')[-1].split('.')[0]
    imagePIL = Image.open(image).convert('L')

    pred = ''
    then = 0
    for x in out:
        if then != x:
            if x > 0 :
                pred += mapping_inv[x]
        then = x

    plt.figure(figsize=(15, 12))
    img_array = np.asarray(imagePIL)
    plt.title(f'Ground Truth - {gt} || Prediction - {pred}',fontproperties=myfont)
    plt.axis('off')
    plt.imshow(img_array,cmap='gray')
    
show_prediction(out, image)

# %%
saving = {'state_dict':engine.model.state_dict(),
          'optimizer':engine.optimizer.state_dict(),
         'mapping':mapping,
         'mapping_inv':mapping_inv}
torch.save(saving, './model/diffnum_chinese_model.pth')
