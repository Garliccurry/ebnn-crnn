# %%
# -*- coding: utf-8 -*-
import os
import glob 
import pandas as pd
import string
import collections
from tqdm import tqdm
from PIL import Image
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
from torch.utils.data import DataLoader
import torch.optim as optim
from Gen.chinese_data import common_chinese_chars

# %%
data = glob.glob(os.path.join(r'F:\project\python\OCR\Recognize\data\chinese\num5size40font3', '*.png'))
path = r'F:\project\python\OCR\Recognize\data\chinese\num5size40font3'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
DEVICE
# Out:
# device(type='cuda')

# %%
all_letters = common_chinese_chars
mapping = {}
mapping_inv = {}
i = 1
for x in all_letters:
    mapping[x] = i
    mapping_inv[i] = x
    i += 1

# %%
num_class = len(mapping)

# %%
mapping
# Out:
# {'的': 1,
#  '一': 2,
#  '是': 3,
#  '了': 4,
#  '我': 5,
#  '不': 6,
#  '在': 7,
#  '人': 8,
#  '们': 9,
#  '有': 10,
#  '来': 11,
#  '他': 12,
#  '这': 13,
#  '上': 14,
#  '着': 15,
#  '个': 16,
#  '为': 17,
#  '到': 18,
#  '说': 19,
#  '要': 20,
#  '就': 21,
#  '出': 22,
#  '会': 23,
#  '可': 24,
#  '也': 25,
#  '你': 26,
#  '对': 27,
#  '生': 28,
#  '能': 29,
#  '而': 30,
#  '子': 31,
#  '那': 32,
#  '得': 33,
#  '于': 34,
#  '下': 35,
#  '自': 36,
#  '之': 37,
#  '年': 38,
#  '过': 39,
#  '发': 40,
#  '后': 41,
#  '作': 42,
#  '里': 43,
#  '用': 44,
#  '道': 45,
#  '行': 46,
#  '所': 47,
#  '然': 48,
#  '家': 49,
#  '种': 50,
#  '事': 51,
#  '成': 52,
#  '方': 53,
#  '多': 54,
#  '经': 55,
#  '么': 56,
#  '去': 57,
#  '法': 58,
#  '学': 59,
#  '如': 60,
#  '都': 61,
#  '同': 62,
#  '现': 63,
#  '当': 64,
#  '没': 65,
#  '动': 66,
#  '面': 67,
#  '起': 68,
#  '看': 69,
#  '定': 70,
#  '天': 71,
#  '分': 72,
#  '还': 73,
#  '进': 74,
#  '好': 75,
#  '小': 76,
#  '部': 77,
#  '其': 78,
#  '些': 79,
#  '主': 80,
#  '样': 81,
#  '理': 82,
#  '心': 83,
#  '她': 84,
#  '本': 85,
#  '前': 86,
#  '开': 87,
#  '但': 88,
#  '因': 89,
#  '只': 90,
#  '从': 91,
#  '想': 92,
#  '实': 93,
#  '日': 94,
#  '军': 95,
#  '者': 96,
#  '意': 97,
#  '无': 98,
#  '力': 99,
#  '它': 100,
#  '与': 101,
#  '长': 102,
#  '把': 103,
#  '机': 104,
#  '十': 105,
#  '民': 106,
#  '第': 107,
#  '公': 108,
#  '此': 109,
#  '已': 110,
#  '工': 111,
#  '使': 112,
#  '情': 113,
#  '明': 114,
#  '性': 115,
#  '知': 116,
#  '全': 117,
#  '三': 118,
#  '又': 119,
#  '关': 120,
#  '点': 121,
#  '正': 122,
#  '业': 123,
#  '外': 124,
#  '将': 125,
#  '两': 126,
#  '高': 127,
#  '间': 128,
#  '由': 129,
#  '问': 130,
#  '很': 131,
#  '最': 132,
#  '重': 133,
#  '并': 134,
#  '物': 135,
#  '手': 136,
#  '应': 137,
#  '战': 138,
#  '向': 139,
#  '头': 140,
#  '文': 141,
#  '体': 142,
#  '政': 143,
#  '美': 144,
#  '相': 145,
#  '见': 146,
#  '被': 147,
#  '利': 148,
#  '什': 149,
#  '二': 150,
#  '等': 151,
#  '产': 152,
#  '或': 153,
#  '新': 154,
#  '己': 155,
#  '制': 156,
#  '身': 157,
#  '果': 158,
#  '加': 159,
#  '西': 160,
#  '斯': 161,
#  '月': 162,
#  '话': 163,
#  '合': 164,
#  '回': 165,
#  '特': 166,
#  '代': 167,
#  '内': 168,
#  '信': 169,
#  '表': 170,
#  '化': 171,
#  '老': 172,
#  '给': 173,
#  '世': 174,
#  '位': 175,
#  '次': 176,
#  '度': 177,
#  '门': 178,
#  '任': 179,
#  '常': 180,
#  '先': 181,
#  '海': 182,
#  '通': 183,
#  '教': 184,
#  '儿': 185,
#  '原': 186,
#  '东': 187,
#  '声': 188,
#  '提': 189,
#  '立': 190,
#  '及': 191,
#  '比': 192,
#  '员': 193,
#  '解': 194,
#  '水': 195,
#  '名': 196,
#  '真': 197,
#  '论': 198,
#  '处': 199,
#  '走': 200,
#  '义': 201,
#  '各': 202,
#  '入': 203,
#  '几': 204,
#  '口': 205,
#  '认': 206,
#  '条': 207,
#  '平': 208,
#  '系': 209,
#  '气': 210,
#  '题': 211,
#  '活': 212,
#  '尔': 213,
#  '更': 214,
#  '别': 215,
#  '打': 216,
#  '女': 217,
#  '变': 218,
#  '四': 219,
#  '神': 220,
#  '总': 221,
#  '何': 222,
#  '电': 223,
#  '数': 224,
#  '安': 225,
#  '少': 226,
#  '报': 227,
#  '才': 228,
#  '结': 229,
#  '反': 230,
#  '受': 231,
#  '目': 232,
#  '太': 233,
#  '量': 234,
#  '再': 235,
#  '感': 236,
#  '建': 237,
#  '务': 238,
#  '做': 239,
#  '接': 240,
#  '必': 241,
#  '场': 242,
#  '件': 243,
#  '计': 244,
#  '管': 245,
#  '期': 246,
#  '市': 247,
#  '直': 248,
#  '德': 249,
#  '资': 250,
#  '命': 251,
#  '山': 252,
#  '金': 253,
#  '指': 254,
#  '克': 255,
#  '许': 256,
#  '统': 257,
#  '区': 258,
#  '保': 259,
#  '至': 260,
#  '队': 261,
#  '形': 262,
#  '社': 263,
#  '便': 264,
#  '空': 265,
#  '决': 266,
#  '治': 267,
#  '展': 268,
#  '马': 269,
#  '科': 270,
#  '司': 271,
#  '五': 272,
#  '基': 273,
#  '眼': 274,
#  '书': 275,
#  '非': 276,
#  '则': 277,
#  '听': 278,
#  '白': 279,
#  '却': 280,
#  '界': 281,
#  '达': 282,
#  '光': 283,
#  '放': 284,
#  '强': 285,
#  '即': 286,
#  '像': 287,
#  '难': 288,
#  '且': 289,
#  '权': 290,
#  '思': 291,
#  '王': 292,
#  '象': 293,
#  '完': 294,
#  '设': 295,
#  '式': 296,
#  '色': 297,
#  '路': 298,
#  '记': 299,
#  '南': 300,
#  '品': 301,
#  '住': 302,
#  '告': 303,
#  '类': 304,
#  '求': 305,
#  '据': 306,
#  '程': 307,
#  '北': 308,
#  '边': 309,
#  '死': 310,
#  '张': 311,
#  '该': 312,
#  '交': 313,
#  '规': 314,
#  '万': 315,
#  '取': 316,
#  '拉': 317,
#  '格': 318,
#  '望': 319,
#  '觉': 320,
#  '术': 321,
#  '领': 322,
#  '共': 323,
#  '确': 324,
#  '传': 325,
#  '师': 326,
#  '观': 327,
#  '清': 328,
#  '今': 329,
#  '切': 330,
#  '院': 331,
#  '让': 332,
#  '识': 333,
#  '候': 334,
#  '带': 335,
#  '导': 336,
#  '争': 337,
#  '运': 338,
#  '笑': 339,
#  '飞': 340,
#  '风': 341,
#  '步': 342,
#  '改': 343,
#  '收': 344,
#  '根': 345,
#  '干': 346,
#  '造': 347,
#  '言': 348,
#  '联': 349,
#  '持': 350,
#  '组': 351,
#  '每': 352,
#  '济': 353,
#  '车': 354,
#  '亲': 355,
#  '极': 356,
#  '林': 357,
#  '服': 358,
#  '快': 359,
#  '办': 360,
#  '议': 361,
#  '往': 362,
#  '元': 363,
#  '英': 364,
#  '士': 365,
#  '证': 366,
#  '近': 367,
#  '律': 368,
#  '般': 369,
#  '尼': 370,
#  '构': 371,
#  '影': 372,
#  '层': 373,
#  '器': 374,
#  '效': 375,
#  '调': 376,
#  '团': 377,
#  '研': 378,
#  '超': 379,
#  '帮': 380,
#  '置': 381,
#  '积': 382,
#  '整': 383,
#  '罗': 384,
#  '参': 385,
#  '备': 386,
#  '维': 387,
#  '础': 388,
#  '值': 389,
#  '温': 390,
#  '落': 391,
#  '职': 392,
#  '流': 393,
#  '连': 394,
#  '镇': 395,
#  '互': 396,
#  '较': 397,
#  '华': 398,
#  '显': 399,
#  '刚': 400,
#  '标': 401,
#  '准': 402,
#  '攻': 403,
#  '推': 404,
#  '施': 405,
#  '究': 406,
#  '扩': 407}

# %%
mapping_inv
# Out:
# {1: '的',
#  2: '一',
#  3: '是',
#  4: '了',
#  5: '我',
#  6: '不',
#  7: '在',
#  8: '人',
#  9: '们',
#  10: '有',
#  11: '来',
#  12: '他',
#  13: '这',
#  14: '上',
#  15: '着',
#  16: '个',
#  17: '为',
#  18: '到',
#  19: '说',
#  20: '要',
#  21: '就',
#  22: '出',
#  23: '会',
#  24: '可',
#  25: '也',
#  26: '你',
#  27: '对',
#  28: '生',
#  29: '能',
#  30: '而',
#  31: '子',
#  32: '那',
#  33: '得',
#  34: '于',
#  35: '下',
#  36: '自',
#  37: '之',
#  38: '年',
#  39: '过',
#  40: '发',
#  41: '后',
#  42: '作',
#  43: '里',
#  44: '用',
#  45: '道',
#  46: '行',
#  47: '所',
#  48: '然',
#  49: '家',
#  50: '种',
#  51: '事',
#  52: '成',
#  53: '方',
#  54: '多',
#  55: '经',
#  56: '么',
#  57: '去',
#  58: '法',
#  59: '学',
#  60: '如',
#  61: '都',
#  62: '同',
#  63: '现',
#  64: '当',
#  65: '没',
#  66: '动',
#  67: '面',
#  68: '起',
#  69: '看',
#  70: '定',
#  71: '天',
#  72: '分',
#  73: '还',
#  74: '进',
#  75: '好',
#  76: '小',
#  77: '部',
#  78: '其',
#  79: '些',
#  80: '主',
#  81: '样',
#  82: '理',
#  83: '心',
#  84: '她',
#  85: '本',
#  86: '前',
#  87: '开',
#  88: '但',
#  89: '因',
#  90: '只',
#  91: '从',
#  92: '想',
#  93: '实',
#  94: '日',
#  95: '军',
#  96: '者',
#  97: '意',
#  98: '无',
#  99: '力',
#  100: '它',
#  101: '与',
#  102: '长',
#  103: '把',
#  104: '机',
#  105: '十',
#  106: '民',
#  107: '第',
#  108: '公',
#  109: '此',
#  110: '已',
#  111: '工',
#  112: '使',
#  113: '情',
#  114: '明',
#  115: '性',
#  116: '知',
#  117: '全',
#  118: '三',
#  119: '又',
#  120: '关',
#  121: '点',
#  122: '正',
#  123: '业',
#  124: '外',
#  125: '将',
#  126: '两',
#  127: '高',
#  128: '间',
#  129: '由',
#  130: '问',
#  131: '很',
#  132: '最',
#  133: '重',
#  134: '并',
#  135: '物',
#  136: '手',
#  137: '应',
#  138: '战',
#  139: '向',
#  140: '头',
#  141: '文',
#  142: '体',
#  143: '政',
#  144: '美',
#  145: '相',
#  146: '见',
#  147: '被',
#  148: '利',
#  149: '什',
#  150: '二',
#  151: '等',
#  152: '产',
#  153: '或',
#  154: '新',
#  155: '己',
#  156: '制',
#  157: '身',
#  158: '果',
#  159: '加',
#  160: '西',
#  161: '斯',
#  162: '月',
#  163: '话',
#  164: '合',
#  165: '回',
#  166: '特',
#  167: '代',
#  168: '内',
#  169: '信',
#  170: '表',
#  171: '化',
#  172: '老',
#  173: '给',
#  174: '世',
#  175: '位',
#  176: '次',
#  177: '度',
#  178: '门',
#  179: '任',
#  180: '常',
#  181: '先',
#  182: '海',
#  183: '通',
#  184: '教',
#  185: '儿',
#  186: '原',
#  187: '东',
#  188: '声',
#  189: '提',
#  190: '立',
#  191: '及',
#  192: '比',
#  193: '员',
#  194: '解',
#  195: '水',
#  196: '名',
#  197: '真',
#  198: '论',
#  199: '处',
#  200: '走',
#  201: '义',
#  202: '各',
#  203: '入',
#  204: '几',
#  205: '口',
#  206: '认',
#  207: '条',
#  208: '平',
#  209: '系',
#  210: '气',
#  211: '题',
#  212: '活',
#  213: '尔',
#  214: '更',
#  215: '别',
#  216: '打',
#  217: '女',
#  218: '变',
#  219: '四',
#  220: '神',
#  221: '总',
#  222: '何',
#  223: '电',
#  224: '数',
#  225: '安',
#  226: '少',
#  227: '报',
#  228: '才',
#  229: '结',
#  230: '反',
#  231: '受',
#  232: '目',
#  233: '太',
#  234: '量',
#  235: '再',
#  236: '感',
#  237: '建',
#  238: '务',
#  239: '做',
#  240: '接',
#  241: '必',
#  242: '场',
#  243: '件',
#  244: '计',
#  245: '管',
#  246: '期',
#  247: '市',
#  248: '直',
#  249: '德',
#  250: '资',
#  251: '命',
#  252: '山',
#  253: '金',
#  254: '指',
#  255: '克',
#  256: '许',
#  257: '统',
#  258: '区',
#  259: '保',
#  260: '至',
#  261: '队',
#  262: '形',
#  263: '社',
#  264: '便',
#  265: '空',
#  266: '决',
#  267: '治',
#  268: '展',
#  269: '马',
#  270: '科',
#  271: '司',
#  272: '五',
#  273: '基',
#  274: '眼',
#  275: '书',
#  276: '非',
#  277: '则',
#  278: '听',
#  279: '白',
#  280: '却',
#  281: '界',
#  282: '达',
#  283: '光',
#  284: '放',
#  285: '强',
#  286: '即',
#  287: '像',
#  288: '难',
#  289: '且',
#  290: '权',
#  291: '思',
#  292: '王',
#  293: '象',
#  294: '完',
#  295: '设',
#  296: '式',
#  297: '色',
#  298: '路',
#  299: '记',
#  300: '南',
#  301: '品',
#  302: '住',
#  303: '告',
#  304: '类',
#  305: '求',
#  306: '据',
#  307: '程',
#  308: '北',
#  309: '边',
#  310: '死',
#  311: '张',
#  312: '该',
#  313: '交',
#  314: '规',
#  315: '万',
#  316: '取',
#  317: '拉',
#  318: '格',
#  319: '望',
#  320: '觉',
#  321: '术',
#  322: '领',
#  323: '共',
#  324: '确',
#  325: '传',
#  326: '师',
#  327: '观',
#  328: '清',
#  329: '今',
#  330: '切',
#  331: '院',
#  332: '让',
#  333: '识',
#  334: '候',
#  335: '带',
#  336: '导',
#  337: '争',
#  338: '运',
#  339: '笑',
#  340: '飞',
#  341: '风',
#  342: '步',
#  343: '改',
#  344: '收',
#  345: '根',
#  346: '干',
#  347: '造',
#  348: '言',
#  349: '联',
#  350: '持',
#  351: '组',
#  352: '每',
#  353: '济',
#  354: '车',
#  355: '亲',
#  356: '极',
#  357: '林',
#  358: '服',
#  359: '快',
#  360: '办',
#  361: '议',
#  362: '往',
#  363: '元',
#  364: '英',
#  365: '士',
#  366: '证',
#  367: '近',
#  368: '律',
#  369: '般',
#  370: '尼',
#  371: '构',
#  372: '影',
#  373: '层',
#  374: '器',
#  375: '效',
#  376: '调',
#  377: '团',
#  378: '研',
#  379: '超',
#  380: '帮',
#  381: '置',
#  382: '积',
#  383: '整',
#  384: '罗',
#  385: '参',
#  386: '备',
#  387: '维',
#  388: '础',
#  389: '值',
#  390: '温',
#  391: '落',
#  392: '职',
#  393: '流',
#  394: '连',
#  395: '镇',
#  396: '互',
#  397: '较',
#  398: '华',
#  399: '显',
#  400: '刚',
#  401: '标',
#  402: '准',
#  403: '攻',
#  404: '推',
#  405: '施',
#  406: '究',
#  407: '扩'}

# %%
images = []
labels = []
datas = collections.defaultdict(list)
for d in data:
    x = d.split('\\')[-1]

    datas['image'].append(x)

    datas['label'].append([mapping[i] for i in x.split('.')[0]])
df = pd.DataFrame(datas)
df.head()
# Out:
#        image                    label
# 0  一今改该步.png  [2, 329, 343, 312, 342]
# 1  一但总律或.png   [2, 88, 221, 368, 153]
# 2  一作后及北.png    [2, 42, 41, 191, 308]
# 3  一入比导领.png  [2, 203, 192, 336, 322]
# 4  一再英内帮.png  [2, 235, 364, 168, 380]

# %%
datas
# Out:
# defaultdict(list,
#             {'image': ['一今改该步.png',
#               '一但总律或.png',
#               '一作后及北.png',
#               '一入比导领.png',
#               '一再英内帮.png',
#               '一南般难区.png',
#               '一却笑十头.png',
#               '一又外目打.png',
#               '一及公很手.png',
#               '一德走所识.png',
#               '一文社分由.png',
#               '一方会积运.png',
#               '一期因尔干.png',
#               '一看变住口.png',
#               '一神强又名.png',
#               '一资元神特.png',
#               '一还在权神.png',
#               '一那并连要.png',
#               '一非说外方.png',
#               '一马极东司.png',
#               '万且识被确.png',
#               '万业量处要.png',
#               '万事死设么.png',
#               '万会信年等.png',
#               '万传期作她.png',
#               '万信今间三.png',
#               '万候子少法.png',
#               '万元处安什.png',
#               '万全院设结.png',
#               '万决当拉起.png',
#               '万化或去认.png',
#               '万同影色术.png',
#               '万命程报改.png',
#               '万回个利统.png',
#               '万在色格员.png',
#               '万导社意过.png',
#               '万常当又带.png',
#               '万把气标好.png',
#               '万斯济但儿.png',
#               '万服在并行.png',
#               '万格当平则.png',
#               '万正区边导.png',
#               '万步究队组.png',
#               '万每主美光.png',
#               '万流统界告.png',
#               '万王义过有.png',
#               '万着切或内.png',
#               '万程强公象.png',
#               '万究什车表.png',
#               '万色界高很.png',
#               '万西领进山.png',
#               '万说或个好.png',
#               '三之记德美.png',
#               '三也听领飞.png',
#               '三代果形总.png',
#               '三刚各做度.png',
#               '三力己连无.png',
#               '三听院式世.png',
#               '三回再五帮.png',
#               '三回战心科.png',
#               '三备关很规.png',
#               '三备度放少.png',
#               '三导水候气.png',
#               '三小元关比.png',
#               '三开性统最.png',
#               '三必领解市.png',
#               '三或传民据.png',
#               '三所万原而.png',
#               '三手光我月.png',
#               '三提代业外.png',
#               '三教四权十.png',
#               '三月觉之南.png',
#               '三望由确题.png',
#               '三要各与天.png',
#               '三议证作间.png',
#               '三调人调组.png',
#               '三资性命在.png',
#               '三运山元多.png',
#               '上值张走到.png',
#               '上元信因路.png',
#               '上十山无及.png',
#               '上受教量民.png',
#               '上如记决总.png',
#               '上子将落对.png',
#               '上对区理万.png',
#               '上干长镇都.png',
#               '上张是入那.png',
#               '上强如安许.png',
#               '上性步究想.png',
#               '上打所成还.png',
#               '上显都改高.png',
#               '上最华此利.png',
#               '上条去利队.png',
#               '上点是重名.png',
#               '上然因前温.png',
#               '上路业看种.png',
#               '上边清神难.png',
#               '上金公世如.png',
#               '上金比听资.png',
#               '上镇出五标.png',
#               '上院机三车.png',
#               '上题点点究.png',
#               '下不近得根.png',
#               '下世或准至.png',
#               '下之说好而.png',
#               '下事光文性.png',
#               '下几切产重.png',
#               '下四发性得.png',
#               '下士所世别.png',
#               '下将前效定.png',
#               '下小点西别.png',
#               '下平色期目.png',
#               '下应整资公.png',
#               '下建风看原.png',
#               '下很直你直.png',
#               '下必部王共.png',
#               '下思度放能.png',
#               '下情克名元.png',
#               '下林也后么.png',
#               '下现德常士.png',
#               '下眼一回观.png',
#               '下统实能你.png',
#               '下难干反金.png',
#               '不使无安罗.png',
#               '不全五现马.png',
#               '不刚影身帮.png',
#               '不参器已化.png',
#               '不因于得或.png',
#               '不处至由且.png',
#               '不安天且他.png',
#               '不感研根个.png',
#               '不方流路南.png',
#               '不有被万个.png',
#               '不果内几多.png',
#               '不每构立管.png',
#               '不相无张观.png',
#               '不笑更这东.png',
#               '不自还加许.png',
#               '不表加形究.png',
#               '不量较见会.png',
#               '不金今死调.png',
#               '不队制何经.png',
#               '不题新什上.png',
#               '不飞想利世.png',
#               '与上化重服.png',
#               '与也空解成.png',
#               '与书上至教.png',
#               '与到能识们.png',
#               '与华总之都.png',
#               '与及飞司领.png',
#               '与口共明力.png',
#               '与司备许是.png',
#               '与外安话真.png',
#               '与如收必得.png',
#               '与定几立各.png',
#               '与干相如走.png',
#               '与律高加别.png',
#               '与我与受层.png',
#               '与果什为位.png',
#               '与确服较己.png',
#               '与般自力员.png',
#               '且东人下别.png',
#               '且之性提其.png',
#               '且位本说利.png',
#               '且使超参工.png',
#               '且出军处形.png',
#               '且声职作整.png',
#               '且导师制主.png',
#               '且常变本联.png',
#               '且平第性职.png',
#               '且总金想儿.png',
#               '且或水光求.png',
#               '且是分月亲.png',
#               '且海路基告.png',
#               '且生师话月.png',
#               '且种尼器往.png',
#               '且被次做镇.png',
#               '且西指题长.png',
#               '且调产入从.png',
#               '且连及多表.png',
#               '且道互济将.png',
#               '且金上但说.png',
#               '世争公置路.png',
#               '世什完水作.png',
#               '世任马好造.png',
#               '世便程互觉.png',
#               '世保位本是.png',
#               '世保权决眼.png',
#               '世光师眼头.png',
#               '世切次入拉.png',
#               '世则员车攻.png',
#               '世务我导今.png',
#               '世区治根立.png',
#               '世十切同门.png',
#               '世发力步打.png',
#               '世太决受命.png',
#               '世头住望打.png',
#               '世就基义神.png',
#               '世平门证从.png',
#               '世律共一思.png',
#               '世成身新种.png',
#               '世拉空元过.png',
#               '世接开来器.png',
#               '世教据四等.png',
#               '世日死点制.png',
#               '世服品基非.png',
#               '世服此物何.png',
#               '世极体司民.png',
#               '世林身通水.png',
#               '世正次影要.png',
#               '世水构知意.png',
#               '世活西此保.png',
#               '世科别许上.png',
#               '世等界比的.png',
#               '世行太本走.png',
#               '世证果被镇.png',
#               '世长一回而.png',
#               '世门新马导.png',
#               '业一头识间.png',
#               '业之解罗万.png',
#               '业也感工头.png',
#               '业产连自科.png',
#               '业何便感可.png',
#               '业公作神话.png',
#               '业军下类女.png',
#               '业务士道性.png',
#               '业后难一日.png',
#               '业四西去电.png',
#               '业在天办南.png',
#               '业多面即现.png',
#               '业尼动问心.png',
#               '业建所都入.png',
#               '业据识证没.png',
#               '业方等成建.png',
#               '业更帮认当.png',
#               '业由结少所.png',
#               '业础住化术.png',
#               '业罗事也确.png',
#               '业能儿行使.png',
#               '业里民你光.png',
#               '业镇而打界.png',
#               '业院才不就.png',
#               '东也万领程.png',
#               '东书过指路.png',
#               '东像打些此.png',
#               '东关即不前.png',
#               '东动办收英.png',
#               '东发连元活.png',
#               '东口观一为.png',
#               '东命构而看.png',
#               '东器便求十.png',
#               '东器维形且.png',
#               '东团关罗公.png',
#               '东天行团物.png',
#               '东帮却斯刚.png',
#               '东把构整件.png',
#               '东真认所学.png',
#               '东社联觉第.png',
#               '东程程电处.png',
#               '东维张何最.png',
#               '东般北进三.png',
#               '东资克言组.png',
#               '东都己超受.png',
#               '两三的每流.png',
#               '两作这要但.png',
#               '两全命空处.png',
#               '两内职传安.png',
#               '两切元建社.png',
#               '两制部难件.png',
#               '两后太美好.png',
#               '两团社备联.png',
#               '两处边院东.png',
#               '两它她眼下.png',
#               '两必持社位.png',
#               '两所种等准.png',
#               '两把提件月.png',
#               '两气西人义.png',
#               '两济下市办.png',
#               '两者种定被.png',
#               '两至记入它.png',
#               '两识出四比.png',
#               '两边主维帮.png',
#               '两边格如力.png',
#               '两运别求市.png',
#               '两这几如般.png',
#               '两那道什名.png',
#               '两里度但为.png',
#               '个业长目间.png',
#               '个使制飞二.png',
#               '个候告治切.png',
#               '个准罗还意.png',
#               '个出五眼外.png',
#               '个到合研克.png',
#               '个参边该生.png',
#               '个合身可但.png',
#               '个后想样斯.png',
#               '个员非机日.png',
#               '个四明职入.png',
#               '个头数金着.png',
#               '个子太造更.png',
#               '个学步同觉.png',
#               '个完们便分.png',
#               '个将做间上.png',
#               '个并直事笑.png',
#               '个开亲马利.png',
#               '个或张非规.png',
#               '个日车儿林.png',
#               '个本题都整.png',
#               '个机题法然.png',
#               '个比来同用.png',
#               '个水南二程.png',
#               '个现产条什.png',
#               '个管理与用.png',
#               '个统人作太.png',
#               '个职对参各.png',
#               '个落新法器.png',
#               '个见运他格.png',
#               '个许院有住.png',
#               '个那由量头.png',
#               '个领施目家.png',
#               '为不业整手.png',
#               '为且落罗无.png',
#               '为东设生道.png',
#               '为为界想有.png',
#               '为争世望么.png',
#               '为任南是己.png',
#               '为传动量看.png',
#               '为但有利正.png',
#               '为像是合建.png',
#               '为全但让飞.png',
#               '为军些现温.png',
#               '为利象解同.png',
#               '为司外施下.png',
#               '为合世争干.png',
#               '为多觉世互.png',
#               '为定显里里.png',
#               '为对完南然.png',
#               '为对清式求.png',
#               '为山品风师.png',
#               '为带应道听.png',
#               '为斯少切流.png',
#               '为极最听他.png',
#               '为活确计如.png',
#               '为温常资尔.png',
#               '为直来计位.png',
#               '为础边英气.png',
#               '为英战山西.png',
#               '为言四其师.png',
#               '为造确求司.png',
#               '主两济利王.png',
#               '主们告利学.png',
#               '主先达根将.png',
#               '主其能施市.png',
#               '主力起把近.png',
#               '主办无构你.png',
#               '主北决位攻.png',
#               '主同拉飞山.png',
#               '主声还真到.png',
#               '主女组取要.png',
#               '主小部知机.png',
#               '主工维目面.png',
#               '主得其落应.png',
#               '主性强基体.png',
#               '主改化象因.png',
#               '主整系市被.png',
#               '主标论起今.png',
#               '主民各施市.png',
#               '主界本使高.png',
#               '主识超两做.png',
#               '主门统山做.png',
#               '么下从报见.png',
#               '么今镇权路.png',
#               '么从口法于.png',
#               '么们南组话.png',
#               '么住之间作.png',
#               '么元出情带.png',
#               '么别及公次.png',
#               '么前极门学.png',
#               '么原五合完.png',
#               '么原你道当.png',
#               '么原结得进.png',
#               '么因发为有.png',
#               '么场身会光.png',
#               '么外明里区.png',
#               '么她尔方置.png',
#               '么就理术日.png',
#               '么尼争最些.png',
#               '么平维物果.png',
#               '么应保动经.png',
#               '么开证共太.png',
#               '么手别说影.png',
#               '么扩当最业.png',
#               '么整什带但.png',
#               '么日下物尔.png',
#               '么月为参相.png',
#               '么月便用件.png',
#               '么物从准互.png',
#               '么种气想现.png',
#               '么结与英员.png',
#               '么维题利完.png',
#               '么老利运物.png',
#               '么论着学间.png',
#               '么起常子这.png',
#               '么重业化指.png',
#               '么题提团在.png',
#               '义也后其才.png',
#               '义于记气向.png',
#               '义值础定全.png',
#               '义值部师见.png',
#               '义其太却职.png',
#               '义切界次尼.png',
#               '义原攻亲争.png',
#               '义反华金攻.png',
#               '义常组建持.png',
#               '义必无由干.png',
#               '义正反可被.png',
#               '义活极文般.png',
#               '义础解两所.png',
#               '义组被各已.png',
#               '义英代制四.png',
#               '义计平目路.png',
#               '义许职作条.png',
#               '义证达非识.png',
#               '义识较之究.png',
#               '之先象风安.png',
#               '之内极安年.png',
#               '之军北据手.png',
#               '之刚可还能.png',
#               '之及万觉接.png',
#               '之好原非主.png',
#               '之它取他部.png',
#               '之对落联度.png',
#               '之少总应两.png',
#               '之很却过命.png',
#               '之据业过次.png',
#               '之提种全更.png',
#               '之攻持白平.png',
#               '之斯西研超.png',
#               '之新打像真.png',
#               '之望信张题.png',
#               '之期外能政.png',
#               '之正象运帮.png',
#               '之理同决分.png',
#               '之解再管展.png',
#               '之通点头住.png',
#               '之量调业开.png',
#               '也了扩报极.png',
#               '也位造落运.png',
#               '也儿观水己.png',
#               '也光斯带被.png',
#               '也决经立体.png',
#               '也出于从路.png',
#               '也如推别每.png',
#               '也学展候术.png',
#               '也帮改用础.png',
#               '也干识知超.png',
#               '也平较主元.png',
#               '也度文他就.png',
#               '也往及种件.png',
#               '也总笑管给.png',
#               '也才部层金.png',
#               '也日身么书.png',
#               '也明服万于.png',
#               '也极太平然.png',
#               '也格些意观.png',
#               '也物年里或.png',
#               '也目者亲金.png',
#               '也着社成计.png',
#               '也空入究方.png',
#               '也给司去拉.png',
#               '也识你些者.png',
#               '也该气互东.png',
#               '也部推车是.png',
#               '也重律风研.png',
#               '书为备备天.png',
#               '书们许则应.png',
#               '书公性为德.png',
#               '书则些会温.png',
#               '书则部根步.png',
#               '书化一次场.png',
#               '书原温会了.png',
#               '书女士风律.png',
#               '书定必务极.png',
#               '书层扩不则.png',
#               '书张形车过.png',
#               '书显然斯究.png',
#               '书最如问定.png',
#               '书此好帮名.png',
#               '书每结会温.png',
#               '书流程里法.png',
#               '书清作水重.png',
#               '书生自温器.png',
#               '书能直镇度.png',
#               '书要交来便.png',
#               '书识世之意.png',
#               '书这镇施生.png',
#               '了万合指参.png',
#               '了争何机色.png',
#               '了使听社器.png',
#               '了关则己起.png',
#               '了回因切期.png',
#               '了带点西感.png',
#               '了战得候且.png',
#               '了提很却斯.png',
#               '了没力里它.png',
#               '了然德感无.png',
#               '了电建或连.png',
#               '了等电条础.png',
#               '了证度因职.png',
#               '了走员样接.png',
#               '了连说了体.png',
#               '了那教教着.png',
#               '了里要等从.png',
#               '争了边何决.png',
#               '争便清拉那.png',
#               '争尔告太办.png',
#               '争师向化觉.png',
#               '争往基民正.png',
#               '争得当多最.png',
#               '争或其克本.png',
#               '争战用提情.png',
#               '争战里天显.png',
#               '争收且管非.png',
#               '争术层些样.png',
#               '争清么边应.png',
#               '争然气物水.png',
#               '争经风业认.png',
#               '争统直明效.png',
#               '争话军超达.png',
#               '争身做去被.png',
#               '争较实立流.png',
#               '争金不点导.png',
#               '争金刚还调.png',
#               '争题等完得.png',
#               '争飞学院气.png',
#               '事世道亲解.png',
#               '事代通济进.png',
#               '事信第要非.png',
#               '事儿小然世.png',
#               '事准别式共.png',
#               '事出建攻几.png',
#               '事我对根施.png',
#               '事教点化光.png',
#               '事日十学部.png',
#               '事样工安让.png',
#               '事求完完条.png',
#               '事笑而军新.png',
#               '事给求结式.png',
#               '事觉家飞东.png',
#               '事许知元打.png',
#               '事论会认看.png',
#               '事部温是可.png',
#               '事都位因安.png',
#               '事间感候与.png',
#               '二业下过互.png',
#               '二元那提代.png',
#               '二光白么位.png',
#               '二军合极被.png',
#               '二出提白一.png',
#               '二分你提重.png',
#               '二切如特合.png',
#               '二制车前日.png',
#               '二区领主一.png',
#               '二女观的次.png',
#               '二定别张帮.png',
#               '二导候军者.png',
#               '二师工克取.png',
#               '二帮多德间.png',
#               '二心觉教观.png',
#               '二成场形方.png',
#               '二或上难先.png',
#               '二所思但认.png',
#               '二收步面内.png',
#               '二气格入林.png',
#               '二物之组决.png',
#               '二的当化日.png',
#               '二相法气器.png',
#               '二看元任及.png',
#               '二积确却书.png',
#               '二等会设然.png',
#               '二经则观超.png',
#               '二罗许手尼.png',
#               '二而多气扩.png',
#               '二联打现光.png',
#               '二般所受拉.png',
#               '二证感重员.png',
#               '二起小路女.png',
#               '二还都四直.png',
#               '二那它市更.png',
#               '于一方团眼.png',
#               '于三家各什.png',
#               '于且来团身.png',
#               '于五两互发.png',
#               '于使机何刚.png',
#               '于候去内究.png',
#               '于关数情可.png',
#               '于内也边可.png',
#               '于在展业置.png',
#               '于基在职收.png',
#               '于基清心性.png',
#               '于整构总工.png',
#               '于次快备全.png',
#               '于此斯参争.png',
#               '于者持已式.png',
#               '于至才常术.png',
#               '于说位西新.png',
#               '于高非美天.png',
#               '于高领区到.png',
#               '互争调效处.png',
#               '互位第更积.png',
#               '互作好般其.png',
#               '互切或尼指.png',
#               '互器变个根.png',
#               '互器科共应.png',
#               '互就则证究.png',
#               '互就指格连.png',
#               '互就的律己.png',
#               '互月有一制.png',
#               '互本问明必.png',
#               '互格手确个.png',
#               '互次服面报.png',
#               '互现点因万.png',
#               '互着础通告.png',
#               '互社区格立.png',
#               '互立会根标.png',
#               '互类相其都.png',
#               '互者期平外.png',
#               '互行流会好.png',
#               '互要日达入.png',
#               '五主科年器.png',
#               '五二飞管形.png',
#               '五住样连没.png',
#               '五候义年济.png',
#               '五几观话标.png',
#               '五前推服看.png',
#               '五动日教子.png',
#               '五区原原口.png',
#               '五反着来市.png',
#               '五发现系提.png',
#               '五可系值着.png',
#               '五听镇则目.png',
#               '五回两强对.png',
#               '五因值来整.png',
#               '五备给候攻.png',
#               '五如发即多.png',
#               '五尼影神更.png',
#               '五形基资过.png',
#               '五得传资务.png',
#               '五报层且资.png',
#               '五拉值会且.png',
#               '五斯对联者.png',
#               '五极交成边.png',
#               '五流带林清.png',
#               '五相事得天.png',
#               '五立出许水.png',
#               '五组团分外.png',
#               '五起飞口四.png',
#               '五造感军眼.png',
#               '五高式天色.png',
#               '些产尔边三.png',
#               '些值做社自.png',
#               '些分本东世.png',
#               '些区实身学.png',
#               '些告常像发.png',
#               '些命达信向.png',
#               '些团界先公.png',
#               '些它性合书.png',
#               '些安等便刚.png',
#               '些实团南运.png',
#               '些对过飞可.png',
#               '些并前积小.png',
#               '些张而求议.png',
#               '些想色感太.png',
#               '些把分水所.png',
#               '些指小系士.png',
#               '些提化交五.png',
#               '些改性罗的.png',
#               '些最世关再.png',
#               '些有水清据.png',
#               '些法么要交.png',
#               '些积天无风.png',
#               '些结想向干.png',
#               '些老连样认.png',
#               '些般学师常.png',
#               '些资运联则.png',
#               '些量把万路.png',
#               '交书之类说.png',
#               '交军为却子.png',
#               '交利争管五.png',
#               '交加正成情.png',
#               '交化但者长.png',
#               '交区数然重.png',
#               '交发克完样.png',
#               '交它车果施.png',
#               '交层共镇色.png',
#               '交推对声如.png',
#               '交文极头导.png',
#               '交显何刚她.png',
#               '交流安有何.png',
#               '交着系置师.png',
#               '交础望望言.png',
#               '交立从基那.png',
#               '交立别基还.png',
#               '交色小常告.png',
#               '交连进接老.png',
#               '交造全水设.png',
#               '交门共指互.png',
#               '交间重眼构.png',
#               '产下边步德.png',
#               '产代程至导.png',
#               '产华全成师.png',
#               '产各英关过.png',
#               '产员处导刚.png',
#               '产头今的位.png',
#               '产展过世电.png',
#               '产干飞少五.png',
#               '产张将扩五.png',
#               '产成非变你.png',
#               '产拉求电争.png',
#               '产方实十二.png',
#               '产林罗间关.png',
#               '产生间积界.png',
#               '产看多才里.png',
#               '产着让见同.png',
#               '产第几准神.png',
#               '产等交民认.png',
#               '产管数太间.png',
#               '产落内风都.png',
#               '产议规刚备.png',
#               '产过边电运.png',
#               '产都北观法.png',
#               '产重要平相.png',
#               '产面被发传.png',
#               '亲入马过十.png',
#               '亲士他总求.png',
#               '亲它快民往.png',
#               '亲想近调帮.png',
#               '亲清由不强.png',
#               '亲用关张眼.png',
#               '亲立场术至.png',
#               '亲美等进便.png',
#               '亲行多帮子.png',
#               '亲被系然强.png',
#               '亲觉切合一.png',
#               '亲话办职市.png',
#               '亲该间己器.png',
#               '亲高万把究.png',
#               '人交书理与.png',
#               '人产式体斯.png',
#               '人光便着常.png',
#               '人内每保前.png',
#               '人军战相来.png',
#               '人动同会刚.png',
#               '人向由其英.png',
#               '人员走子强.png',
#               '人品上过任.png',
#               '人回望光行.png',
#               '人因标华件.png',
#               '人士全尼司.png',
#               '人帮提受统.png',
#               '人强显们南.png',
#               '人很标那何.png',
#               '人情神眼记.png',
#               '人战术知又.png',
#               '人推积进种.png',
#               '人每心这话.png',
#               '人现性安可.png',
#               '人空知他放.png',
#               '人组经值说.png',
#               '人西但被研.png',
#               '人计特落再.png',
#               '人资最备如.png',
#               '人近书指海.png',
#               '人镇值常内.png',
#               '人院上的此.png',
#               '人题重让较.png',
#               '人风打边器.png',
#               '什之面后南.png',
#               '什书行罗业.png',
#               '什全相成机.png',
#               '什内太显己.png',
#               '什军点完也.png',
#               '什力今难文.png',
#               '什南层重分.png',
#               '什原象其职.png',
#               '什取观民太.png',
#               '什同笑常十.png',
#               '什团美进水.png',
#               '什声二女得.png',
#               '什少则提回.png',
#               '什往研行气.png',
#               '什打分确等.png',
#               '什报里多又.png',
#               '什收这水互.png',
#               '什方标第从.png',
#               '什根品说四.png',
#               '什民只职调.png',
#               '什物系区究.png',
#               '什界般无较.png',
#               '什知华教器.png',
#               '什空先亲想.png',
#               '什等主成做.png',
#               '什证条往变.png',
#               '什里气空真.png',
#               '什问使受业.png',
#               '什面接治完.png',
#               '今一什后战.png',
#               '今与互传新.png',
#               '今为难理部.png',
#               '今义教用会.png',
#               '今了安主经.png',
#               '今今空近色.png',
#               '今从程回权.png',
#               '今传何名组.png',
#               '今切件连这.png',
#               '今到点该点.png',
#               '今制从明从.png',
#               '今口各表战.png',
#               '今因义达代.png',
#               '今在罗飞安.png',
#               '今她如分且.png',
#               '今尔入子向.png',
#               '今提飞意它.png',
#               '今效声三不.png',
#               '今月常证四.png',
#               '今权任来发.png',
#               '今权子维传.png',
#               '今死干四成.png',
#               '今治施或死.png',
#               '今温更再像.png',
#               '今认像主战.png',
#               '今识即本什.png',
#               '今近言类种.png',
#               '今难参为此.png',
#               '从与般且还.png',
#               '从个南住上.png',
#               '从像何究建.png',
#               '从办制象准.png',
#               '从办有展干.png',
#               '从办记上格.png',
#               '从好说部资.png',
#               '从己风类们.png',
#               '从师别据极.png',
#               '从帮生别统.png',
#               '从年气声只.png',
#               '从度向性目.png',
#               '从影式将最.png',
#               '从很指影题.png',
#               '从放帮格才.png',
#               '从死意言力.png',
#               '从求学感变.png',
#               '从济师觉很.png',
#               '从清马各共.png',
#               '从理电管数.png',
#               '从解成前飞.png',
#               '从该候强只.png',
#               '从重之究告.png',
#               '他与全强会.png',
#               '他二与器全.png',
#               '他今师步多.png',
#               '他到每年话.png',
#               '他华放之方.png',
#               '他南原同想.png',
#               '他发克标英.png',
#               '他外立可极.png',
#               '他治极战果.png',
#               '他真直该形.png',
#               '他系分争山.png',
#               '他老有也分.png',
#               '他见团子维.png',
#               '他话保该死.png',
#               '他说进小究.png',
#               '他连利量清.png',
#               '他非进取先.png',
#               '代二来并体.png',
#               '代什任解受.png',
#               '代值名命研.png',
#               '代公等观少.png',
#               '代共小边职.png',
#               '代十便达攻.png',
#               '代听起女员.png',
#               '代命便年这.png',
#               '代场让利飞.png',
#               '代定且果员.png',
#               '代所加士争.png',
#               '代条方儿科.png',
#               '代根展经制.png',
#               '代现原这其.png',
#               '代确领张女.png',
#               '代组建元重.png',
#               '代维会可关.png',
#               '代置础了造.png',
#               '代职置效长.png',
#               '代行老传传.png',
#               '代表报真领.png',
#               '代里组扩工.png',
#               '们为道场扩.png',
#               '们互们战意.png',
#               '们你眼界给.png',
#               '们信职活点.png',
#               '们各下见一.png',
#               '们同多量安.png',
#               '们就从月次.png',
#               '们常资个现.png',
#               '们得期扩的.png',
#               '们成飞成水.png',
#               '们打题原原.png',
#               '们望活完据.png',
#               '们王干积许.png',
#               '们研团间动.png',
#               '们能度条数.png',
#               '们证其调很.png',
#               '们边团从议.png',
#               '们还走快长.png',
#               '们部把尔础.png',
#               '们领清度规.png',
#               '件且强计军.png',
#               '件事管影积.png',
#               '件件一但对.png',
#               '件值律持因.png',
#               '件务团者通.png',
#               '件口听数则.png',
#               '件场是四部.png',
#               '件对积后导.png',
#               '件就点女决.png',
#               '件平运内家.png',
#               '件文品放原.png',
#               '件机间基攻.png',
#               '件根边话安.png',
#               '件死车带两.png',
#               '件王攻子安.png',
#               '件电向共设.png',
#               '件种传都何.png',
#               '件笑德开度.png',
#               '件般区识一.png',
#               '件西政别后.png',
#               '件资设死器.png',
#               '件路争干前.png',
#               '件里识据很.png',
#               '件题界住十.png',
#               '件高之现往.png',
#               '任两格们气.png',
#               '任主二务员.png',
#               '任也确口打.png',
#               '任会把像东.png',
#               '任便家白权.png',
#               '任候刚会达.png',
#               '任做身动界.png',
#               '任前接本落.png',
#               '任化让活告.png',
#               '任司分尼条.png',
#               '任市只好电.png',
#               '任律想二社.png',
#               '任接让如会.png',
#               '任数品面体.png',
#               '任文没员日.png',
#               '任明务下飞.png',
#               '任机设应度.png',
#               '任权基安做.png',
#               '任正前机第.png',
#               '任水非区天.png',
#               '任求然则万.png',
#               '任眼服月定.png',
#               '任立位二相.png',
#               '任规非气安.png',
#               '任起事口镇.png',
#               '任起些记有.png',
#               '任较向回月.png',
#               '任问解共常.png',
#               '任面于定便.png',
#               '会世北快用.png',
#               '会们先维利.png',
#               '会使超教种.png',
#               '会做构效现.png',
#               '会别构象要.png',
#               '会别资先利.png',
#               '会动决道原.png',
#               '会反物器之.png',
#               '会听础目扩.png',
#               '会场者显实.png',
#               '会帮五可所.png',
#               '会推间命究.png',
#               '会提及小小.png',
#               '会攻斯并许.png',
#               '会政主机记.png',
#               '会本望置量.png',
#               '会样连性期.png',
#               '会法他统务.png',
#               '会然打力子.png',
#               '会目水管法.png',
#               '会科义么较.png',
#               '会程合交作.png',
#               '会表今那求.png',
#               '会说上基各.png',
#               '会车社由种.png',
#               '会运显这加.png',
#               '会部定学件.png',
#               '会金少分工.png',
#               '会非镇条层.png',
#               '传之收告那.png',
#               ...],
#              'label': [[2, 329, 343, 312, 342],
#               [2, 88, 221, 368, 153],
#               [2, 42, 41, 191, 308],
#               [2, 203, 192, 336, 322],
#               [2, 235, 364, 168, 380],
#               [2, 300, 369, 288, 258],
#               [2, 280, 339, 105, 140],
#               [2, 119, 124, 232, 216],
#               [2, 191, 108, 131, 136],
#               [2, 249, 200, 47, 333],
#               [2, 141, 263, 72, 129],
#               [2, 53, 23, 382, 338],
#               [2, 246, 89, 213, 346],
#               [2, 69, 218, 302, 205],
#               [2, 220, 285, 119, 196],
#               [2, 250, 363, 220, 166],
#               [2, 73, 7, 290, 220],
#               [2, 32, 134, 394, 20],
#               [2, 276, 19, 124, 53],
#               [2, 269, 356, 187, 271],
#               [315, 289, 333, 147, 324],
#               [315, 123, 234, 199, 20],
#               [315, 51, 310, 295, 56],
#               [315, 23, 169, 38, 151],
#               [315, 325, 246, 42, 84],
#               [315, 169, 329, 128, 118],
#               [315, 334, 31, 226, 58],
#               [315, 363, 199, 225, 149],
#               [315, 117, 331, 295, 229],
#               [315, 266, 64, 317, 68],
#               [315, 171, 153, 57, 206],
#               [315, 62, 372, 297, 321],
#               [315, 251, 307, 227, 343],
#               [315, 165, 16, 148, 257],
#               [315, 7, 297, 318, 193],
#               [315, 336, 263, 97, 39],
#               [315, 180, 64, 119, 335],
#               [315, 103, 210, 401, 75],
#               [315, 161, 353, 88, 185],
#               [315, 358, 7, 134, 46],
#               [315, 318, 64, 208, 277],
#               [315, 122, 258, 309, 336],
#               [315, 342, 406, 261, 351],
#               [315, 352, 80, 144, 283],
#               [315, 393, 257, 281, 303],
#               [315, 292, 201, 39, 10],
#               [315, 15, 330, 153, 168],
#               [315, 307, 285, 108, 293],
#               [315, 406, 149, 354, 170],
#               [315, 297, 281, 127, 131],
#               [315, 160, 322, 74, 252],
#               [315, 19, 153, 16, 75],
#               [118, 37, 299, 249, 144],
#               [118, 25, 278, 322, 340],
#               [118, 167, 158, 262, 221],
#               [118, 400, 202, 239, 177],
#               [118, 99, 155, 394, 98],
#               [118, 278, 331, 296, 174],
#               [118, 165, 235, 272, 380],
#               [118, 165, 138, 83, 270],
#               [118, 386, 120, 131, 314],
#               [118, 386, 177, 284, 226],
#               [118, 336, 195, 334, 210],
#               [118, 76, 363, 120, 192],
#               [118, 87, 115, 257, 132],
#               [118, 241, 322, 194, 247],
#               [118, 153, 325, 106, 306],
#               [118, 47, 315, 186, 30],
#               [118, 136, 283, 5, 162],
#               [118, 189, 167, 123, 124],
#               [118, 184, 219, 290, 105],
#               [118, 162, 320, 37, 300],
#               [118, 319, 129, 324, 211],
#               [118, 20, 202, 101, 71],
#               [118, 361, 366, 42, 128],
#               [118, 376, 8, 376, 351],
#               [118, 250, 115, 251, 7],
#               [118, 338, 252, 363, 54],
#               [14, 389, 311, 200, 18],
#               [14, 363, 169, 89, 298],
#               [14, 105, 252, 98, 191],
#               [14, 231, 184, 234, 106],
#               [14, 60, 299, 266, 221],
#               [14, 31, 125, 391, 27],
#               [14, 27, 258, 82, 315],
#               [14, 346, 102, 395, 61],
#               [14, 311, 3, 203, 32],
#               [14, 285, 60, 225, 256],
#               [14, 115, 342, 406, 92],
#               [14, 216, 47, 52, 73],
#               [14, 399, 61, 343, 127],
#               [14, 132, 398, 109, 148],
#               [14, 207, 57, 148, 261],
#               [14, 121, 3, 133, 196],
#               [14, 48, 89, 86, 390],
#               [14, 298, 123, 69, 50],
#               [14, 309, 328, 220, 288],
#               [14, 253, 108, 174, 60],
#               [14, 253, 192, 278, 250],
#               [14, 395, 22, 272, 401],
#               [14, 331, 104, 118, 354],
#               [14, 211, 121, 121, 406],
#               [35, 6, 367, 33, 345],
#               [35, 174, 153, 402, 260],
#               [35, 37, 19, 75, 30],
#               [35, 51, 283, 141, 115],
#               [35, 204, 330, 152, 133],
#               [35, 219, 40, 115, 33],
#               [35, 365, 47, 174, 215],
#               [35, 125, 86, 375, 70],
#               [35, 76, 121, 160, 215],
#               [35, 208, 297, 246, 232],
#               [35, 137, 383, 250, 108],
#               [35, 237, 341, 69, 186],
#               [35, 131, 248, 26, 248],
#               [35, 241, 77, 292, 323],
#               [35, 291, 177, 284, 29],
#               [35, 113, 255, 196, 363],
#               [35, 357, 25, 41, 56],
#               [35, 63, 249, 180, 365],
#               [35, 274, 2, 165, 327],
#               [35, 257, 93, 29, 26],
#               [35, 288, 346, 230, 253],
#               [6, 112, 98, 225, 384],
#               [6, 117, 272, 63, 269],
#               [6, 400, 372, 157, 380],
#               [6, 385, 374, 110, 171],
#               [6, 89, 34, 33, 153],
#               [6, 199, 260, 129, 289],
#               [6, 225, 71, 289, 12],
#               [6, 236, 378, 345, 16],
#               [6, 53, 393, 298, 300],
#               [6, 10, 147, 315, 16],
#               [6, 158, 168, 204, 54],
#               [6, 352, 371, 190, 245],
#               [6, 145, 98, 311, 327],
#               [6, 339, 214, 13, 187],
#               [6, 36, 73, 159, 256],
#               [6, 170, 159, 262, 406],
#               [6, 234, 397, 146, 23],
#               [6, 253, 329, 310, 376],
#               [6, 261, 156, 222, 55],
#               [6, 211, 154, 149, 14],
#               [6, 340, 92, 148, 174],
#               [101, 14, 171, 133, 358],
#               [101, 25, 265, 194, 52],
#               [101, 275, 14, 260, 184],
#               [101, 18, 29, 333, 9],
#               [101, 398, 221, 37, 61],
#               [101, 191, 340, 271, 322],
#               [101, 205, 323, 114, 99],
#               [101, 271, 386, 256, 3],
#               [101, 124, 225, 163, 197],
#               [101, 60, 344, 241, 33],
#               [101, 70, 204, 190, 202],
#               [101, 346, 145, 60, 200],
#               [101, 368, 127, 159, 215],
#               [101, 5, 101, 231, 373],
#               [101, 158, 149, 17, 175],
#               [101, 324, 358, 397, 155],
#               [101, 369, 36, 99, 193],
#               [289, 187, 8, 35, 215],
#               [289, 37, 115, 189, 78],
#               [289, 175, 85, 19, 148],
#               [289, 112, 379, 385, 111],
#               [289, 22, 95, 199, 262],
#               [289, 188, 392, 42, 383],
#               [289, 336, 326, 156, 80],
#               [289, 180, 218, 85, 349],
#               [289, 208, 107, 115, 392],
#               [289, 221, 253, 92, 185],
#               [289, 153, 195, 283, 305],
#               [289, 3, 72, 162, 355],
#               [289, 182, 298, 273, 303],
#               [289, 28, 326, 163, 162],
#               [289, 50, 370, 374, 362],
#               [289, 147, 176, 239, 395],
#               [289, 160, 254, 211, 102],
#               [289, 376, 152, 203, 91],
#               [289, 394, 191, 54, 170],
#               [289, 45, 396, 353, 125],
#               [289, 253, 14, 88, 19],
#               [174, 337, 108, 381, 298],
#               [174, 149, 294, 195, 42],
#               [174, 179, 269, 75, 347],
#               [174, 264, 307, 396, 320],
#               [174, 259, 175, 85, 3],
#               [174, 259, 290, 266, 274],
#               [174, 283, 326, 274, 140],
#               [174, 330, 176, 203, 317],
#               [174, 277, 193, 354, 403],
#               [174, 238, 5, 336, 329],
#               [174, 258, 267, 345, 190],
#               [174, 105, 330, 62, 178],
#               [174, 40, 99, 342, 216],
#               [174, 233, 266, 231, 251],
#               [174, 140, 302, 319, 216],
#               [174, 21, 273, 201, 220],
#               [174, 208, 178, 366, 91],
#               [174, 368, 323, 2, 291],
#               [174, 52, 157, 154, 50],
#               [174, 317, 265, 363, 39],
#               [174, 240, 87, 11, 374],
#               [174, 184, 306, 219, 151],
#               [174, 94, 310, 121, 156],
#               [174, 358, 301, 273, 276],
#               [174, 358, 109, 135, 222],
#               [174, 356, 142, 271, 106],
#               [174, 357, 157, 183, 195],
#               [174, 122, 176, 372, 20],
#               [174, 195, 371, 116, 97],
#               [174, 212, 160, 109, 259],
#               [174, 270, 215, 256, 14],
#               [174, 151, 281, 192, 1],
#               [174, 46, 233, 85, 200],
#               [174, 366, 158, 147, 395],
#               [174, 102, 2, 165, 30],
#               [174, 178, 154, 269, 336],
#               [123, 2, 140, 333, 128],
#               [123, 37, 194, 384, 315],
#               [123, 25, 236, 111, 140],
#               [123, 152, 394, 36, 270],
#               [123, 222, 264, 236, 24],
#               [123, 108, 42, 220, 163],
#               [123, 95, 35, 304, 217],
#               [123, 238, 365, 45, 115],
#               [123, 41, 288, 2, 94],
#               [123, 219, 160, 57, 223],
#               [123, 7, 71, 360, 300],
#               [123, 54, 67, 286, 63],
#               [123, 370, 66, 130, 83],
#               [123, 237, 47, 61, 203],
#               [123, 306, 333, 366, 65],
#               [123, 53, 151, 52, 237],
#               [123, 214, 380, 206, 64],
#               [123, 129, 229, 226, 47],
#               [123, 388, 302, 171, 321],
#               [123, 384, 51, 25, 324],
#               [123, 29, 185, 46, 112],
#               [123, 43, 106, 26, 283],
#               [123, 395, 30, 216, 281],
#               [123, 331, 228, 6, 21],
#               [187, 25, 315, 322, 307],
#               [187, 275, 39, 254, 298],
#               [187, 287, 216, 79, 109],
#               [187, 120, 286, 6, 86],
#               [187, 66, 360, 344, 364],
#               [187, 40, 394, 363, 212],
#               [187, 205, 327, 2, 17],
#               [187, 251, 371, 30, 69],
#               [187, 374, 264, 305, 105],
#               [187, 374, 387, 262, 289],
#               [187, 377, 120, 384, 108],
#               [187, 71, 46, 377, 135],
#               [187, 380, 280, 161, 400],
#               [187, 103, 371, 383, 243],
#               [187, 197, 206, 47, 59],
#               [187, 263, 349, 320, 107],
#               [187, 307, 307, 223, 199],
#               [187, 387, 311, 222, 132],
#               [187, 369, 308, 74, 118],
#               [187, 250, 255, 348, 351],
#               [187, 61, 155, 379, 231],
#               [126, 118, 1, 352, 393],
#               [126, 42, 13, 20, 88],
#               [126, 117, 251, 265, 199],
#               [126, 168, 392, 325, 225],
#               [126, 330, 363, 237, 263],
#               [126, 156, 77, 288, 243],
#               [126, 41, 233, 144, 75],
#               [126, 377, 263, 386, 349],
#               [126, 199, 309, 331, 187],
#               [126, 100, 84, 274, 35],
#               [126, 241, 350, 263, 175],
#               [126, 47, 50, 151, 402],
#               [126, 103, 189, 243, 162],
#               [126, 210, 160, 8, 201],
#               [126, 353, 35, 247, 360],
#               [126, 96, 50, 70, 147],
#               [126, 260, 299, 203, 100],
#               [126, 333, 22, 219, 192],
#               [126, 309, 80, 387, 380],
#               [126, 309, 318, 60, 99],
#               [126, 338, 215, 305, 247],
#               [126, 13, 204, 60, 369],
#               [126, 32, 45, 149, 196],
#               [126, 43, 177, 88, 17],
#               [16, 123, 102, 232, 128],
#               [16, 112, 156, 340, 150],
#               [16, 334, 303, 267, 330],
#               [16, 402, 384, 73, 97],
#               [16, 22, 272, 274, 124],
#               [16, 18, 164, 378, 255],
#               [16, 385, 309, 312, 28],
#               [16, 164, 157, 24, 88],
#               [16, 41, 92, 81, 161],
#               [16, 193, 276, 104, 94],
#               [16, 219, 114, 392, 203],
#               [16, 140, 224, 253, 15],
#               [16, 31, 233, 347, 214],
#               [16, 59, 342, 62, 320],
#               [16, 294, 9, 264, 72],
#               [16, 125, 239, 128, 14],
#               [16, 134, 248, 51, 339],
#               [16, 87, 355, 269, 148],
#               [16, 153, 311, 276, 314],
#               [16, 94, 354, 185, 357],
#               [16, 85, 211, 61, 383],
#               [16, 104, 211, 58, 48],
#               [16, 192, 11, 62, 44],
#               [16, 195, 300, 150, 307],
#               [16, 63, 152, 207, 149],
#               [16, 245, 82, 101, 44],
#               [16, 257, 8, 42, 233],
#               [16, 392, 27, 385, 202],
#               [16, 391, 154, 58, 374],
#               [16, 146, 338, 12, 318],
#               [16, 256, 331, 10, 302],
#               [16, 32, 129, 234, 140],
#               [16, 322, 405, 232, 49],
#               [17, 6, 123, 383, 136],
#               [17, 289, 391, 384, 98],
#               [17, 187, 295, 28, 45],
#               [17, 17, 281, 92, 10],
#               [17, 337, 174, 319, 56],
#               [17, 179, 300, 3, 155],
#               [17, 325, 66, 234, 69],
#               [17, 88, 10, 148, 122],
#               [17, 287, 3, 164, 237],
#               [17, 117, 88, 332, 340],
#               [17, 95, 79, 63, 390],
#               [17, 148, 293, 194, 62],
#               [17, 271, 124, 405, 35],
#               [17, 164, 174, 337, 346],
#               [17, 54, 320, 174, 396],
#               [17, 70, 399, 43, 43],
#               [17, 27, 294, 300, 48],
#               [17, 27, 328, 296, 305],
#               [17, 252, 301, 341, 326],
#               [17, 335, 137, 45, 278],
#               [17, 161, 226, 330, 393],
#               [17, 356, 132, 278, 12],
#               [17, 212, 324, 244, 60],
#               [17, 390, 180, 250, 213],
#               [17, 248, 11, 244, 175],
#               [17, 388, 309, 364, 210],
#               [17, 364, 138, 252, 160],
#               [17, 348, 219, 78, 326],
#               [17, 347, 324, 305, 271],
#               [80, 126, 353, 148, 292],
#               [80, 9, 303, 148, 59],
#               [80, 181, 282, 345, 125],
#               [80, 78, 29, 405, 247],
#               [80, 99, 68, 103, 367],
#               [80, 360, 98, 371, 26],
#               [80, 308, 266, 175, 403],
#               [80, 62, 317, 340, 252],
#               [80, 188, 73, 197, 18],
#               [80, 217, 351, 316, 20],
#               [80, 76, 77, 116, 104],
#               [80, 111, 387, 232, 67],
#               [80, 33, 78, 391, 137],
#               [80, 115, 285, 273, 142],
#               [80, 343, 171, 293, 89],
#               [80, 383, 209, 247, 147],
#               [80, 401, 198, 68, 329],
#               [80, 106, 202, 405, 247],
#               [80, 281, 85, 112, 127],
#               [80, 333, 379, 126, 239],
#               [80, 178, 257, 252, 239],
#               [56, 35, 91, 227, 146],
#               [56, 329, 395, 290, 298],
#               [56, 91, 205, 58, 34],
#               [56, 9, 300, 351, 163],
#               [56, 302, 37, 128, 42],
#               [56, 363, 22, 113, 335],
#               [56, 215, 191, 108, 176],
#               [56, 86, 356, 178, 59],
#               [56, 186, 272, 164, 294],
#               [56, 186, 26, 45, 64],
#               [56, 186, 229, 33, 74],
#               [56, 89, 40, 17, 10],
#               [56, 242, 157, 23, 283],
#               [56, 124, 114, 43, 258],
#               [56, 84, 213, 53, 381],
#               [56, 21, 82, 321, 94],
#               [56, 370, 337, 132, 79],
#               [56, 208, 387, 135, 158],
#               [56, 137, 259, 66, 55],
#               [56, 87, 366, 323, 233],
#               [56, 136, 215, 19, 372],
#               [56, 407, 64, 132, 123],
#               [56, 383, 149, 335, 88],
#               [56, 94, 35, 135, 213],
#               [56, 162, 17, 385, 145],
#               [56, 162, 264, 44, 243],
#               [56, 135, 91, 402, 396],
#               [56, 50, 210, 92, 63],
#               [56, 229, 101, 364, 193],
#               [56, 387, 211, 148, 294],
#               [56, 172, 148, 338, 135],
#               [56, 198, 15, 59, 128],
#               [56, 68, 180, 31, 13],
#               [56, 133, 123, 171, 254],
#               [56, 211, 189, 377, 7],
#               [201, 25, 41, 78, 228],
#               [201, 34, 299, 210, 139],
#               [201, 389, 388, 70, 117],
#               [201, 389, 77, 326, 146],
#               [201, 78, 233, 280, 392],
#               [201, 330, 281, 176, 370],
#               [201, 186, 403, 355, 337],
#               [201, 230, 398, 253, 403],
#               [201, 180, 351, 237, 350],
#               [201, 241, 98, 129, 346],
#               [201, 122, 230, 24, 147],
#               [201, 212, 356, 141, 369],
#               [201, 388, 194, 126, 47],
#               [201, 351, 147, 202, 110],
#               [201, 364, 167, 156, 219],
#               [201, 244, 208, 232, 298],
#               [201, 256, 392, 42, 207],
#               [201, 366, 282, 276, 333],
#               [201, 333, 397, 37, 406],
#               [37, 181, 293, 341, 225],
#               [37, 168, 356, 225, 38],
#               [37, 95, 308, 306, 136],
#               [37, 400, 24, 73, 29],
#               [37, 191, 315, 320, 240],
#               [37, 75, 186, 276, 80],
#               [37, 100, 316, 12, 77],
#               [37, 27, 391, 349, 177],
#               [37, 226, 221, 137, 126],
#               [37, 131, 280, 39, 251],
#               [37, 306, 123, 39, 176],
#               [37, 189, 50, 117, 214],
#               [37, 403, 350, 279, 208],
#               [37, 161, 160, 378, 379],
#               [37, 154, 216, 287, 197],
#               [37, 319, 169, 311, 211],
#               [37, 246, 124, 29, 143],
#               [37, 122, 293, 338, 380],
#               [37, 82, 62, 266, 72],
#               [37, 194, 235, 245, 268],
#               [37, 183, 121, 140, 302],
#               [37, 234, 376, 123, 87],
#               [25, 4, 407, 227, 356],
#               [25, 175, 347, 391, 338],
#               [25, 185, 327, 195, 155],
#               [25, 283, 161, 335, 147],
#               [25, 266, 55, 190, 142],
#               [25, 22, 34, 91, 298],
#               [25, 60, 404, 215, 352],
#               [25, 59, 268, 334, 321],
#               [25, 380, 343, 44, 388],
#               [25, 346, 333, 116, 379],
#               [25, 208, 397, 80, 363],
#               [25, 177, 141, 12, 21],
#               [25, 362, 191, 50, 243],
#               [25, 221, 339, 245, 173],
#               [25, 228, 77, 373, 253],
#               [25, 94, 157, 56, 275],
#               [25, 114, 358, 315, 34],
#               [25, 356, 233, 208, 48],
#               [25, 318, 79, 97, 327],
#               [25, 135, 38, 43, 153],
#               [25, 232, 96, 355, 253],
#               [25, 15, 263, 52, 244],
#               [25, 265, 203, 406, 53],
#               [25, 173, 271, 57, 317],
#               [25, 333, 26, 79, 96],
#               [25, 312, 210, 396, 187],
#               [25, 77, 404, 354, 3],
#               [25, 133, 368, 341, 378],
#               [275, 17, 386, 386, 71],
#               [275, 9, 256, 277, 137],
#               [275, 108, 115, 17, 249],
#               [275, 277, 79, 23, 390],
#               [275, 277, 77, 345, 342],
#               [275, 171, 2, 176, 242],
#               [275, 186, 390, 23, 4],
#               [275, 217, 365, 341, 368],
#               [275, 70, 241, 238, 356],
#               [275, 373, 407, 6, 277],
#               [275, 311, 262, 354, 39],
#               [275, 399, 48, 161, 406],
#               [275, 132, 60, 130, 70],
#               [275, 109, 75, 380, 196],
#               [275, 352, 229, 23, 390],
#               [275, 393, 307, 43, 58],
#               [275, 328, 42, 195, 133],
#               [275, 28, 36, 390, 374],
#               [275, 29, 248, 395, 177],
#               [275, 20, 313, 11, 264],
#               [275, 333, 174, 37, 97],
#               [275, 13, 395, 405, 28],
#               [4, 315, 164, 254, 385],
#               [4, 337, 222, 104, 297],
#               [4, 112, 278, 263, 374],
#               [4, 120, 277, 155, 68],
#               [4, 165, 89, 330, 246],
#               [4, 335, 121, 160, 236],
#               [4, 138, 33, 334, 289],
#               [4, 189, 131, 280, 161],
#               [4, 65, 99, 43, 100],
#               [4, 48, 249, 236, 98],
#               [4, 223, 237, 153, 394],
#               [4, 151, 223, 207, 388],
#               [4, 366, 177, 89, 392],
#               [4, 200, 193, 81, 240],
#               [4, 394, 19, 4, 142],
#               [4, 32, 184, 184, 15],
#               [4, 43, 20, 151, 91],
#               [337, 4, 309, 222, 266],
#               [337, 264, 328, 317, 32],
#               [337, 213, 303, 233, 360],
#               [337, 326, 139, 171, 320],
#               [337, 362, 273, 106, 122],
#               [337, 33, 64, 54, 132],
#               [337, 153, 78, 255, 85],
#               [337, 138, 44, 189, 113],
#               [337, 138, 43, 71, 399],
#               [337, 344, 289, 245, 276],
#               [337, 321, 373, 79, 81],
#               [337, 328, 56, 309, 137],
#               [337, 48, 210, 135, 195],
#               [337, 55, 341, 123, 206],
#               [337, 257, 248, 114, 375],
#               [337, 163, 95, 379, 282],
#               [337, 157, 239, 57, 147],
#               [337, 397, 93, 190, 393],
#               [337, 253, 6, 121, 336],
#               [337, 253, 400, 73, 376],
# ...
#               [34, 120, 224, 113, 24],
#               [34, 168, 25, 309, 24],
#               [34, 7, 268, 123, 381],
#               [34, 273, 7, 392, 344],
#               [34, 273, 328, 83, 115],
#               [34, 383, 371, 221, 111],
#               [34, 176, 359, 386, 117],
#               [34, 109, 161, 385, 337],
#               [34, 96, 350, 110, 296],
#               [34, 260, 228, 180, 321],
#               [34, 19, 175, 160, 154],
#               [34, 127, 276, 144, 71],
#               [34, 127, 322, 258, 18],
#               [396, 337, 376, 375, 199],
#               [396, 175, 107, 214, 382],
#               [396, 42, 75, 369, 78],
#               [396, 330, 153, 370, 254],
#               [396, 374, 218, 16, 345],
#               [396, 374, 270, 323, 137],
#               [396, 21, 277, 366, 406],
#               [396, 21, 254, 318, 394],
#               [396, 21, 1, 368, 155],
#               [396, 162, 10, 2, 156],
#               [396, 85, 130, 114, 241],
#               [396, 318, 136, 324, 16],
#               [396, 176, 358, 67, 227],
#               [396, 63, 121, 89, 315],
#               [396, 15, 388, 183, 303],
#               [396, 263, 258, 318, 190],
#               [396, 190, 23, 345, 401],
#               [396, 304, 145, 78, 61],
#               [396, 96, 246, 208, 124],
#               [396, 46, 393, 23, 75],
#               [396, 20, 94, 282, 203],
#               [272, 80, 270, 38, 374],
#               [272, 150, 340, 245, 262],
#               [272, 302, 81, 394, 65],
#               [272, 334, 201, 38, 353],
#               [272, 204, 327, 163, 401],
#               [272, 86, 404, 358, 69],
#               [272, 66, 94, 184, 31],
#               [272, 258, 186, 186, 205],
#               [272, 230, 15, 11, 247],
#               [272, 40, 63, 209, 189],
#               [272, 24, 209, 389, 15],
#               [272, 278, 395, 277, 232],
#               [272, 165, 126, 285, 27],
#               [272, 89, 389, 11, 383],
#               [272, 386, 173, 334, 403],
#               [272, 60, 40, 286, 54],
#               [272, 370, 372, 220, 214],
#               [272, 262, 273, 250, 39],
#               [272, 33, 325, 250, 238],
#               [272, 227, 373, 289, 250],
#               [272, 317, 389, 23, 289],
#               [272, 161, 27, 349, 96],
#               [272, 356, 313, 52, 309],
#               [272, 393, 335, 357, 328],
#               [272, 145, 51, 33, 71],
#               [272, 190, 22, 256, 195],
#               [272, 351, 377, 72, 124],
#               [272, 68, 340, 205, 219],
#               [272, 347, 236, 95, 274],
#               [272, 127, 296, 71, 297],
#               [79, 152, 213, 309, 118],
#               [79, 389, 239, 263, 36],
#               [79, 72, 85, 187, 174],
#               [79, 258, 93, 157, 59],
#               [79, 303, 180, 287, 40],
#               [79, 251, 282, 169, 139],
#               [79, 377, 281, 181, 108],
#               [79, 100, 115, 164, 275],
#               [79, 225, 151, 264, 400],
#               [79, 93, 377, 300, 338],
#               [79, 27, 39, 340, 24],
#               [79, 134, 86, 382, 76],
#               [79, 311, 30, 305, 361],
#               [79, 92, 297, 236, 233],
#               [79, 103, 72, 195, 47],
#               [79, 254, 76, 209, 365],
#               [79, 189, 171, 313, 272],
#               [79, 343, 115, 384, 1],
#               [79, 132, 174, 120, 235],
#               [79, 10, 195, 328, 306],
#               [79, 58, 56, 20, 313],
#               [79, 382, 71, 98, 341],
#               [79, 229, 92, 139, 346],
#               [79, 172, 394, 81, 206],
#               [79, 369, 59, 326, 180],
#               [79, 250, 338, 349, 277],
#               [79, 234, 103, 315, 298],
#               [313, 275, 37, 304, 19],
#               [313, 95, 17, 280, 31],
#               [313, 148, 337, 245, 272],
#               [313, 159, 122, 52, 113],
#               [313, 171, 88, 96, 102],
#               [313, 258, 224, 48, 133],
#               [313, 40, 255, 294, 81],
#               [313, 100, 354, 158, 405],
#               [313, 373, 323, 395, 297],
#               [313, 404, 27, 188, 60],
#               [313, 141, 356, 140, 336],
#               [313, 399, 222, 400, 84],
#               [313, 393, 225, 10, 222],
#               [313, 15, 209, 381, 326],
#               [313, 388, 319, 319, 348],
#               [313, 190, 91, 273, 32],
#               [313, 190, 215, 273, 73],
#               [313, 297, 76, 180, 303],
#               [313, 394, 74, 240, 172],
#               [313, 347, 117, 195, 295],
#               [313, 178, 323, 254, 396],
#               [313, 128, 133, 274, 371],
#               [152, 35, 309, 342, 249],
#               [152, 167, 307, 260, 336],
#               [152, 398, 117, 52, 326],
#               [152, 202, 364, 120, 39],
#               [152, 193, 199, 336, 400],
#               [152, 140, 329, 1, 175],
#               [152, 268, 39, 174, 223],
#               [152, 346, 340, 226, 272],
#               [152, 311, 125, 407, 272],
#               [152, 52, 276, 218, 26],
#               [152, 317, 305, 223, 337],
#               [152, 53, 93, 105, 150],
#               [152, 357, 384, 128, 120],
#               [152, 28, 128, 382, 281],
#               [152, 69, 54, 228, 43],
#               [152, 15, 332, 146, 62],
#               [152, 107, 204, 402, 220],
#               [152, 151, 313, 106, 206],
#               [152, 245, 224, 233, 128],
#               [152, 391, 168, 341, 61],
#               [152, 361, 314, 400, 386],
#               [152, 39, 309, 223, 338],
#               [152, 61, 308, 327, 58],
#               [152, 133, 20, 208, 145],
#               [152, 67, 147, 40, 325],
#               [355, 203, 269, 39, 105],
#               [355, 365, 12, 221, 305],
#               [355, 100, 359, 106, 362],
#               [355, 92, 367, 376, 380],
#               [355, 328, 129, 6, 285],
#               [355, 44, 120, 311, 274],
#               [355, 190, 242, 321, 260],
#               [355, 144, 151, 74, 264],
#               [355, 46, 54, 380, 31],
#               [355, 147, 209, 48, 285],
#               [355, 320, 330, 164, 2],
#               [355, 163, 360, 392, 247],
#               [355, 312, 128, 155, 374],
#               [355, 127, 315, 103, 406],
#               [8, 313, 275, 82, 101],
#               [8, 152, 296, 142, 161],
#               [8, 283, 264, 15, 180],
#               [8, 168, 352, 259, 86],
#               [8, 95, 138, 145, 11],
#               [8, 66, 62, 23, 400],
#               [8, 139, 129, 78, 364],
#               [8, 193, 200, 31, 285],
#               [8, 301, 14, 39, 179],
#               [8, 165, 319, 283, 46],
#               [8, 89, 401, 398, 243],
#               [8, 365, 117, 370, 271],
#               [8, 380, 189, 231, 257],
#               [8, 285, 399, 9, 300],
#               [8, 131, 401, 32, 222],
#               [8, 113, 220, 274, 299],
#               [8, 138, 321, 116, 119],
#               [8, 404, 382, 74, 50],
#               [8, 352, 83, 13, 163],
#               [8, 63, 115, 225, 24],
#               [8, 265, 116, 12, 284],
#               [8, 351, 55, 389, 19],
#               [8, 160, 88, 147, 378],
#               [8, 244, 166, 391, 235],
#               [8, 250, 132, 386, 60],
#               [8, 367, 275, 254, 182],
#               [8, 395, 389, 180, 168],
#               [8, 331, 14, 1, 109],
#               [8, 211, 133, 332, 397],
#               [8, 341, 216, 309, 374],
#               [149, 37, 67, 41, 300],
#               [149, 275, 46, 384, 123],
#               [149, 117, 145, 52, 104],
#               [149, 168, 233, 399, 155],
#               [149, 95, 121, 294, 25],
#               [149, 99, 329, 288, 141],
#               [149, 300, 373, 133, 72],
#               [149, 186, 293, 78, 392],
#               [149, 316, 327, 106, 233],
#               [149, 62, 339, 180, 105],
#               [149, 377, 144, 74, 195],
#               [149, 188, 150, 217, 33],
#               [149, 226, 277, 189, 165],
#               [149, 362, 378, 46, 210],
#               [149, 216, 72, 324, 151],
#               [149, 227, 43, 54, 119],
#               [149, 344, 13, 195, 396],
#               [149, 53, 401, 107, 91],
#               [149, 345, 301, 19, 219],
#               [149, 106, 90, 392, 376],
#               [149, 135, 209, 258, 406],
#               [149, 281, 369, 98, 397],
#               [149, 116, 398, 184, 374],
#               [149, 265, 181, 355, 92],
#               [149, 151, 80, 52, 239],
#               [149, 366, 207, 362, 218],
#               [149, 43, 210, 265, 197],
#               [149, 130, 112, 231, 123],
#               [149, 67, 240, 267, 294],
#               [329, 2, 149, 41, 138],
#               [329, 101, 396, 325, 154],
#               [329, 17, 288, 82, 77],
#               [329, 201, 184, 44, 23],
#               [329, 4, 225, 80, 55],
#               [329, 329, 265, 367, 297],
#               [329, 91, 307, 165, 290],
#               [329, 325, 222, 196, 351],
#               [329, 330, 243, 394, 13],
#               [329, 18, 121, 312, 121],
#               [329, 156, 91, 114, 91],
#               [329, 205, 202, 170, 138],
#               [329, 89, 201, 282, 167],
#               [329, 7, 384, 340, 225],
#               [329, 84, 60, 72, 289],
#               [329, 213, 203, 31, 139],
#               [329, 189, 340, 97, 100],
#               [329, 375, 188, 118, 6],
#               [329, 162, 180, 366, 219],
#               [329, 290, 179, 11, 40],
#               [329, 290, 31, 387, 325],
#               [329, 310, 346, 219, 52],
#               [329, 267, 405, 153, 310],
#               [329, 390, 214, 235, 287],
#               [329, 206, 287, 80, 138],
#               [329, 333, 286, 85, 149],
#               [329, 367, 348, 304, 50],
#               [329, 288, 385, 17, 109],
#               [91, 101, 369, 289, 73],
#               [91, 16, 300, 302, 14],
#               [91, 287, 222, 406, 237],
#               [91, 360, 156, 293, 402],
#               [91, 360, 10, 268, 346],
#               [91, 360, 299, 14, 318],
#               [91, 75, 19, 77, 250],
#               [91, 155, 341, 304, 9],
#               [91, 326, 215, 306, 356],
#               [91, 380, 28, 215, 257],
#               [91, 38, 210, 188, 90],
#               [91, 177, 139, 115, 232],
#               [91, 372, 296, 125, 132],
#               [91, 131, 254, 372, 211],
#               [91, 284, 380, 318, 228],
#               [91, 310, 97, 348, 99],
#               [91, 305, 59, 236, 218],
#               [91, 353, 326, 320, 131],
#               [91, 328, 269, 202, 323],
#               [91, 82, 223, 245, 224],
#               [91, 194, 52, 86, 340],
#               [91, 312, 334, 285, 90],
#               [91, 133, 37, 406, 303],
#               [12, 101, 117, 285, 23],
#               [12, 150, 101, 374, 117],
#               [12, 329, 326, 342, 54],
#               [12, 18, 352, 38, 163],
#               [12, 398, 284, 37, 53],
#               [12, 300, 186, 62, 92],
#               [12, 40, 255, 401, 364],
#               [12, 124, 190, 24, 356],
#               [12, 267, 356, 138, 158],
#               [12, 197, 248, 312, 262],
#               [12, 209, 72, 337, 252],
#               [12, 172, 10, 25, 72],
#               [12, 146, 377, 31, 387],
#               [12, 163, 259, 312, 310],
#               [12, 19, 74, 76, 406],
#               [12, 394, 148, 234, 328],
#               [12, 276, 74, 316, 181],
#               [167, 150, 11, 134, 142],
#               [167, 149, 179, 194, 231],
#               [167, 389, 196, 251, 378],
#               [167, 108, 151, 327, 226],
#               [167, 323, 76, 309, 392],
#               [167, 105, 264, 282, 403],
#               [167, 278, 68, 217, 193],
#               [167, 251, 264, 38, 13],
#               [167, 242, 332, 148, 340],
#               [167, 70, 289, 158, 193],
#               [167, 47, 159, 365, 337],
#               [167, 207, 53, 185, 270],
#               [167, 345, 268, 55, 156],
#               [167, 63, 186, 13, 78],
#               [167, 324, 322, 311, 217],
#               [167, 351, 237, 363, 133],
#               [167, 387, 23, 24, 120],
#               [167, 381, 388, 4, 347],
#               [167, 392, 381, 375, 102],
#               [167, 46, 172, 325, 325],
#               [167, 170, 227, 197, 322],
#               [167, 43, 351, 407, 111],
#               [9, 17, 45, 242, 407],
#               [9, 396, 9, 138, 97],
#               [9, 26, 274, 281, 173],
#               [9, 169, 392, 212, 121],
#               [9, 202, 35, 146, 2],
#               [9, 62, 54, 234, 225],
#               [9, 21, 91, 162, 176],
#               [9, 180, 250, 16, 63],
#               [9, 33, 246, 407, 1],
#               [9, 52, 340, 52, 195],
#               [9, 216, 211, 186, 186],
#               [9, 319, 212, 294, 306],
#               [9, 292, 346, 382, 256],
#               [9, 378, 377, 128, 66],
#               [9, 29, 177, 207, 224],
#               [9, 366, 78, 376, 131],
#               [9, 309, 377, 91, 361],
#               [9, 73, 200, 359, 102],
#               [9, 77, 103, 213, 388],
#               [9, 322, 328, 177, 314],
#               [243, 289, 285, 244, 95],
#               [243, 51, 245, 372, 382],
#               [243, 243, 2, 88, 27],
#               [243, 389, 368, 350, 89],
#               [243, 238, 377, 96, 183],
#               [243, 205, 278, 224, 277],
#               [243, 242, 3, 219, 77],
#               [243, 27, 382, 41, 336],
#               [243, 21, 121, 217, 266],
#               [243, 208, 338, 168, 49],
#               [243, 141, 301, 284, 186],
#               [243, 104, 128, 273, 403],
#               [243, 345, 309, 163, 225],
#               [243, 310, 354, 335, 126],
#               [243, 292, 403, 31, 225],
#               [243, 223, 139, 323, 295],
#               [243, 50, 325, 61, 222],
#               [243, 339, 249, 87, 177],
#               [243, 369, 258, 333, 2],
#               [243, 160, 143, 215, 41],
#               [243, 250, 295, 310, 374],
#               [243, 298, 337, 346, 86],
#               [243, 43, 333, 306, 131],
#               [243, 211, 281, 302, 105],
#               [243, 127, 37, 63, 362],
#               [179, 126, 318, 9, 210],
#               [179, 80, 150, 238, 193],
#               [179, 25, 324, 205, 216],
#               [179, 23, 103, 287, 187],
#               [179, 264, 49, 279, 290],
#               [179, 334, 400, 23, 282],
#               [179, 239, 157, 66, 281],
#               [179, 86, 240, 85, 391],
#               [179, 171, 332, 212, 303],
#               [179, 271, 72, 370, 207],
#               [179, 247, 90, 75, 223],
#               [179, 368, 92, 150, 263],
#               [179, 240, 332, 60, 23],
#               [179, 224, 301, 67, 142],
#               [179, 141, 65, 193, 94],
#               [179, 114, 238, 35, 340],
#               [179, 104, 295, 137, 177],
#               [179, 290, 273, 225, 239],
#               [179, 122, 86, 104, 107],
#               [179, 195, 276, 258, 71],
#               [179, 305, 48, 277, 315],
#               [179, 274, 358, 162, 70],
#               [179, 190, 175, 150, 145],
#               [179, 314, 276, 210, 225],
#               [179, 68, 51, 205, 395],
#               [179, 68, 79, 299, 10],
#               [179, 397, 139, 165, 162],
#               [179, 130, 194, 323, 180],
#               [179, 67, 34, 70, 264],
#               [23, 174, 308, 359, 44],
#               [23, 9, 181, 387, 148],
#               [23, 112, 379, 184, 50],
#               [23, 239, 371, 375, 63],
#               [23, 215, 371, 293, 20],
#               [23, 215, 250, 181, 148],
#               [23, 66, 266, 45, 186],
#               [23, 230, 135, 374, 37],
#               [23, 278, 388, 232, 407],
#               [23, 242, 96, 399, 93],
#               [23, 380, 272, 24, 47],
#               [23, 404, 128, 251, 406],
#               [23, 189, 191, 76, 76],
#               [23, 403, 161, 134, 256],
#               [23, 143, 80, 104, 299],
#               [23, 85, 319, 381, 234],
#               [23, 81, 394, 115, 246],
#               [23, 58, 12, 257, 238],
#               [23, 48, 216, 99, 31],
#               [23, 232, 195, 245, 58],
#               [23, 270, 201, 56, 397],
#               [23, 307, 164, 313, 42],
#               [23, 170, 329, 32, 305],
#               [23, 19, 14, 273, 202],
#               [23, 354, 263, 129, 50],
#               [23, 338, 399, 13, 159],
#               [23, 77, 70, 59, 243],
#               [23, 253, 226, 72, 111],
#               [23, 276, 395, 207, 373],
#               [325, 37, 344, 303, 32],
#               ...]})

# %%
df_train, df_test = train_test_split(df, test_size=0.2, shuffle=True)

# %%
class CaptchaDataset:
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        data = self.df.iloc[idx]
        image = Image.open(os.path.join(path, data['image'])).convert('L')
        label = torch.tensor(data['label'], dtype=torch.int32)
        
        if self.transform is not None:
            image = self.transform(image)
        
        return image, label
        
        
transform = T.Compose([
    T.ToTensor()
])

train_data = CaptchaDataset(df_train, transform)
test_data = CaptchaDataset(df_test, transform)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True)
test_loader = DataLoader(test_data, batch_size=8)

# %%
class Bidirectional(nn.Module):
    def __init__(self, inp, hidden, out, lstm=True):
        super(Bidirectional, self).__init__()
        if lstm:
            self.rnn = nn.LSTM(inp, hidden, bidirectional=True)
        else:
            self.rnn = nn.GRU(inp, hidden, bidirectional=True)
        self.embedding = nn.Linear(hidden*2, out)
    def forward(self, X):
        recurrent, _ = self.rnn(X)
        out = self.embedding(recurrent)     
        return out
    
    
class CRNN(nn.Module):
    def __init__(self, in_channels, output):
        super(CRNN, self).__init__()

        self.cnn = nn.Sequential(
                nn.Conv2d(in_channels, 256, 9, stride=1, padding=1),
                nn.ReLU(),
                nn.BatchNorm2d(256),
                nn.MaxPool2d(3, 3),
                nn.Conv2d(256, 256, (4, 3), stride=1, padding=1),
                nn.ReLU(),
                nn.BatchNorm2d(256))
        
        self.linear = nn.Linear(3328, 256)
        self.bn1 = nn.BatchNorm1d(256)
        self.rnn = Bidirectional(256, 1024, output+1)

    def forward(self, X, y=None, criterion = None):
        out = self.cnn(X)
        N, C, w, h = out.size()
        out = out.view(N, -1, h)
        out = out.permute(0, 2, 1)
        out = self.linear(out)

        out = out.permute(1, 0, 2)
        out = self.rnn(out)
            
        if y is not None:
            T = out.size(0)
            N = out.size(1)
        
            input_lengths = torch.full(size=(N,), fill_value=T, dtype=torch.int32)
            target_lengths = torch.full(size=(N,), fill_value=5, dtype=torch.int32)
        
            loss = criterion(out, y, input_lengths, target_lengths)
            
            return out, loss
        
        return out, None
    
    def _ConvLayer(self, inp, out, kernel, stride, padding, bn=False):
        if bn:
            conv = [
                nn.Conv2d(inp, out, kernel, stride=stride, padding=padding),
                nn.ReLU(),
                nn.BatchNorm2d(out)
            ]
        else:
            conv = [
                nn.Conv2d(inp, out, kernel, stride=stride, padding=padding),
                nn.ReLU()
            ]
        return nn.Sequential(*conv)

# %%
class Engine:
    def __init__(self, model, optimizer, criterion, epochs=30, early_stop=False, device='cpu'):
        self.model = model
        self.optimizer = optimizer
        self.criterion = criterion
        self.epochs = epochs
        self.early_stop = early_stop
        self.device = device
        
    def fit(self, dataloader):
        hist_loss = []
        for epoch in range(self.epochs):
            self.model.train()
            tk = tqdm(dataloader, total=len(dataloader))
            for data, target in tk:
                data = data.to(device=self.device)
                target = target.to(device=self.device)

                self.optimizer.zero_grad()

                out, loss = self.model(data, target, criterion=self.criterion)

                loss.backward()

                self.optimizer.step()


                tk.set_postfix({'Epoch':epoch+1, 'Loss' : loss.item()})
                
    def evaluate(self, dataloader):
        self.model.eval()
        loss = 0
        hist_loss = []
        outs = collections.defaultdict(list)
        tk = tqdm(dataloader, total=len(dataloader))
        with torch.no_grad():
            for data, target in tk:
                data = data.to(device=self.device)
                target = target.to(device=self.device)

                out, loss = self.model(data, target, criterion=self.criterion)
               
                target=target.cpu().detach().numpy()
                outs['pred'].append(out)
                outs['target'].append(target)


                hist_loss.append(loss)

                tk.set_postfix({'Loss':loss.item()})
                
        return outs, hist_loss
    
    def predict(self, image):
        image = Image.open(image).convert('L')
        image_tensor = T.ToTensor()(image)
        image_tensor = image_tensor.unsqueeze(0)        
        out, _ = self.model(image_tensor.to(device=self.device))
        out = out.permute(1, 0, 2)
        out = out.log_softmax(2)
        out = out.argmax(2)
        out = out.cpu().detach().numpy()
        
        return out

# %%
model = CRNN(in_channels=1, output=num_class).to(DEVICE)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.CTCLoss()

engine = Engine(model, optimizer, criterion, device=DEVICE)

# %%
engine.fit(train_loader)
outs, loss = engine.evaluate(test_loader)
# Out:
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.10it/s, Epoch=1, Loss=5.97]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.31it/s, Epoch=2, Loss=6.32]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.21it/s, Epoch=3, Loss=6.35]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.15it/s, Epoch=4, Loss=6.36]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.03it/s, Epoch=5, Loss=6.37]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.01it/s, Epoch=6, Loss=6.38]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.99it/s, Epoch=7, Loss=6.39]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.03it/s, Epoch=8, Loss=6.37]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.02it/s, Epoch=9, Loss=6.38]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.94it/s, Epoch=10, Loss=6.22]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.98it/s, Epoch=11, Loss=6.19]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.03it/s, Epoch=12, Loss=6.21]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.00it/s, Epoch=13, Loss=5.76]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.03it/s, Epoch=14, Loss=5.52]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.06it/s, Epoch=15, Loss=4.71]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.20it/s, Epoch=16, Loss=2.13]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.15it/s, Epoch=17, Loss=0.916]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:19<00:00, 25.01it/s, Epoch=18, Loss=0.162]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.97it/s, Epoch=19, Loss=0.262]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.91it/s, Epoch=20, Loss=0.411]
# 100%|███████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.93it/s, Epoch=21, Loss=0.21]
# 100%|█████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.97it/s, Epoch=22, Loss=0.0771]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.93it/s, Epoch=23, Loss=0.202]
# 100%|█████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.56it/s, Epoch=24, Loss=0.0825]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.84it/s, Epoch=25, Loss=0.105]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.90it/s, Epoch=26, Loss=0.171]
# 100%|████████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.92it/s, Epoch=27, Loss=0.1]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.91it/s, Epoch=28, Loss=0.039]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.95it/s, Epoch=29, Loss=0.181]
# 100%|██████████████████████████████████████████████████████████| 500/500 [00:20<00:00, 24.91it/s, Epoch=30, Loss=0.205]
# 100%|███████████████████████████████████████████████████████████████████| 250/250 [00:03<00:00, 80.18it/s, Loss=-0.111]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties

# 指定中文字体文件的路径
font_path = "F:\\project\\python\\OCR\\Recognize\\Gen\\font\\SimHei.ttf"  # 替换成你的中文字体文件路径

# 加载中文字体
myfont = FontProperties(fname=font_path)

ids = np.random.randint(len(data))

image = data[ids]
out = engine.predict(image)[0]

def show_prediction(out, image):
    gt = image.split('/')[-1].split('.')[0]
    imagePIL = Image.open(image).convert('L')

    pred = ''
    then = 0
    for x in out:
        if then != x:
            if x > 0 :
                pred += mapping_inv[x]
        then = x

    plt.figure(figsize=(15, 12))
    img_array = np.asarray(imagePIL)
    plt.title(f'Ground Truth - {gt} || Prediction - {pred}',fontproperties=myfont)
    plt.axis('off')
    plt.imshow(img_array,cmap='gray')
    
show_prediction(out, image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 # 加载中文字体
#       9 myfont = FontProperties(fname=font_path)
# ---> 11 ids = np.random.randint(len(data))
#      13 image = data[ids]
#      14 out = engine.predict(image)[0]
#
# NameError: name 'data' is not defined

# %%
saving = {'state_dict':engine.model.state_dict(),
          'optimizer':engine.optimizer.state_dict(),
         'mapping':mapping,
         'mapping_inv':mapping_inv}
torch.save(saving, './model/chinese_model.pth')
