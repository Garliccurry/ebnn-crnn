# %%
# -*- coding: utf-8 -*-
import os
import glob 
import pandas as pd
import string
import collections
from tqdm import tqdm
from PIL import Image
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pad_sequence
import torch.nn.functional as F
import torchvision.transforms as T
from torch.utils.data import DataLoader
import torch.optim as optim
from Gen.chinese_data import common_chinese_chars
# Out:
# 407

# %%
data = glob.glob(os.path.join(r'F:\project\python\OCR\Recognize\data\chinese\5rand7size30font3', '*.png'))
path = r'F:\project\python\OCR\Recognize\data\chinese\5rand7size30font3'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
DEVICE
# Out:
# device(type='cuda')

# %%
all_letters = common_chinese_chars
mapping = {}
mapping_inv = {}
i = 1
for x in all_letters:
    mapping[x] = i
    mapping_inv[i] = x
    i += 1

# %%
num_class = len(mapping)

# %%
mapping
# Out:
# {'的': 1,
#  '一': 2,
#  '是': 3,
#  '了': 4,
#  '我': 5,
#  '不': 6,
#  '在': 7,
#  '人': 8,
#  '们': 9,
#  '有': 10,
#  '来': 11,
#  '他': 12,
#  '这': 13,
#  '上': 14,
#  '着': 15,
#  '个': 16,
#  '为': 17,
#  '到': 18,
#  '说': 19,
#  '要': 20,
#  '就': 21,
#  '出': 22,
#  '会': 23,
#  '可': 24,
#  '也': 25,
#  '你': 26,
#  '对': 27,
#  '生': 28,
#  '能': 29,
#  '而': 30,
#  '子': 31,
#  '那': 32,
#  '得': 33,
#  '于': 34,
#  '下': 35,
#  '自': 36,
#  '之': 37,
#  '年': 38,
#  '过': 39,
#  '发': 40,
#  '后': 41,
#  '作': 42,
#  '里': 43,
#  '用': 44,
#  '道': 45,
#  '行': 46,
#  '所': 47,
#  '然': 48,
#  '家': 49,
#  '种': 50,
#  '事': 51,
#  '成': 52,
#  '方': 53,
#  '多': 54,
#  '经': 55,
#  '么': 56,
#  '去': 57,
#  '法': 58,
#  '学': 59,
#  '如': 60,
#  '都': 61,
#  '同': 62,
#  '现': 63,
#  '当': 64,
#  '没': 65,
#  '动': 66,
#  '面': 67,
#  '起': 68,
#  '看': 69,
#  '定': 70,
#  '天': 71,
#  '分': 72,
#  '还': 73,
#  '进': 74,
#  '好': 75,
#  '小': 76,
#  '部': 77,
#  '其': 78,
#  '些': 79,
#  '主': 80,
#  '样': 81,
#  '理': 82,
#  '心': 83,
#  '她': 84,
#  '本': 85,
#  '前': 86,
#  '开': 87,
#  '但': 88,
#  '因': 89,
#  '只': 90,
#  '从': 91,
#  '想': 92,
#  '实': 93,
#  '日': 94,
#  '军': 95,
#  '者': 96,
#  '意': 97,
#  '无': 98,
#  '力': 99,
#  '它': 100,
#  '与': 101,
#  '长': 102,
#  '把': 103,
#  '机': 104,
#  '十': 105,
#  '民': 106,
#  '第': 107,
#  '公': 108,
#  '此': 109,
#  '已': 110,
#  '工': 111,
#  '使': 112,
#  '情': 113,
#  '明': 114,
#  '性': 115,
#  '知': 116,
#  '全': 117,
#  '三': 118,
#  '又': 119,
#  '关': 120,
#  '点': 121,
#  '正': 122,
#  '业': 123,
#  '外': 124,
#  '将': 125,
#  '两': 126,
#  '高': 127,
#  '间': 128,
#  '由': 129,
#  '问': 130,
#  '很': 131,
#  '最': 132,
#  '重': 133,
#  '并': 134,
#  '物': 135,
#  '手': 136,
#  '应': 137,
#  '战': 138,
#  '向': 139,
#  '头': 140,
#  '文': 141,
#  '体': 142,
#  '政': 143,
#  '美': 144,
#  '相': 145,
#  '见': 146,
#  '被': 147,
#  '利': 148,
#  '什': 149,
#  '二': 150,
#  '等': 151,
#  '产': 152,
#  '或': 153,
#  '新': 154,
#  '己': 155,
#  '制': 156,
#  '身': 157,
#  '果': 158,
#  '加': 159,
#  '西': 160,
#  '斯': 161,
#  '月': 162,
#  '话': 163,
#  '合': 164,
#  '回': 165,
#  '特': 166,
#  '代': 167,
#  '内': 168,
#  '信': 169,
#  '表': 170,
#  '化': 171,
#  '老': 172,
#  '给': 173,
#  '世': 174,
#  '位': 175,
#  '次': 176,
#  '度': 177,
#  '门': 178,
#  '任': 179,
#  '常': 180,
#  '先': 181,
#  '海': 182,
#  '通': 183,
#  '教': 184,
#  '儿': 185,
#  '原': 186,
#  '东': 187,
#  '声': 188,
#  '提': 189,
#  '立': 190,
#  '及': 191,
#  '比': 192,
#  '员': 193,
#  '解': 194,
#  '水': 195,
#  '名': 196,
#  '真': 197,
#  '论': 198,
#  '处': 199,
#  '走': 200,
#  '义': 201,
#  '各': 202,
#  '入': 203,
#  '几': 204,
#  '口': 205,
#  '认': 206,
#  '条': 207,
#  '平': 208,
#  '系': 209,
#  '气': 210,
#  '题': 211,
#  '活': 212,
#  '尔': 213,
#  '更': 214,
#  '别': 215,
#  '打': 216,
#  '女': 217,
#  '变': 218,
#  '四': 219,
#  '神': 220,
#  '总': 221,
#  '何': 222,
#  '电': 223,
#  '数': 224,
#  '安': 225,
#  '少': 226,
#  '报': 227,
#  '才': 228,
#  '结': 229,
#  '反': 230,
#  '受': 231,
#  '目': 232,
#  '太': 233,
#  '量': 234,
#  '再': 235,
#  '感': 236,
#  '建': 237,
#  '务': 238,
#  '做': 239,
#  '接': 240,
#  '必': 241,
#  '场': 242,
#  '件': 243,
#  '计': 244,
#  '管': 245,
#  '期': 246,
#  '市': 247,
#  '直': 248,
#  '德': 249,
#  '资': 250,
#  '命': 251,
#  '山': 252,
#  '金': 253,
#  '指': 254,
#  '克': 255,
#  '许': 256,
#  '统': 257,
#  '区': 258,
#  '保': 259,
#  '至': 260,
#  '队': 261,
#  '形': 262,
#  '社': 263,
#  '便': 264,
#  '空': 265,
#  '决': 266,
#  '治': 267,
#  '展': 268,
#  '马': 269,
#  '科': 270,
#  '司': 271,
#  '五': 272,
#  '基': 273,
#  '眼': 274,
#  '书': 275,
#  '非': 276,
#  '则': 277,
#  '听': 278,
#  '白': 279,
#  '却': 280,
#  '界': 281,
#  '达': 282,
#  '光': 283,
#  '放': 284,
#  '强': 285,
#  '即': 286,
#  '像': 287,
#  '难': 288,
#  '且': 289,
#  '权': 290,
#  '思': 291,
#  '王': 292,
#  '象': 293,
#  '完': 294,
#  '设': 295,
#  '式': 296,
#  '色': 297,
#  '路': 298,
#  '记': 299,
#  '南': 300,
#  '品': 301,
#  '住': 302,
#  '告': 303,
#  '类': 304,
#  '求': 305,
#  '据': 306,
#  '程': 307,
#  '北': 308,
#  '边': 309,
#  '死': 310,
#  '张': 311,
#  '该': 312,
#  '交': 313,
#  '规': 314,
#  '万': 315,
#  '取': 316,
#  '拉': 317,
#  '格': 318,
#  '望': 319,
#  '觉': 320,
#  '术': 321,
#  '领': 322,
#  '共': 323,
#  '确': 324,
#  '传': 325,
#  '师': 326,
#  '观': 327,
#  '清': 328,
#  '今': 329,
#  '切': 330,
#  '院': 331,
#  '让': 332,
#  '识': 333,
#  '候': 334,
#  '带': 335,
#  '导': 336,
#  '争': 337,
#  '运': 338,
#  '笑': 339,
#  '飞': 340,
#  '风': 341,
#  '步': 342,
#  '改': 343,
#  '收': 344,
#  '根': 345,
#  '干': 346,
#  '造': 347,
#  '言': 348,
#  '联': 349,
#  '持': 350,
#  '组': 351,
#  '每': 352,
#  '济': 353,
#  '车': 354,
#  '亲': 355,
#  '极': 356,
#  '林': 357,
#  '服': 358,
#  '快': 359,
#  '办': 360,
#  '议': 361,
#  '往': 362,
#  '元': 363,
#  '英': 364,
#  '士': 365,
#  '证': 366,
#  '近': 367,
#  '律': 368,
#  '般': 369,
#  '尼': 370,
#  '构': 371,
#  '影': 372,
#  '层': 373,
#  '器': 374,
#  '效': 375,
#  '调': 376,
#  '团': 377,
#  '研': 378,
#  '超': 379,
#  '帮': 380,
#  '置': 381,
#  '积': 382,
#  '整': 383,
#  '罗': 384,
#  '参': 385,
#  '备': 386,
#  '维': 387,
#  '础': 388,
#  '值': 389,
#  '温': 390,
#  '落': 391,
#  '职': 392,
#  '流': 393,
#  '连': 394,
#  '镇': 395,
#  '互': 396,
#  '较': 397,
#  '华': 398,
#  '显': 399,
#  '刚': 400,
#  '标': 401,
#  '准': 402,
#  '攻': 403,
#  '推': 404,
#  '施': 405,
#  '究': 406,
#  '扩': 407}

# %%
mapping_inv
# Out:
# {1: '的',
#  2: '一',
#  3: '是',
#  4: '了',
#  5: '我',
#  6: '不',
#  7: '在',
#  8: '人',
#  9: '们',
#  10: '有',
#  11: '来',
#  12: '他',
#  13: '这',
#  14: '上',
#  15: '着',
#  16: '个',
#  17: '为',
#  18: '到',
#  19: '说',
#  20: '要',
#  21: '就',
#  22: '出',
#  23: '会',
#  24: '可',
#  25: '也',
#  26: '你',
#  27: '对',
#  28: '生',
#  29: '能',
#  30: '而',
#  31: '子',
#  32: '那',
#  33: '得',
#  34: '于',
#  35: '下',
#  36: '自',
#  37: '之',
#  38: '年',
#  39: '过',
#  40: '发',
#  41: '后',
#  42: '作',
#  43: '里',
#  44: '用',
#  45: '道',
#  46: '行',
#  47: '所',
#  48: '然',
#  49: '家',
#  50: '种',
#  51: '事',
#  52: '成',
#  53: '方',
#  54: '多',
#  55: '经',
#  56: '么',
#  57: '去',
#  58: '法',
#  59: '学',
#  60: '如',
#  61: '都',
#  62: '同',
#  63: '现',
#  64: '当',
#  65: '没',
#  66: '动',
#  67: '面',
#  68: '起',
#  69: '看',
#  70: '定',
#  71: '天',
#  72: '分',
#  73: '还',
#  74: '进',
#  75: '好',
#  76: '小',
#  77: '部',
#  78: '其',
#  79: '些',
#  80: '主',
#  81: '样',
#  82: '理',
#  83: '心',
#  84: '她',
#  85: '本',
#  86: '前',
#  87: '开',
#  88: '但',
#  89: '因',
#  90: '只',
#  91: '从',
#  92: '想',
#  93: '实',
#  94: '日',
#  95: '军',
#  96: '者',
#  97: '意',
#  98: '无',
#  99: '力',
#  100: '它',
#  101: '与',
#  102: '长',
#  103: '把',
#  104: '机',
#  105: '十',
#  106: '民',
#  107: '第',
#  108: '公',
#  109: '此',
#  110: '已',
#  111: '工',
#  112: '使',
#  113: '情',
#  114: '明',
#  115: '性',
#  116: '知',
#  117: '全',
#  118: '三',
#  119: '又',
#  120: '关',
#  121: '点',
#  122: '正',
#  123: '业',
#  124: '外',
#  125: '将',
#  126: '两',
#  127: '高',
#  128: '间',
#  129: '由',
#  130: '问',
#  131: '很',
#  132: '最',
#  133: '重',
#  134: '并',
#  135: '物',
#  136: '手',
#  137: '应',
#  138: '战',
#  139: '向',
#  140: '头',
#  141: '文',
#  142: '体',
#  143: '政',
#  144: '美',
#  145: '相',
#  146: '见',
#  147: '被',
#  148: '利',
#  149: '什',
#  150: '二',
#  151: '等',
#  152: '产',
#  153: '或',
#  154: '新',
#  155: '己',
#  156: '制',
#  157: '身',
#  158: '果',
#  159: '加',
#  160: '西',
#  161: '斯',
#  162: '月',
#  163: '话',
#  164: '合',
#  165: '回',
#  166: '特',
#  167: '代',
#  168: '内',
#  169: '信',
#  170: '表',
#  171: '化',
#  172: '老',
#  173: '给',
#  174: '世',
#  175: '位',
#  176: '次',
#  177: '度',
#  178: '门',
#  179: '任',
#  180: '常',
#  181: '先',
#  182: '海',
#  183: '通',
#  184: '教',
#  185: '儿',
#  186: '原',
#  187: '东',
#  188: '声',
#  189: '提',
#  190: '立',
#  191: '及',
#  192: '比',
#  193: '员',
#  194: '解',
#  195: '水',
#  196: '名',
#  197: '真',
#  198: '论',
#  199: '处',
#  200: '走',
#  201: '义',
#  202: '各',
#  203: '入',
#  204: '几',
#  205: '口',
#  206: '认',
#  207: '条',
#  208: '平',
#  209: '系',
#  210: '气',
#  211: '题',
#  212: '活',
#  213: '尔',
#  214: '更',
#  215: '别',
#  216: '打',
#  217: '女',
#  218: '变',
#  219: '四',
#  220: '神',
#  221: '总',
#  222: '何',
#  223: '电',
#  224: '数',
#  225: '安',
#  226: '少',
#  227: '报',
#  228: '才',
#  229: '结',
#  230: '反',
#  231: '受',
#  232: '目',
#  233: '太',
#  234: '量',
#  235: '再',
#  236: '感',
#  237: '建',
#  238: '务',
#  239: '做',
#  240: '接',
#  241: '必',
#  242: '场',
#  243: '件',
#  244: '计',
#  245: '管',
#  246: '期',
#  247: '市',
#  248: '直',
#  249: '德',
#  250: '资',
#  251: '命',
#  252: '山',
#  253: '金',
#  254: '指',
#  255: '克',
#  256: '许',
#  257: '统',
#  258: '区',
#  259: '保',
#  260: '至',
#  261: '队',
#  262: '形',
#  263: '社',
#  264: '便',
#  265: '空',
#  266: '决',
#  267: '治',
#  268: '展',
#  269: '马',
#  270: '科',
#  271: '司',
#  272: '五',
#  273: '基',
#  274: '眼',
#  275: '书',
#  276: '非',
#  277: '则',
#  278: '听',
#  279: '白',
#  280: '却',
#  281: '界',
#  282: '达',
#  283: '光',
#  284: '放',
#  285: '强',
#  286: '即',
#  287: '像',
#  288: '难',
#  289: '且',
#  290: '权',
#  291: '思',
#  292: '王',
#  293: '象',
#  294: '完',
#  295: '设',
#  296: '式',
#  297: '色',
#  298: '路',
#  299: '记',
#  300: '南',
#  301: '品',
#  302: '住',
#  303: '告',
#  304: '类',
#  305: '求',
#  306: '据',
#  307: '程',
#  308: '北',
#  309: '边',
#  310: '死',
#  311: '张',
#  312: '该',
#  313: '交',
#  314: '规',
#  315: '万',
#  316: '取',
#  317: '拉',
#  318: '格',
#  319: '望',
#  320: '觉',
#  321: '术',
#  322: '领',
#  323: '共',
#  324: '确',
#  325: '传',
#  326: '师',
#  327: '观',
#  328: '清',
#  329: '今',
#  330: '切',
#  331: '院',
#  332: '让',
#  333: '识',
#  334: '候',
#  335: '带',
#  336: '导',
#  337: '争',
#  338: '运',
#  339: '笑',
#  340: '飞',
#  341: '风',
#  342: '步',
#  343: '改',
#  344: '收',
#  345: '根',
#  346: '干',
#  347: '造',
#  348: '言',
#  349: '联',
#  350: '持',
#  351: '组',
#  352: '每',
#  353: '济',
#  354: '车',
#  355: '亲',
#  356: '极',
#  357: '林',
#  358: '服',
#  359: '快',
#  360: '办',
#  361: '议',
#  362: '往',
#  363: '元',
#  364: '英',
#  365: '士',
#  366: '证',
#  367: '近',
#  368: '律',
#  369: '般',
#  370: '尼',
#  371: '构',
#  372: '影',
#  373: '层',
#  374: '器',
#  375: '效',
#  376: '调',
#  377: '团',
#  378: '研',
#  379: '超',
#  380: '帮',
#  381: '置',
#  382: '积',
#  383: '整',
#  384: '罗',
#  385: '参',
#  386: '备',
#  387: '维',
#  388: '础',
#  389: '值',
#  390: '温',
#  391: '落',
#  392: '职',
#  393: '流',
#  394: '连',
#  395: '镇',
#  396: '互',
#  397: '较',
#  398: '华',
#  399: '显',
#  400: '刚',
#  401: '标',
#  402: '准',
#  403: '攻',
#  404: '推',
#  405: '施',
#  406: '究',
#  407: '扩'}

# %%
images = []
labels = []
datas = collections.defaultdict(list)
for d in data:
    x = d.split('\\')[-1]

    datas['image'].append(x)

    datas['label'].append([mapping[i] for i in x.split('.')[0]])
df = pd.DataFrame(datas)
df.head()
# Out:
#          image                              label
# 0    一物许高运.png            [2, 135, 256, 127, 338]
# 1    一说有直实.png               [2, 19, 10, 248, 93]
# 2    万进理与温.png            [315, 74, 82, 101, 390]
# 3    上己维立作.png            [14, 155, 387, 190, 42]
# 4  上常全造解方运.png  [14, 180, 117, 347, 194, 53, 338]

# %%
datas
# Out:
# defaultdict(list,
#             {'image': ['一物许高运.png',
#               '一说有直实.png',
#               '万进理与温.png',
#               '上己维立作.png',
#               '上常全造解方运.png',
#               '上显对重参明义.png',
#               '下维被立工.png',
#               '不动期推问持.png',
#               '不帮加式理无.png',
#               '与体教标却.png',
#               '与落来通个.png',
#               '且北业常互如.png',
#               '且明带立放.png',
#               '且观市帮件是.png',
#               '且部然神义.png',
#               '世点少民且效必.png',
#               '世由效切儿.png',
#               '世重眼等所名笑.png',
#               '业在回已量术北.png',
#               '业流求识受又.png',
#               '业色高与市比.png',
#               '业观少提院老新.png',
#               '东给才着真王是.png',
#               '两今镇了及还.png',
#               '两十像认维口.png',
#               '两名权色学器扩.png',
#               '两收没认近他.png',
#               '个步目则总.png',
#               '个里定扩向罗.png',
#               '为两只是做施.png',
#               '为它各场战近.png',
#               '为调死资形使.png',
#               '么告被气便南交.png',
#               '义分调导认思行.png',
#               '义过展该少那建.png',
#               '之但行标求现.png',
#               '之候重望般.png',
#               '之全造所道会上.png',
#               '之定术张快极.png',
#               '之条往子间帮着.png',
#               '之气英也手即代.png',
#               '之水想体超思.png',
#               '也关感小济.png',
#               '书原应金常你的.png',
#               '书来马海施山么.png',
#               '书识必近分如三.png',
#               '了理她张但四位.png',
#               '了白你备信的置.png',
#               '了管家拉林起.png',
#               '了觉比东步.png',
#               '争代全开长度.png',
#               '争们立能太一五.png',
#               '争让治议即建师.png',
#               '事保何报学.png',
#               '事信民五全.png',
#               '事影动科马.png',
#               '二关她文论动.png',
#               '二化过手根往.png',
#               '二尼刚快或很.png',
#               '二空导自使题.png',
#               '于亲改少月.png',
#               '于得常变北.png',
#               '互再帮总子果看.png',
#               '互名极报种南许.png',
#               '互安动系论设.png',
#               '互识保北表.png',
#               '五过因导二建死.png',
#               '些向积导很总格.png',
#               '些战之市积.png',
#               '交想刚思万.png',
#               '交近法联产头互.png',
#               '产德生主同即平.png',
#               '产果新形通.png',
#               '产进加则性.png',
#               '亲张设思走前资.png',
#               '亲标告加而看.png',
#               '亲车特南所.png',
#               '人类命计分日.png',
#               '什之它工安员所.png',
#               '什刚温济扩点.png',
#               '什在华气治.png',
#               '什外受般入传.png',
#               '什础什真组流且.png',
#               '什究且德程.png',
#               '今设推没人.png',
#               '从力出机西本.png',
#               '从同物里无本.png',
#               '从已里管让进.png',
#               '从直品他收.png',
#               '他万务完清日做.png',
#               '他之规会去.png',
#               '他见位会超.png',
#               '代再础程张社.png',
#               '代接非理员即.png',
#               '代用争空各.png',
#               '代眼统于备们情.png',
#               '件今而住老较特.png',
#               '件作三加她必见.png',
#               '任子种金长.png',
#               '会步到领又政.png',
#               '传发眼数学领.png',
#               '传快流们却管及.png',
#               '但当个设可月.png',
#               '但用听克住.png',
#               '但知气好看度化.png',
#               '但神扩理职.png',
#               '住什一必民名后.png',
#               '住别英士得.png',
#               '住快了特政.png',
#               '体二难流利不.png',
#               '体克走干领.png',
#               '体并收打结.png',
#               '何信笑参小实.png',
#               '何题业法近往学.png',
#               '作落化到步由.png',
#               '作连觉万德.png',
#               '你影将你相西.png',
#               '使西期路认义那.png',
#               '便山加亲美备.png',
#               '保力术公林.png',
#               '保数两许说.png',
#               '保理道内应.png',
#               '保让镇点变候能.png',
#               '信场第她服内电.png',
#               '信小四色月难.png',
#               '信极与笑可近化.png',
#               '信根同切由则.png',
#               '候报情真共会场.png',
#               '候行事往产.png',
#               '值住业队里.png',
#               '值基头自求无.png',
#               '值战影由制积言.png',
#               '值着着直场且.png',
#               '做备争风受品英.png',
#               '做指等光笑究领.png',
#               '做罗候白华团.png',
#               '像在路向感.png',
#               '像很民让组.png',
#               '像至收先流打清.png',
#               '儿度士同也团置.png',
#               '元年至由打.png',
#               '先命传气何改能.png',
#               '先多死白记科通.png',
#               '光南力物象及.png',
#               '光究做备日思.png',
#               '光能月这自动.png',
#               '全刚着就种三.png',
#               '全合样必民现共.png',
#               '全研受研她通师.png',
#               '公师近快再改刚.png',
#               '公等司面调将.png',
#               '共总边系身.png',
#               '共新全议施济.png',
#               '关们式能业向象.png',
#               '关老就口罗直刚.png',
#               '其何反正准前工.png',
#               '其学关造且.png',
#               '其所工改制给.png',
#               '其极更两却意见.png',
#               '内别儿较给及究.png',
#               '内工山主计本.png',
#               '内来交院信海.png',
#               '再者第此就德走.png',
#               '军这使头清传.png',
#               '决文础院世因.png',
#               '决权干我要.png',
#               '决构置论风.png',
#               '决气先华后见.png',
#               '准保相种攻路.png',
#               '准利你准心.png',
#               '准或证扩式于当.png',
#               '准研也也别.png',
#               '准类调士马联.png',
#               '几万自记最家识.png',
#               '几人望关却.png',
#               '几合然也条.png',
#               '几子重听放运.png',
#               '几而话将流同识.png',
#               '几里电样识.png',
#               '出入长的安新.png',
#               '出每影刚是术.png',
#               '出至从受近实.png',
#               '分而下同部就.png',
#               '分造马士院.png',
#               '切亲反却司互程.png',
#               '切反证义机题.png',
#               '切应期让几平.png',
#               '切林战器光清好.png',
#               '切记切体证.png',
#               '则收量样运战.png',
#               '刚化且真气.png',
#               '刚学女也相.png',
#               '刚往值第学.png',
#               '刚手组品想三.png',
#               '利儿他备她名金.png',
#               '利思显去反.png',
#               '利金安想我服气.png',
#               '利非可车础.png',
#               '别件切还身万明.png',
#               '别参力如导.png',
#               '到动要保些教王.png',
#               '到学外告开.png',
#               '到感切究相你.png',
#               '到经流力话推家.png',
#               '到议切运任.png',
#               '制且间生流社.png',
#               '制东亲里制身.png',
#               '制比置德安.png',
#               '前好流去上超.png',
#               '前落意清行象第.png',
#               '力十因道二改.png',
#               '力置现打金种.png',
#               '办形于主部.png',
#               '办着同应如少究.png',
#               '加备小代再.png',
#               '加话式给说出在.png',
#               '务个员动队白.png',
#               '务分切军他更.png',
#               '务处然收要业超.png',
#               '务尔取月直强.png',
#               '务笑结式结用.png',
#               '动下反命标放.png',
#               '动做教作争意整.png',
#               '动尔保度用而.png',
#               '化利济干有组.png',
#               '化服格电却行果.png',
#               '北往张手及.png',
#               '北起服改通.png',
#               '北非这生条.png',
#               '区受门子市据设.png',
#               '区常活样的.png',
#               '区被心放备提.png',
#               '区重思车十给.png',
#               '区非这行便言.png',
#               '十小飞最事月女.png',
#               '十议团子却.png',
#               '华亲强实论.png',
#               '华行世清有种.png',
#               '华都理至今.png',
#               '南济究四改合.png',
#               '即使流正条就.png',
#               '即刚生边王子.png',
#               '即效规性斯路格.png',
#               '却住她边明.png',
#               '却林指司先战.png',
#               '却类类象克能服.png',
#               '去共的人器度.png',
#               '去干在你十各治.png',
#               '去成较才头马.png',
#               '去然攻些难你界.png',
#               '去老效超受没神.png',
#               '参带能体路保二.png',
#               '又住告之面.png',
#               '又收着尔团.png',
#               '及出十民镇运求.png',
#               '及化性等团知本.png',
#               '及在真完西那多.png',
#               '及目发她运种.png',
#               '及证间动华身万.png',
#               '反建表白权.png',
#               '反战两有后带.png',
#               '反次世成们儿全.png',
#               '反而互更笑.png',
#               '发下现改过式.png',
#               '发原就做它长斯.png',
#               '发司数工科都落.png',
#               '发头取方少所间.png',
#               '发维太话积.png',
#               '发这目打直量.png',
#               '取小每气知间.png',
#               '受几记品东己知.png',
#               '受取比听亲代感.png',
#               '变十极构安变.png',
#               '变部开再原情.png',
#               '口内会则收活.png',
#               '口系日联用.png',
#               '只光当求识.png',
#               '只内些候还带.png',
#               '只方被十组发.png',
#               '只无新通总.png',
#               '可在根并本界.png',
#               '司别但明分住.png',
#               '司往英样小看从.png',
#               '司施书十务克.png',
#               '各世上原四什层.png',
#               '各月发每言用性.png',
#               '各权管民提今当.png',
#               '各设理斯求加极.png',
#               '合道不管家进体.png',
#               '同此权才系机.png',
#               '同调权其维.png',
#               '后三些力西东较.png',
#               '后信治年律空义.png',
#               '后像话风世.png',
#               '后常身多北.png',
#               '后张名之它施.png',
#               '向值格前次.png',
#               '向职山生万决还.png',
#               '向观础士而为比.png',
#               '听内领着女队.png',
#               '听动攻要准.png',
#               '告马律基务达子.png',
#               '员眼个础电张军.png',
#               '命品年命应气.png',
#               '命能王义多.png',
#               '品为个道议.png',
#               '器分使造些张.png',
#               '器回市提办.png',
#               '回产一如市然.png',
#               '回性美强识她.png',
#               '回资办高白成.png',
#               '因头道别性体年.png',
#               '因山代日如空.png',
#               '因施把都没电象.png',
#               '因罗由实别次.png',
#               '因面整极世很.png',
#               '团代领界导科.png',
#               '团较持师更由流.png',
#               '团难整原做.png',
#               '在共帮学正.png',
#               '在对连显车.png',
#               '在并维儿已林过.png',
#               '在推明风月死备.png',
#               '在还候学物连.png',
#               '在道定展本一.png',
#               '场些边没合形领.png',
#               '场员从性士.png',
#               '场机建业有方.png',
#               '士听却东果备.png',
#               '士术空场构更.png',
#               '士机统性般能尔.png',
#               '士边太不对.png',
#               '声师力真情.png',
#               '声种等流根求多.png',
#               '处提山别神元.png',
#               '处显打队少.png',
#               '备业万司或.png',
#               '备住推研到.png',
#               '备几体天不法.png',
#               '外往四每物.png',
#               '外指处罗文去互.png',
#               '多目持及山给.png',
#               '天五张知山给等.png',
#               '天出自认子.png',
#               '天命部受老.png',
#               '天话来得构何林.png',
#               '太女及多及.png',
#               '太进究美交刚.png',
#               '头出般金车互天.png',
#               '女代神至干积.png',
#               '女文场务识建成.png',
#               '女础儿解正.png',
#               '她则器长主与认.png',
#               '她市在美往服运.png',
#               '好工科子工管里.png',
#               '好进相至发前非.png',
#               '如些计先此.png',
#               '如及如政强.png',
#               '如民化相空利然.png',
#               '如金直格们成.png',
#               '子法他听拉.png',
#               '子运发求它同外.png',
#               '学直林才许.png',
#               '它机产显死看.png',
#               '它根后之东同己.png',
#               '它部非从合快打.png',
#               '安内共格罗其运.png',
#               '安口真统研.png',
#               '安如都放想.png',
#               '完神指情是点.png',
#               '完飞什高实镇.png',
#               '定教什感准解.png',
#               '定整看界感明也.png',
#               '实听导行张高并.png',
#               '实太本然拉.png',
#               '实民无起根设取.png',
#               '家作义化化.png',
#               '家观把影手而.png',
#               '家还成还互.png',
#               '对或市全经分.png',
#               '对放经建它务.png',
#               '对期治开成.png',
#               '对连交受元.png',
#               '将东门论用.png',
#               '将命山总西.png',
#               '小关器运重区解.png',
#               '小文导走反走确.png',
#               '小眼二向北南死.png',
#               '小话南连克放.png',
#               '少导作它见要.png',
#               '少山信改太.png',
#               '少权步般职告.png',
#               '少联达成及较形.png',
#               '少许水会出小四.png',
#               '少道天职证知亲.png',
#               '尔北条部动光说.png',
#               '尔命看法情把真.png',
#               '尔理克镇导.png',
#               '就原声回着基连.png',
#               '就构金及放.png',
#               '尼美条后说起各.png',
#               '层学上成言.png',
#               '层物理所议.png',
#               '层真及特对华.png',
#               '展回然年将.png',
#               '展团对天建主立.png',
#               '展定气得很件.png',
#               '展白华儿往文.png',
#               '展知则你向思加.png',
#               '展超治事成些流.png',
#               '山三体白得研.png',
#               '山听至不克治把.png',
#               '山士她水成马.png',
#               '山真证运同头.png',
#               '山这动更导发.png',
#               '工员命新世电.png',
#               '己声道能部程镇.png',
#               '己知发们风术.png',
#               '己那尔超二则先.png',
#               '已带加再么.png',
#               '已式现北神神.png',
#               '已显海英并果.png',
#               '已础感团北有.png',
#               '已空制将做影组.png',
#               '市儿电外德.png',
#               '市被眼重向次.png',
#               '师即很团么职马.png',
#               '师无反已却.png',
#               '师活门点一起标.png',
#               '带切几军些据.png',
#               '带参活设议.png',
#               '带张走面展.png',
#               '帮此也次二形.png',
#               '常持正美活四日.png',
#               '常资应张职社造.png',
#               '年关变人克司比.png',
#               '年四器力传就.png',
#               '年得及么师元.png',
#               '并制年攻头.png',
#               '并如眼边因变.png',
#               '并少老情品.png',
#               '度这几士工就.png',
#               '建你知就落流.png',
#               '建队应电持.png',
#               '开施理共场.png',
#               '开法来在思像.png',
#               '式点济南合美.png',
#               '张交望他之.png',
#               '张难关英础再女.png',
#               '强交都口真程统.png',
#               '强体定并最张.png',
#               '强它则证职真.png',
#               '强样温太进参.png',
#               '强研种并死.png',
#               '强程常已程.png',
#               '当显将造么们.png',
#               '形之清科做.png',
#               '形就后重如老.png',
#               '形平高入空被.png',
#               '形生造军效物领.png',
#               '形知每信门.png',
#               '影山较由水山王.png',
#               '影格们参期.png',
#               '往体何走亲区置.png',
#               '往子月斯治.png',
#               '很向动最计.png',
#               '很温民收第影头.png',
#               '很系会还办什.png',
#               '律却次种步.png',
#               '律反心将该保说.png',
#               '律科想往影.png',
#               '律空规发准.png',
#               '得只步报拉务.png',
#               '得实罗再术.png',
#               '德万相干其她.png',
#               '德取议类气该.png',
#               '德尔必础是外.png',
#               '德改面让设.png',
#               '德明海主飞.png',
#               '德重明达建.png',
#               '必却治义主.png',
#               '必尔她工从准儿.png',
#               '快于思向持.png',
#               '思色即设命亲影.png',
#               '性最给四儿.png',
#               '性系再实维与.png',
#               '性话调等区论为.png',
#               '总建后目础的.png',
#               '情也互空为每.png',
#               '情真管十世组.png',
#               '想门作与格政.png',
#               '意义再济方现女.png',
#               '意它导题门.png',
#               '意数去觉气指.png',
#               '感法开互基.png',
#               '感的尼平制.png',
#               '成任开部然要问.png',
#               '成笑调一接她问.png',
#               '我个较何保则望.png',
#               '我南第快被车积.png',
#               '我林造司且流.png',
#               '或力常书从军.png',
#               '或期提家强观.png',
#               '战常们女太变.png',
#               '战达动先据想.png',
#               '战难程今命气.png',
#               '所各于究超条.png',
#               '所尔落可业色于.png',
#               '所接并对建及三.png',
#               '所果打又望.png',
#               '手今收取资都头.png',
#               '打在完手对.png',
#               '打据空少得里化.png',
#               '扩步英根结.png',
#               '扩组打处色.png',
#               '把决干不也识.png',
#               '把将们道可果.png',
#               '把治路反影.png',
#               '把程政告办是已.png',
#               '报家义权果几.png',
#               '报死队高义.png',
#               '报管女德书.png',
#               '拉张传拉层化没.png',
#               '持他结边即.png',
#               '持构度女关或五.png',
#               '持通非次证望更.png',
#               '指口式力只王会.png',
#               '指所面科部者.png',
#               '指科边到次.png',
#               '据面员外目克.png',
#               '据风式死体因.png',
#               '接共们美重较.png',
#               '接开去题于得当.png',
#               '接德识儿根.png',
#               '推罗资干那开果.png',
#               '提分全条完.png',
#               '提本服直听层去.png',
#               '攻住场或说取动.png',
#               '攻清克联相候.png',
#               '放会军英些.png',
#               '放便济科完.png',
#               '放公华收英整.png',
#               '放在走帮老值感.png',
#               '政与最业者资.png',
#               '政前想传战.png',
#               '政家设运儿.png',
#               '政社场得指结之.png',
#               '政资何把达.png',
#               '效难等非太显不.png',
#               '教先都器定为报.png',
#               '教分多达市别科.png',
#               '教山步便么些.png',
#               '教常传当教.png',
#               '教拉对格什法金.png',
#               '教持几解研.png',
#               '教种儿总笑或.png',
#               '教维定科数总.png',
#               '教非学标边走全.png',
#               '整取开互候会镇.png',
#               '文与求求英候.png',
#               '文两性么强.png',
#               '文济刚望小.png',
#               '文见元东二许.png',
#               '文过王报济门.png',
#               '新五来女代第家.png',
#               '新候资点里运.png',
#               '新光道比入文.png',
#               '新流认完或美里.png',
#               '方经事门当进.png',
#               '方风决那改.png',
#               '施头很年海目院.png',
#               '施安美你之值.png',
#               '无张确近月.png',
#               '无根都望先眼.png',
#               '日儿感备之加的.png',
#               '日连活切超队.png',
#               '明体由被收上.png',
#               '明儿维太天通.png',
#               '是必道展张则少.png',
#               '是西学参克.png',
#               '显任太力分.png',
#               '显司才她便团发.png',
#               '显直无口风.png',
#               '显真建可备使.png',
#               '显积求证更便服.png',
#               '显职济院北.png',
#               '显走导镇制即从.png',
#               '显走最色月术.png',
#               '更区亲点题回学.png',
#               '更让西但光儿互.png',
#               '最定共元等到.png',
#               '最方当工社.png',
#               '最长切机确.png',
#               '最高第万很等.png',
#               '月交即础高.png',
#               '月取指代备类.png',
#               '月统较见开任.png',
#               '月许构长并.png',
#               '月金强经观么声.png',
#               '有关目意同老.png',
#               '有计每西结关.png',
#               '有车克些公.png',
#               '有面文切色.png',
#               '服全代论英产决.png',
#               '服很认还强.png',
#               '服边望此显由.png',
#               '望今才话德现.png',
#               '望又觉目法.png',
#               '望员形安扩员常.png',
#               '望因同信扩变.png',
#               '期其攻么知.png',
#               '期十员工至你.png',
#               '期建镇原运取我.png',
#               '期步政命就气从.png',
#               '本学联再运社加.png',
#               '本才且问干情.png',
#               '术保意科落.png',
#               '术觉色同改.png',
#               '机又好设常方.png',
#               '机身外心资.png',
#               '权成这场得准住.png',
#               '条二却任持两声.png',
#               '条他思一斯.png',
#               '条原根建最林.png',
#               '来说都便现律.png',
#               '极十都少由飞近.png',
#               '极强值去观.png',
#               '构只美山或二.png',
#               '构基林影五落.png',
#               '构能下边界目观.png',
#               '构话性或路值全.png',
#               '林加他能已开话.png',
#               '果前万情那.png',
#               '标像原取置回制.png',
#               '样再空式提.png',
#               '根持年他她团.png',
#               '根改应标十给.png',
#               '根温求空理应结.png',
#               '格发英温及.png',
#               '格所发方象经.png',
#               '格死实上二.png',
#               '格程书值效书认.png',
#               '格维己政活路看.png',
#               '格罗边表极.png',
#               '次及因建从听让.png',
#               '次的程只业.png',
#               '正是近又言.png',
#               '正目少干团较别.png',
#               '此交极导职它这.png',
#               '此同候快清条.png',
#               '步没分我了.png',
#               '步都女想今.png',
#               '死值互积改那.png',
#               '死品过给动入重.png',
#               '死结做难则上比.png',
#               '死象表研据展.png',
#               '每法的实该.png',
#               '每至镇罗公争.png',
#               '比好两候员美日.png',
#               '民全要她机设应.png',
#               '民其平管很推队.png',
#               '民十得系部少.png',
#               '气什话样得落.png',
#               '气办理运却.png',
#               '气动业长干应军.png',
#               '气参正争如.png',
#               '气山飞它个.png',
#               '气身色原日格手.png',
#               '水做该整却最.png',
#               '水后目究理活情.png',
#               '求会品下们女.png',
#               '求像办给手.png',
#               '求备先不完.png',
#               '求学身要置空将.png',
#               '没立性老己联情.png',
#               '治不白被实只服.png',
#               '治位想院空山.png',
#               '治尔动信然其维.png',
#               '治此第白接体.png',
#               '法业能服方今论.png',
#               '法常二较才治边.png',
#               '法是明记刚.png',
#               '法罗传些气从.png',
#               '活义间路标每.png',
#               '流做开院克.png',
#               '流无识各般.png',
#               '流更定定任造关.png',
#               '流职思住被.png',
#               '济器看为较者团.png',
#               '海条通所海镇.png',
#               '清你强制总让.png',
#               '清制每显品头情.png',
#               '清者学用且.png',
#               '温它这海领光.png',
#               '温构被因民什发.png',
#               '然变张收共.png',
#               '然带展日总给.png',
#               '物统工观什于.png',
#               '特共目结即空.png',
#               '王事及帮科去团.png',
#               '王发里眼便从.png',
#               '王女干确社记提.png',
#               '王求候特自路.png',
#               '现各类记英.png',
#               '理团笑又力.png',
#               '理已表但然.png',
#               '理进并让人长.png',
#               '理题过会公们职.png',
#               '生条总量指.png',
#               '生罗那值实.png',
#               '生超世真量风.png',
#               '用应重学次名.png',
#               '用气战住攻论.png',
#               '用知路林议院像.png',
#               '用说她记多见.png',
#               '由且展手互联准.png',
#               '由个经白觉却.png',
#               '电两本场界必则.png',
#               '电报落经活则.png',
#               '电指然利但.png',
#               '电较由见尔.png',
#               '界打死美金度.png',
#               '界无觉及言镇.png',
#               '界求像连见结.png',
#               '界置种间战可.png',
#               '界进北他之望.png',
#               '白设会互扩.png',
#               '的入还最格得帮.png',
#               '的声展命要位各.png',
#               '的我达正规而又.png',
#               '的有思达往员清.png',
#               '的用快己原间色.png',
#               '的长般与当.png',
#               '目制士将看.png',
#               '目及每向主见好.png',
#               '目日信光些她.png',
#               '目马攻定己.png',
#               '直物难使月做其.png',
#               '直门员统道根认.png',
#               '相各里果原.png',
#               '看一少小该研区.png',
#               '看加望也同平.png',
#               '看后让期口师置.png',
#               '看想互础反告.png',
#               '看本一世就到.png',
#               '看物望关回.png',
#               '看系般品比己指.png',
#               '真从共报收能.png',
#               '真把公眼重.png',
#               '真推走林然职万.png',
#               '真望报互斯几.png',
#               '真让己候次.png',
#               '眼导华义分多见.png',
#               '眼础万的经.png',
#               '着要规张程一.png',
#               '知南开刚之.png',
#               '研自组而心运.png',
#               '研较界期扩要运.png',
#               '础一今小收规.png',
#               '础师里产利表.png',
#               '确清子则新女.png',
#               '确象比式作.png',
#               '社天攻下是器.png',
#               '社正最准白.png',
#               '社组再场治学我.png',
#               '神物构济争现等.png',
#               '种被较言东华产.png',
#               '科几镇进感.png',
#               '科战天会死.png',
#               '科步真管计眼.png',
#               '科没下生受般步.png',
#               '科海得持使利.png',
#               '科至代术受.png',
#               '积从她市争.png',
#               '积从民部没本各.png',
#               '积分认带且济安.png',
#               '积女很报完路.png',
#               '积显今力处.png',
#               '积来市当非后.png',
#               '程去色造保互又.png',
#               '程想就影决.png',
#               '程界却工道军.png',
#               '程神再边些样好.png',
#               '究为像条组声后.png',
#               '究事攻都过经.png',
#               '究计前原能应.png',
#               '空利连斯改.png',
#               '空改必生加些眼.png',
#               '立头相尔值市又.png',
#               '笑次区华任.png',
#               '第且基及重月难.png',
#               '第色目即可.png',
#               '等向声又市能.png',
#               '等难情社究命.png',
#               '管团真改带信.png',
#               '类的难年太书王.png',
#               '类给识开白.png',
#               '系共看克华利代.png',
#               '系流收构色前.png',
#               '系超与被数件.png',
#               '组力条边司体.png',
#               '组快别从下.png',
#               '组显入分强.png',
#               '组议制运公.png',
#               '经落识效心新神.png',
#               '结能书空组.png',
#               '结资己据器人识.png',
#               '给持南说识先.png',
#               '给题在期定.png',
#               '统业战近产.png',
#               '统变根见程实比.png',
#               '维场在文外决.png',
#               '维师华交业张话.png',
#               '置华天决位.png',
#               '美取于没象司车.png',
#               '美风人儿少通几.png',
#               '老口前合给己文.png',
#               '老种许思设.png',
#               '老规比总道其.png',
#               '者效业业光金.png',
#               '而到难白维去马.png',
#               '而子此取她.png',
#               '而斯老出全.png',
#               '而极分年经战.png',
#               '而走很确那构.png',
#               '职别影任理.png',
#               '职言积师干.png',
#               '职认面交数.png',
#               '职重器见名则利.png',
#               '联书己化元更.png',
#               '联到世命物.png',
#               '联如更你受表又.png',
#               '能小家研组王.png',
#               '能整更定光.png',
#               '能直却其何.png',
#               '自品决书系多边.png',
#               '自施会做眼而第.png',
#               '至总镇观业作.png',
#               '般主件果问.png',
#               '般表明回向.png',
#               '色三制听给.png',
#               '色值施美第不论.png',
#               '色准多难资.png',
#               '色务比准器成元.png',
#               '色边进更因会.png',
#               '英处界经西新领.png',
#               '英这你十该看.png',
#               '英镇万神北象.png',
#               '落济关设超.png',
#               '行表快规先.png',
#               '被情去且经队你.png',
#               '被类果总面英日.png',
#               '被罗门安维.png',
#               '西度员四过外.png',
#               '西快争镇也原.png',
#               '西种的镇运少员.png',
#               '西过把社要东用.png',
#               '要很系少温.png',
#               '见业准定活任.png',
#               '见清加回那门.png',
#               '观受达她车场造.png',
#               '观教今强因经边.png',
#               '观而层管儿.png',
#               '觉现听造每.png',
#               '觉解积为力确.png',
#               '解么且产职.png',
#               '解月超主问.png',
#               '解条眼切切.png',
#               '解领人处建快.png',
#               '计他解效较又.png',
#               '计们通死根.png',
#               '计然声回共总.png',
#               '认华根律院有.png',
#               '让军思门间规见.png',
#               '让成展士尔话四.png',
#               '议事与司该.png',
#               '议论济部情将.png',
#               '议过华少子.png',
#               '许使攻放罗德定.png',
#               '许动性子调.png',
#               '许律而证成.png',
#               '论万会军对关罗.png',
#               '论改强完什.png',
#               '论该职必知应.png',
#               '设记所知道受.png',
#               '证为办世律让接.png',
#               '证量笑加今生.png',
#               '话何感还学.png',
#               '话接超金学器建.png',
#               '话觉己将新果美.png',
#               '该军电变常笑还.png',
#               '该则求子力.png',
#               '说为队决体再.png',
#               '说参常团确办.png',
#               '说斯说王过.png',
#               '说无条成死因.png',
#               '说术次所备根.png',
#               '调老作理海.png',
#               '调被还就争.png',
#               '调还问问且方白.png',
#               '象根边新然比理.png',
#               '资关于做何目.png',
#               '资对及争识个.png',
#               '资界议合区经.png',
#               '资认笑斯程有.png',
#               '资走只果扩.png',
#               '走么提生当运.png',
#               '走观万正程研.png',
#               '起品位克对.png',
#               '起士持总方月.png',
#               '起积推础你长白.png',
#               '起题文效内.png',
#               '路义现干任.png',
#               '路可女资改建飞.png',
#               '路提他名山飞子.png',
#               '路联门最万教.png',
#               '身一克老领设来.png',
#               '身因类万它来她.png',
#               '车性还然亲帮制.png',
#               '较切非水服山万.png',
#               '较才见机用重近.png',
#               '边前很础那话接.png',
#               '边老格书业点么.png',
#               '达导放区构形受.png',
#               '过年任职术.png',
#               '运帮色明给.png',
#               '近笑性队多都.png',
#               '还近几连打说.png',
#               '这工问能的部.png',
#               '这格扩论思置.png',
#               '进团员风期.png',
#               '进现事笑传较.png',
#               '连之而器三.png',
#               '通性造告司道结.png',
#               '通证生理有进.png',
#               '造争接路者义教.png',
#               '造做南连什.png',
#               '造太扩并内结.png',
#               '道人之院计.png',
#               '道务机一落术.png',
#               '道月过华数他极.png',
#               '道现攻保维然.png',
#               '道门先却术值便.png',
#               '那个之可会.png',
#               '那告领现光程.png',
#               '那团书平度.png',
#               '那少所往必程.png',
#               '那工今较造.png',
#               '那才推治刚.png',
#               '那物认完亲白.png',
#               '部下原式去科.png',
#               '部拉式样争连再.png',
#               '都己做备条件即.png',
#               '都非者设向.png',
#               '里产眼确走.png',
#               '里真者于起信.png',
#               '重参义特造扩.png',
#               '量区在感性别.png',
#               '量听解而两好了.png',
#               '量思开快新.png',
#               '量才王立服常.png',
#               '量水已治从加说.png',
#               '金眼标里律.png',
#               '金表四院备月制.png',
#               '镇办位效最.png',
#               '镇施成很个.png',
#               '镇老持十那.png',
#               '长更参步还原好.png',
#               '长济般立听.png',
#               '门学又风四.png',
#               '门对马什许.png',
#               '问式改总什.png',
#               '问性建都眼工.png',
#               '问标许落许立说.png',
#               '问走传必所运.png',
#               '间后题外山还.png',
#               '间月性该保海加.png',
#               '间然切式非.png',
#               '队工人取神.png',
#               '队民应标些义带.png',
#               '院内家然即告.png',
#               '院器领常类原女.png',
#               '院效备被便.png',
#               '难起传程工造重.png',
#               '难造四工而应.png',
#               '非问电罗不.png',
#               '面发影表反.png',
#               '面空般行月给手.png',
#               '领报近性温不.png',
#               '领据会边让.png',
#               '领着准从设.png',
#               '题亲笑究很命.png',
#               '题机三可门.png',
#               '飞什建分命施走.png',
#               '飞位至便了备.png',
#               '马司设有等实.png',
#               '马看度构新本.png',
#               '高决器何程五.png',
#               '高场提流工设.png',
#               '高看意说内许.png'],
#              'label': [[2, 135, 256, 127, 338],
#               [2, 19, 10, 248, 93],
#               [315, 74, 82, 101, 390],
#               [14, 155, 387, 190, 42],
#               [14, 180, 117, 347, 194, 53, 338],
#               [14, 399, 27, 133, 385, 114, 201],
#               [35, 387, 147, 190, 111],
#               [6, 66, 246, 404, 130, 350],
#               [6, 380, 159, 296, 82, 98],
#               [101, 142, 184, 401, 280],
#               [101, 391, 11, 183, 16],
#               [289, 308, 123, 180, 396, 60],
#               [289, 114, 335, 190, 284],
#               [289, 327, 247, 380, 243, 3],
#               [289, 77, 48, 220, 201],
#               [174, 121, 226, 106, 289, 375, 241],
#               [174, 129, 375, 330, 185],
#               [174, 133, 274, 151, 47, 196, 339],
#               [123, 7, 165, 110, 234, 321, 308],
#               [123, 393, 305, 333, 231, 119],
#               [123, 297, 127, 101, 247, 192],
#               [123, 327, 226, 189, 331, 172, 154],
#               [187, 173, 228, 15, 197, 292, 3],
#               [126, 329, 395, 4, 191, 73],
#               [126, 105, 287, 206, 387, 205],
#               [126, 196, 290, 297, 59, 374, 407],
#               [126, 344, 65, 206, 367, 12],
#               [16, 342, 232, 277, 221],
#               [16, 43, 70, 407, 139, 384],
#               [17, 126, 90, 3, 239, 405],
#               [17, 100, 202, 242, 138, 367],
#               [17, 376, 310, 250, 262, 112],
#               [56, 303, 147, 210, 264, 300, 313],
#               [201, 72, 376, 336, 206, 291, 46],
#               [201, 39, 268, 312, 226, 32, 237],
#               [37, 88, 46, 401, 305, 63],
#               [37, 334, 133, 319, 369],
#               [37, 117, 347, 47, 45, 23, 14],
#               [37, 70, 321, 311, 359, 356],
#               [37, 207, 362, 31, 128, 380, 15],
#               [37, 210, 364, 25, 136, 286, 167],
#               [37, 195, 92, 142, 379, 291],
#               [25, 120, 236, 76, 353],
#               [275, 186, 137, 253, 180, 26, 1],
#               [275, 11, 269, 182, 405, 252, 56],
#               [275, 333, 241, 367, 72, 60, 118],
#               [4, 82, 84, 311, 88, 219, 175],
#               [4, 279, 26, 386, 169, 1, 381],
#               [4, 245, 49, 317, 357, 68],
#               [4, 320, 192, 187, 342],
#               [337, 167, 117, 87, 102, 177],
#               [337, 9, 190, 29, 233, 2, 272],
#               [337, 332, 267, 361, 286, 237, 326],
#               [51, 259, 222, 227, 59],
#               [51, 169, 106, 272, 117],
#               [51, 372, 66, 270, 269],
#               [150, 120, 84, 141, 198, 66],
#               [150, 171, 39, 136, 345, 362],
#               [150, 370, 400, 359, 153, 131],
#               [150, 265, 336, 36, 112, 211],
#               [34, 355, 343, 226, 162],
#               [34, 33, 180, 218, 308],
#               [396, 235, 380, 221, 31, 158, 69],
#               [396, 196, 356, 227, 50, 300, 256],
#               [396, 225, 66, 209, 198, 295],
#               [396, 333, 259, 308, 170],
#               [272, 39, 89, 336, 150, 237, 310],
#               [79, 139, 382, 336, 131, 221, 318],
#               [79, 138, 37, 247, 382],
#               [313, 92, 400, 291, 315],
#               [313, 367, 58, 349, 152, 140, 396],
#               [152, 249, 28, 80, 62, 286, 208],
#               [152, 158, 154, 262, 183],
#               [152, 74, 159, 277, 115],
#               [355, 311, 295, 291, 200, 86, 250],
#               [355, 401, 303, 159, 30, 69],
#               [355, 354, 166, 300, 47],
#               [8, 304, 251, 244, 72, 94],
#               [149, 37, 100, 111, 225, 193, 47],
#               [149, 400, 390, 353, 407, 121],
#               [149, 7, 398, 210, 267],
#               [149, 124, 231, 369, 203, 325],
#               [149, 388, 149, 197, 351, 393, 289],
#               [149, 406, 289, 249, 307],
#               [329, 295, 404, 65, 8],
#               [91, 99, 22, 104, 160, 85],
#               [91, 62, 135, 43, 98, 85],
#               [91, 110, 43, 245, 332, 74],
#               [91, 248, 301, 12, 344],
#               [12, 315, 238, 294, 328, 94, 239],
#               [12, 37, 314, 23, 57],
#               [12, 146, 175, 23, 379],
#               [167, 235, 388, 307, 311, 263],
#               [167, 240, 276, 82, 193, 286],
#               [167, 44, 337, 265, 202],
#               [167, 274, 257, 34, 386, 9, 113],
#               [243, 329, 30, 302, 172, 397, 166],
#               [243, 42, 118, 159, 84, 241, 146],
#               [179, 31, 50, 253, 102],
#               [23, 342, 18, 322, 119, 143],
#               [325, 40, 274, 224, 59, 322],
#               [325, 359, 393, 9, 280, 245, 191],
#               [88, 64, 16, 295, 24, 162],
#               [88, 44, 278, 255, 302],
#               [88, 116, 210, 75, 69, 177, 171],
#               [88, 220, 407, 82, 392],
#               [302, 149, 2, 241, 106, 196, 41],
#               [302, 215, 364, 365, 33],
#               [302, 359, 4, 166, 143],
#               [142, 150, 288, 393, 148, 6],
#               [142, 255, 200, 346, 322],
#               [142, 134, 344, 216, 229],
#               [222, 169, 339, 385, 76, 93],
#               [222, 211, 123, 58, 367, 362, 59],
#               [42, 391, 171, 18, 342, 129],
#               [42, 394, 320, 315, 249],
#               [26, 372, 125, 26, 145, 160],
#               [112, 160, 246, 298, 206, 201, 32],
#               [264, 252, 159, 355, 144, 386],
#               [259, 99, 321, 108, 357],
#               [259, 224, 126, 256, 19],
#               [259, 82, 45, 168, 137],
#               [259, 332, 395, 121, 218, 334, 29],
#               [169, 242, 107, 84, 358, 168, 223],
#               [169, 76, 219, 297, 162, 288],
#               [169, 356, 101, 339, 24, 367, 171],
#               [169, 345, 62, 330, 129, 277],
#               [334, 227, 113, 197, 323, 23, 242],
#               [334, 46, 51, 362, 152],
#               [389, 302, 123, 261, 43],
#               [389, 273, 140, 36, 305, 98],
#               [389, 138, 372, 129, 156, 382, 348],
#               [389, 15, 15, 248, 242, 289],
#               [239, 386, 337, 341, 231, 301, 364],
#               [239, 254, 151, 283, 339, 406, 322],
#               [239, 384, 334, 279, 398, 377],
#               [287, 7, 298, 139, 236],
#               [287, 131, 106, 332, 351],
#               [287, 260, 344, 181, 393, 216, 328],
#               [185, 177, 365, 62, 25, 377, 381],
#               [363, 38, 260, 129, 216],
#               [181, 251, 325, 210, 222, 343, 29],
#               [181, 54, 310, 279, 299, 270, 183],
#               [283, 300, 99, 135, 293, 191],
#               [283, 406, 239, 386, 94, 291],
#               [283, 29, 162, 13, 36, 66],
#               [117, 400, 15, 21, 50, 118],
#               [117, 164, 81, 241, 106, 63, 323],
#               [117, 378, 231, 378, 84, 183, 326],
#               [108, 326, 367, 359, 235, 343, 400],
#               [108, 151, 271, 67, 376, 125],
#               [323, 221, 309, 209, 157],
#               [323, 154, 117, 361, 405, 353],
#               [120, 9, 296, 29, 123, 139, 293],
#               [120, 172, 21, 205, 384, 248, 400],
#               [78, 222, 230, 122, 402, 86, 111],
#               [78, 59, 120, 347, 289],
#               [78, 47, 111, 343, 156, 173],
#               [78, 356, 214, 126, 280, 97, 146],
#               [168, 215, 185, 397, 173, 191, 406],
#               [168, 111, 252, 80, 244, 85],
#               [168, 11, 313, 331, 169, 182],
#               [235, 96, 107, 109, 21, 249, 200],
#               [95, 13, 112, 140, 328, 325],
#               [266, 141, 388, 331, 174, 89],
#               [266, 290, 346, 5, 20],
#               [266, 371, 381, 198, 341],
#               [266, 210, 181, 398, 41, 146],
#               [402, 259, 145, 50, 403, 298],
#               [402, 148, 26, 402, 83],
#               [402, 153, 366, 407, 296, 34, 64],
#               [402, 378, 25, 25, 215],
#               [402, 304, 376, 365, 269, 349],
#               [204, 315, 36, 299, 132, 49, 333],
#               [204, 8, 319, 120, 280],
#               [204, 164, 48, 25, 207],
#               [204, 31, 133, 278, 284, 338],
#               [204, 30, 163, 125, 393, 62, 333],
#               [204, 43, 223, 81, 333],
#               [22, 203, 102, 1, 225, 154],
#               [22, 352, 372, 400, 3, 321],
#               [22, 260, 91, 231, 367, 93],
#               [72, 30, 35, 62, 77, 21],
#               [72, 347, 269, 365, 331],
#               [330, 355, 230, 280, 271, 396, 307],
#               [330, 230, 366, 201, 104, 211],
#               [330, 137, 246, 332, 204, 208],
#               [330, 357, 138, 374, 283, 328, 75],
#               [330, 299, 330, 142, 366],
#               [277, 344, 234, 81, 338, 138],
#               [400, 171, 289, 197, 210],
#               [400, 59, 217, 25, 145],
#               [400, 362, 389, 107, 59],
#               [400, 136, 351, 301, 92, 118],
#               [148, 185, 12, 386, 84, 196, 253],
#               [148, 291, 399, 57, 230],
#               [148, 253, 225, 92, 5, 358, 210],
#               [148, 276, 24, 354, 388],
#               [215, 243, 330, 73, 157, 315, 114],
#               [215, 385, 99, 60, 336],
#               [18, 66, 20, 259, 79, 184, 292],
#               [18, 59, 124, 303, 87],
#               [18, 236, 330, 406, 145, 26],
#               [18, 55, 393, 99, 163, 404, 49],
#               [18, 361, 330, 338, 179],
#               [156, 289, 128, 28, 393, 263],
#               [156, 187, 355, 43, 156, 157],
#               [156, 192, 381, 249, 225],
#               [86, 75, 393, 57, 14, 379],
#               [86, 391, 97, 328, 46, 293, 107],
#               [99, 105, 89, 45, 150, 343],
#               [99, 381, 63, 216, 253, 50],
#               [360, 262, 34, 80, 77],
#               [360, 15, 62, 137, 60, 226, 406],
#               [159, 386, 76, 167, 235],
#               [159, 163, 296, 173, 19, 22, 7],
#               [238, 16, 193, 66, 261, 279],
#               [238, 72, 330, 95, 12, 214],
#               [238, 199, 48, 344, 20, 123, 379],
#               [238, 213, 316, 162, 248, 285],
#               [238, 339, 229, 296, 229, 44],
#               [66, 35, 230, 251, 401, 284],
#               [66, 239, 184, 42, 337, 97, 383],
#               [66, 213, 259, 177, 44, 30],
#               [171, 148, 353, 346, 10, 351],
#               [171, 358, 318, 223, 280, 46, 158],
#               [308, 362, 311, 136, 191],
#               [308, 68, 358, 343, 183],
#               [308, 276, 13, 28, 207],
#               [258, 231, 178, 31, 247, 306, 295],
#               [258, 180, 212, 81, 1],
#               [258, 147, 83, 284, 386, 189],
#               [258, 133, 291, 354, 105, 173],
#               [258, 276, 13, 46, 264, 348],
#               [105, 76, 340, 132, 51, 162, 217],
#               [105, 361, 377, 31, 280],
#               [398, 355, 285, 93, 198],
#               [398, 46, 174, 328, 10, 50],
#               [398, 61, 82, 260, 329],
#               [300, 353, 406, 219, 343, 164],
#               [286, 112, 393, 122, 207, 21],
#               [286, 400, 28, 309, 292, 31],
#               [286, 375, 314, 115, 161, 298, 318],
#               [280, 302, 84, 309, 114],
#               [280, 357, 254, 271, 181, 138],
#               [280, 304, 304, 293, 255, 29, 358],
#               [57, 323, 1, 8, 374, 177],
#               [57, 346, 7, 26, 105, 202, 267],
#               [57, 52, 397, 228, 140, 269],
#               [57, 48, 403, 79, 288, 26, 281],
#               [57, 172, 375, 379, 231, 65, 220],
#               [385, 335, 29, 142, 298, 259, 150],
#               [119, 302, 303, 37, 67],
#               [119, 344, 15, 213, 377],
#               [191, 22, 105, 106, 395, 338, 305],
#               [191, 171, 115, 151, 377, 116, 85],
#               [191, 7, 197, 294, 160, 32, 54],
#               [191, 232, 40, 84, 338, 50],
#               [191, 366, 128, 66, 398, 157, 315],
#               [230, 237, 170, 279, 290],
#               [230, 138, 126, 10, 41, 335],
#               [230, 176, 174, 52, 9, 185, 117],
#               [230, 30, 396, 214, 339],
#               [40, 35, 63, 343, 39, 296],
#               [40, 186, 21, 239, 100, 102, 161],
#               [40, 271, 224, 111, 270, 61, 391],
#               [40, 140, 316, 53, 226, 47, 128],
#               [40, 387, 233, 163, 382],
#               [40, 13, 232, 216, 248, 234],
#               [316, 76, 352, 210, 116, 128],
#               [231, 204, 299, 301, 187, 155, 116],
#               [231, 316, 192, 278, 355, 167, 236],
#               [218, 105, 356, 371, 225, 218],
#               [218, 77, 87, 235, 186, 113],
#               [205, 168, 23, 277, 344, 212],
#               [205, 209, 94, 349, 44],
#               [90, 283, 64, 305, 333],
#               [90, 168, 79, 334, 73, 335],
#               [90, 53, 147, 105, 351, 40],
#               [90, 98, 154, 183, 221],
#               [24, 7, 345, 134, 85, 281],
#               [271, 215, 88, 114, 72, 302],
#               [271, 362, 364, 81, 76, 69, 91],
#               [271, 405, 275, 105, 238, 255],
#               [202, 174, 14, 186, 219, 149, 373],
#               [202, 162, 40, 352, 348, 44, 115],
#               [202, 290, 245, 106, 189, 329, 64],
#               [202, 295, 82, 161, 305, 159, 356],
#               [164, 45, 6, 245, 49, 74, 142],
#               [62, 109, 290, 228, 209, 104],
#               [62, 376, 290, 78, 387],
#               [41, 118, 79, 99, 160, 187, 397],
#               [41, 169, 267, 38, 368, 265, 201],
#               [41, 287, 163, 341, 174],
#               [41, 180, 157, 54, 308],
#               [41, 311, 196, 37, 100, 405],
#               [139, 389, 318, 86, 176],
#               [139, 392, 252, 28, 315, 266, 73],
#               [139, 327, 388, 365, 30, 17, 192],
#               [278, 168, 322, 15, 217, 261],
#               [278, 66, 403, 20, 402],
#               [303, 269, 368, 273, 238, 282, 31],
#               [193, 274, 16, 388, 223, 311, 95],
#               [251, 301, 38, 251, 137, 210],
#               [251, 29, 292, 201, 54],
#               [301, 17, 16, 45, 361],
#               [374, 72, 112, 347, 79, 311],
#               [374, 165, 247, 189, 360],
#               [165, 152, 2, 60, 247, 48],
#               [165, 115, 144, 285, 333, 84],
#               [165, 250, 360, 127, 279, 52],
#               [89, 140, 45, 215, 115, 142, 38],
#               [89, 252, 167, 94, 60, 265],
#               [89, 405, 103, 61, 65, 223, 293],
#               [89, 384, 129, 93, 215, 176],
#               [89, 67, 383, 356, 174, 131],
#               [377, 167, 322, 281, 336, 270],
#               [377, 397, 350, 326, 214, 129, 393],
#               [377, 288, 383, 186, 239],
#               [7, 323, 380, 59, 122],
#               [7, 27, 394, 399, 354],
#               [7, 134, 387, 185, 110, 357, 39],
#               [7, 404, 114, 341, 162, 310, 386],
#               [7, 73, 334, 59, 135, 394],
#               [7, 45, 70, 268, 85, 2],
#               [242, 79, 309, 65, 164, 262, 322],
#               [242, 193, 91, 115, 365],
#               [242, 104, 237, 123, 10, 53],
#               [365, 278, 280, 187, 158, 386],
#               [365, 321, 265, 242, 371, 214],
#               [365, 104, 257, 115, 369, 29, 213],
#               [365, 309, 233, 6, 27],
#               [188, 326, 99, 197, 113],
#               [188, 50, 151, 393, 345, 305, 54],
#               [199, 189, 252, 215, 220, 363],
#               [199, 399, 216, 261, 226],
#               [386, 123, 315, 271, 153],
#               [386, 302, 404, 378, 18],
#               [386, 204, 142, 71, 6, 58],
#               [124, 362, 219, 352, 135],
#               [124, 254, 199, 384, 141, 57, 396],
#               [54, 232, 350, 191, 252, 173],
#               [71, 272, 311, 116, 252, 173, 151],
#               [71, 22, 36, 206, 31],
#               [71, 251, 77, 231, 172],
#               [71, 163, 11, 33, 371, 222, 357],
#               [233, 217, 191, 54, 191],
#               [233, 74, 406, 144, 313, 400],
#               [140, 22, 369, 253, 354, 396, 71],
#               [217, 167, 220, 260, 346, 382],
#               [217, 141, 242, 238, 333, 237, 52],
#               [217, 388, 185, 194, 122],
#               [84, 277, 374, 102, 80, 101, 206],
#               [84, 247, 7, 144, 362, 358, 338],
#               [75, 111, 270, 31, 111, 245, 43],
#               [75, 74, 145, 260, 40, 86, 276],
#               [60, 79, 244, 181, 109],
#               [60, 191, 60, 143, 285],
#               [60, 106, 171, 145, 265, 148, 48],
#               [60, 253, 248, 318, 9, 52],
#               [31, 58, 12, 278, 317],
#               [31, 338, 40, 305, 100, 62, 124],
#               [59, 248, 357, 228, 256],
#               [100, 104, 152, 399, 310, 69],
#               [100, 345, 41, 37, 187, 62, 155],
#               [100, 77, 276, 91, 164, 359, 216],
#               [225, 168, 323, 318, 384, 78, 338],
#               [225, 205, 197, 257, 378],
#               [225, 60, 61, 284, 92],
#               [294, 220, 254, 113, 3, 121],
#               [294, 340, 149, 127, 93, 395],
#               [70, 184, 149, 236, 402, 194],
#               [70, 383, 69, 281, 236, 114, 25],
#               [93, 278, 336, 46, 311, 127, 134],
#               [93, 233, 85, 48, 317],
#               [93, 106, 98, 68, 345, 295, 316],
#               [49, 42, 201, 171, 171],
#               [49, 327, 103, 372, 136, 30],
#               [49, 73, 52, 73, 396],
#               [27, 153, 247, 117, 55, 72],
#               [27, 284, 55, 237, 100, 238],
#               [27, 246, 267, 87, 52],
#               [27, 394, 313, 231, 363],
#               [125, 187, 178, 198, 44],
#               [125, 251, 252, 221, 160],
#               [76, 120, 374, 338, 133, 258, 194],
#               [76, 141, 336, 200, 230, 200, 324],
#               [76, 274, 150, 139, 308, 300, 310],
#               [76, 163, 300, 394, 255, 284],
#               [226, 336, 42, 100, 146, 20],
#               [226, 252, 169, 343, 233],
#               [226, 290, 342, 369, 392, 303],
#               [226, 349, 282, 52, 191, 397, 262],
#               [226, 256, 195, 23, 22, 76, 219],
#               [226, 45, 71, 392, 366, 116, 355],
#               [213, 308, 207, 77, 66, 283, 19],
#               [213, 251, 69, 58, 113, 103, 197],
#               [213, 82, 255, 395, 336],
#               [21, 186, 188, 165, 15, 273, 394],
#               [21, 371, 253, 191, 284],
#               [370, 144, 207, 41, 19, 68, 202],
#               [373, 59, 14, 52, 348],
#               [373, 135, 82, 47, 361],
#               [373, 197, 191, 166, 27, 398],
#               [268, 165, 48, 38, 125],
#               [268, 377, 27, 71, 237, 80, 190],
#               [268, 70, 210, 33, 131, 243],
#               [268, 279, 398, 185, 362, 141],
#               [268, 116, 277, 26, 139, 291, 159],
#               [268, 379, 267, 51, 52, 79, 393],
#               [252, 118, 142, 279, 33, 378],
#               [252, 278, 260, 6, 255, 267, 103],
#               [252, 365, 84, 195, 52, 269],
#               [252, 197, 366, 338, 62, 140],
#               [252, 13, 66, 214, 336, 40],
#               [111, 193, 251, 154, 174, 223],
#               [155, 188, 45, 29, 77, 307, 395],
#               [155, 116, 40, 9, 341, 321],
#               [155, 32, 213, 379, 150, 277, 181],
#               [110, 335, 159, 235, 56],
#               [110, 296, 63, 308, 220, 220],
#               [110, 399, 182, 364, 134, 158],
#               [110, 388, 236, 377, 308, 10],
#               [110, 265, 156, 125, 239, 372, 351],
#               [247, 185, 223, 124, 249],
#               [247, 147, 274, 133, 139, 176],
#               [326, 286, 131, 377, 56, 392, 269],
#               [326, 98, 230, 110, 280],
#               [326, 212, 178, 121, 2, 68, 401],
#               [335, 330, 204, 95, 79, 306],
#               [335, 385, 212, 295, 361],
#               [335, 311, 200, 67, 268],
#               [380, 109, 25, 176, 150, 262],
#               [180, 350, 122, 144, 212, 219, 94],
#               [180, 250, 137, 311, 392, 263, 347],
#               [38, 120, 218, 8, 255, 271, 192],
#               [38, 219, 374, 99, 325, 21],
#               [38, 33, 191, 56, 326, 363],
#               [134, 156, 38, 403, 140],
#               [134, 60, 274, 309, 89, 218],
#               [134, 226, 172, 113, 301],
#               [177, 13, 204, 365, 111, 21],
#               [237, 26, 116, 21, 391, 393],
#               [237, 261, 137, 223, 350],
#               [87, 405, 82, 323, 242],
#               [87, 58, 11, 7, 291, 287],
#               [296, 121, 353, 300, 164, 144],
#               [311, 313, 319, 12, 37],
# ...
#               [318, 310, 93, 14, 150],
#               [318, 307, 275, 389, 375, 275, 206],
#               [318, 387, 155, 143, 212, 298, 69],
#               [318, 384, 309, 170, 356],
#               [176, 191, 89, 237, 91, 278, 332],
#               [176, 1, 307, 90, 123],
#               [122, 3, 367, 119, 348],
#               [122, 232, 226, 346, 377, 397, 215],
#               [109, 313, 356, 336, 392, 100, 13],
#               [109, 62, 334, 359, 328, 207],
#               [342, 65, 72, 5, 4],
#               [342, 61, 217, 92, 329],
#               [310, 389, 396, 382, 343, 32],
#               [310, 301, 39, 173, 66, 203, 133],
#               [310, 229, 239, 288, 277, 14, 192],
#               [310, 293, 170, 378, 306, 268],
#               [352, 58, 1, 93, 312],
#               [352, 260, 395, 384, 108, 337],
#               [192, 75, 126, 334, 193, 144, 94],
#               [106, 117, 20, 84, 104, 295, 137],
#               [106, 78, 208, 245, 131, 404, 261],
#               [106, 105, 33, 209, 77, 226],
#               [210, 149, 163, 81, 33, 391],
#               [210, 360, 82, 338, 280],
#               [210, 66, 123, 102, 346, 137, 95],
#               [210, 385, 122, 337, 60],
#               [210, 252, 340, 100, 16],
#               [210, 157, 297, 186, 94, 318, 136],
#               [195, 239, 312, 383, 280, 132],
#               [195, 41, 232, 406, 82, 212, 113],
#               [305, 23, 301, 35, 9, 217],
#               [305, 287, 360, 173, 136],
#               [305, 386, 181, 6, 294],
#               [305, 59, 157, 20, 381, 265, 125],
#               [65, 190, 115, 172, 155, 349, 113],
#               [267, 6, 279, 147, 93, 90, 358],
#               [267, 175, 92, 331, 265, 252],
#               [267, 213, 66, 169, 48, 78, 387],
#               [267, 109, 107, 279, 240, 142],
#               [58, 123, 29, 358, 53, 329, 198],
#               [58, 180, 150, 397, 228, 267, 309],
#               [58, 3, 114, 299, 400],
#               [58, 384, 325, 79, 210, 91],
#               [212, 201, 128, 298, 401, 352],
#               [393, 239, 87, 331, 255],
#               [393, 98, 333, 202, 369],
#               [393, 214, 70, 70, 179, 347, 120],
#               [393, 392, 291, 302, 147],
#               [353, 374, 69, 17, 397, 96, 377],
#               [182, 207, 183, 47, 182, 395],
#               [328, 26, 285, 156, 221, 332],
#               [328, 156, 352, 399, 301, 140, 113],
#               [328, 96, 59, 44, 289],
#               [390, 100, 13, 182, 322, 283],
#               [390, 371, 147, 89, 106, 149, 40],
#               [48, 218, 311, 344, 323],
#               [48, 335, 268, 94, 221, 173],
#               [135, 257, 111, 327, 149, 34],
#               [166, 323, 232, 229, 286, 265],
#               [292, 51, 191, 380, 270, 57, 377],
#               [292, 40, 43, 274, 264, 91],
#               [292, 217, 346, 324, 263, 299, 189],
#               [292, 305, 334, 166, 36, 298],
#               [63, 202, 304, 299, 364],
#               [82, 377, 339, 119, 99],
#               [82, 110, 170, 88, 48],
#               [82, 74, 134, 332, 8, 102],
#               [82, 211, 39, 23, 108, 9, 392],
#               [28, 207, 221, 234, 254],
#               [28, 384, 32, 389, 93],
#               [28, 379, 174, 197, 234, 341],
#               [44, 137, 133, 59, 176, 196],
#               [44, 210, 138, 302, 403, 198],
#               [44, 116, 298, 357, 361, 331, 287],
#               [44, 19, 84, 299, 54, 146],
#               [129, 289, 268, 136, 396, 349, 402],
#               [129, 16, 55, 279, 320, 280],
#               [223, 126, 85, 242, 281, 241, 277],
#               [223, 227, 391, 55, 212, 277],
#               [223, 254, 48, 148, 88],
#               [223, 397, 129, 146, 213],
#               [281, 216, 310, 144, 253, 177],
#               [281, 98, 320, 191, 348, 395],
#               [281, 305, 287, 394, 146, 229],
#               [281, 381, 50, 128, 138, 24],
#               [281, 74, 308, 12, 37, 319],
#               [279, 295, 23, 396, 407],
#               [1, 203, 73, 132, 318, 33, 380],
#               [1, 188, 268, 251, 20, 175, 202],
#               [1, 5, 282, 122, 314, 30, 119],
#               [1, 10, 291, 282, 362, 193, 328],
#               [1, 44, 359, 155, 186, 128, 297],
#               [1, 102, 369, 101, 64],
#               [232, 156, 365, 125, 69],
#               [232, 191, 352, 139, 80, 146, 75],
#               [232, 94, 169, 283, 79, 84],
#               [232, 269, 403, 70, 155],
#               [248, 135, 288, 112, 162, 239, 78],
#               [248, 178, 193, 257, 45, 345, 206],
#               [145, 202, 43, 158, 186],
#               [69, 2, 226, 76, 312, 378, 258],
#               [69, 159, 319, 25, 62, 208],
#               [69, 41, 332, 246, 205, 326, 381],
#               [69, 92, 396, 388, 230, 303],
#               [69, 85, 2, 174, 21, 18],
#               [69, 135, 319, 120, 165],
#               [69, 209, 369, 301, 192, 155, 254],
#               [197, 91, 323, 227, 344, 29],
#               [197, 103, 108, 274, 133],
#               [197, 404, 200, 357, 48, 392, 315],
#               [197, 319, 227, 396, 161, 204],
#               [197, 332, 155, 334, 176],
#               [274, 336, 398, 201, 72, 54, 146],
#               [274, 388, 315, 1, 55],
#               [15, 20, 314, 311, 307, 2],
#               [116, 300, 87, 400, 37],
#               [378, 36, 351, 30, 83, 338],
#               [378, 397, 281, 246, 407, 20, 338],
#               [388, 2, 329, 76, 344, 314],
#               [388, 326, 43, 152, 148, 170],
#               [324, 328, 31, 277, 154, 217],
#               [324, 293, 192, 296, 42],
#               [263, 71, 403, 35, 3, 374],
#               [263, 122, 132, 402, 279],
#               [263, 351, 235, 242, 267, 59, 5],
#               [220, 135, 371, 353, 337, 63, 151],
#               [50, 147, 397, 348, 187, 398, 152],
#               [270, 204, 395, 74, 236],
#               [270, 138, 71, 23, 310],
#               [270, 342, 197, 245, 244, 274],
#               [270, 65, 35, 28, 231, 369, 342],
#               [270, 182, 33, 350, 112, 148],
#               [270, 260, 167, 321, 231],
#               [382, 91, 84, 247, 337],
#               [382, 91, 106, 77, 65, 85, 202],
#               [382, 72, 206, 335, 289, 353, 225],
#               [382, 217, 131, 227, 294, 298],
#               [382, 399, 329, 99, 199],
#               [382, 11, 247, 64, 276, 41],
#               [307, 57, 297, 347, 259, 396, 119],
#               [307, 92, 21, 372, 266],
#               [307, 281, 280, 111, 45, 95],
#               [307, 220, 235, 309, 79, 81, 75],
#               [406, 17, 287, 207, 351, 188, 41],
#               [406, 51, 403, 61, 39, 55],
#               [406, 244, 86, 186, 29, 137],
#               [265, 148, 394, 161, 343],
#               [265, 343, 241, 28, 159, 79, 274],
#               [190, 140, 145, 213, 389, 247, 119],
#               [339, 176, 258, 398, 179],
#               [107, 289, 273, 191, 133, 162, 288],
#               [107, 297, 232, 286, 24],
#               [151, 139, 188, 119, 247, 29],
#               [151, 288, 113, 263, 406, 251],
#               [245, 377, 197, 343, 335, 169],
#               [304, 1, 288, 38, 233, 275, 292],
#               [304, 173, 333, 87, 279],
#               [209, 323, 69, 255, 398, 148, 167],
#               [209, 393, 344, 371, 297, 86],
#               [209, 379, 101, 147, 224, 243],
#               [351, 99, 207, 309, 271, 142],
#               [351, 359, 215, 91, 35],
#               [351, 399, 203, 72, 285],
#               [351, 361, 156, 338, 108],
#               [55, 391, 333, 375, 83, 154, 220],
#               [229, 29, 275, 265, 351],
#               [229, 250, 155, 306, 374, 8, 333],
#               [173, 350, 300, 19, 333, 181],
#               [173, 211, 7, 246, 70],
#               [257, 123, 138, 367, 152],
#               [257, 218, 345, 146, 307, 93, 192],
#               [387, 242, 7, 141, 124, 266],
#               [387, 326, 398, 313, 123, 311, 163],
#               [381, 398, 71, 266, 175],
#               [144, 316, 34, 65, 293, 271, 354],
#               [144, 341, 8, 185, 226, 183, 204],
#               [172, 205, 86, 164, 173, 155, 141],
#               [172, 50, 256, 291, 295],
#               [172, 314, 192, 221, 45, 78],
#               [96, 375, 123, 123, 283, 253],
#               [30, 18, 288, 279, 387, 57, 269],
#               [30, 31, 109, 316, 84],
#               [30, 161, 172, 22, 117],
#               [30, 356, 72, 38, 55, 138],
#               [30, 200, 131, 324, 32, 371],
#               [392, 215, 372, 179, 82],
#               [392, 348, 382, 326, 346],
#               [392, 206, 67, 313, 224],
#               [392, 133, 374, 146, 196, 277, 148],
#               [349, 275, 155, 171, 363, 214],
#               [349, 18, 174, 251, 135],
#               [349, 60, 214, 26, 231, 170, 119],
#               [29, 76, 49, 378, 351, 292],
#               [29, 383, 214, 70, 283],
#               [29, 248, 280, 78, 222],
#               [36, 301, 266, 275, 209, 54, 309],
#               [36, 405, 23, 239, 274, 30, 107],
#               [260, 221, 395, 327, 123, 42],
#               [369, 80, 243, 158, 130],
#               [369, 170, 114, 165, 139],
#               [297, 118, 156, 278, 173],
#               [297, 389, 405, 144, 107, 6, 198],
#               [297, 402, 54, 288, 250],
#               [297, 238, 192, 402, 374, 52, 363],
#               [297, 309, 74, 214, 89, 23],
#               [364, 199, 281, 55, 160, 154, 322],
#               [364, 13, 26, 105, 312, 69],
#               [364, 395, 315, 220, 308, 293],
#               [391, 353, 120, 295, 379],
#               [46, 170, 359, 314, 181],
#               [147, 113, 57, 289, 55, 261, 26],
#               [147, 304, 158, 221, 67, 364, 94],
#               [147, 384, 178, 225, 387],
#               [160, 177, 193, 219, 39, 124],
#               [160, 359, 337, 395, 25, 186],
#               [160, 50, 1, 395, 338, 226, 193],
#               [160, 39, 103, 263, 20, 187, 44],
#               [20, 131, 209, 226, 390],
#               [146, 123, 402, 70, 212, 179],
#               [146, 328, 159, 165, 32, 178],
#               [327, 231, 282, 84, 354, 242, 347],
#               [327, 184, 329, 285, 89, 55, 309],
#               [327, 30, 373, 245, 185],
#               [320, 63, 278, 347, 352],
#               [320, 194, 382, 17, 99, 324],
#               [194, 56, 289, 152, 392],
#               [194, 162, 379, 80, 130],
#               [194, 207, 274, 330, 330],
#               [194, 322, 8, 199, 237, 359],
#               [244, 12, 194, 375, 397, 119],
#               [244, 9, 183, 310, 345],
#               [244, 48, 188, 165, 323, 221],
#               [206, 398, 345, 368, 331, 10],
#               [332, 95, 291, 178, 128, 314, 146],
#               [332, 52, 268, 365, 213, 163, 219],
#               [361, 51, 101, 271, 312],
#               [361, 198, 353, 77, 113, 125],
#               [361, 39, 398, 226, 31],
#               [256, 112, 403, 284, 384, 249, 70],
#               [256, 66, 115, 31, 376],
#               [256, 368, 30, 366, 52],
#               [198, 315, 23, 95, 27, 120, 384],
#               [198, 343, 285, 294, 149],
#               [198, 312, 392, 241, 116, 137],
#               [295, 299, 47, 116, 45, 231],
#               [366, 17, 360, 174, 368, 332, 240],
#               [366, 234, 339, 159, 329, 28],
#               [163, 222, 236, 73, 59],
#               [163, 240, 379, 253, 59, 374, 237],
#               [163, 320, 155, 125, 154, 158, 144],
#               [312, 95, 223, 218, 180, 339, 73],
#               [312, 277, 305, 31, 99],
#               [19, 17, 261, 266, 142, 235],
#               [19, 385, 180, 377, 324, 360],
#               [19, 161, 19, 292, 39],
#               [19, 98, 207, 52, 310, 89],
#               [19, 321, 176, 47, 386, 345],
#               [376, 172, 42, 82, 182],
#               [376, 147, 73, 21, 337],
#               [376, 73, 130, 130, 289, 53, 279],
#               [293, 345, 309, 154, 48, 192, 82],
#               [250, 120, 34, 239, 222, 232],
#               [250, 27, 191, 337, 333, 16],
#               [250, 281, 361, 164, 258, 55],
#               [250, 206, 339, 161, 307, 10],
#               [250, 200, 90, 158, 407],
#               [200, 56, 189, 28, 64, 338],
#               [200, 327, 315, 122, 307, 378],
#               [68, 301, 175, 255, 27],
#               [68, 365, 350, 221, 53, 162],
#               [68, 382, 404, 388, 26, 102, 279],
#               [68, 211, 141, 375, 168],
#               [298, 201, 63, 346, 179],
#               [298, 24, 217, 250, 343, 237, 340],
#               [298, 189, 12, 196, 252, 340, 31],
#               [298, 349, 178, 132, 315, 184],
#               [157, 2, 255, 172, 322, 295, 11],
#               [157, 89, 304, 315, 100, 11, 84],
#               [354, 115, 73, 48, 355, 380, 156],
#               [397, 330, 276, 195, 358, 252, 315],
#               [397, 228, 146, 104, 44, 133, 367],
#               [309, 86, 131, 388, 32, 163, 240],
#               [309, 172, 318, 275, 123, 121, 56],
#               [282, 336, 284, 258, 371, 262, 231],
#               [39, 38, 179, 392, 321],
#               [338, 380, 297, 114, 173],
#               [367, 339, 115, 261, 54, 61],
#               [73, 367, 204, 394, 216, 19],
#               [13, 111, 130, 29, 1, 77],
#               [13, 318, 407, 198, 291, 381],
#               [74, 377, 193, 341, 246],
#               [74, 63, 51, 339, 325, 397],
#               [394, 37, 30, 374, 118],
#               [183, 115, 347, 303, 271, 45, 229],
#               [183, 366, 28, 82, 10, 74],
#               [347, 337, 240, 298, 96, 201, 184],
#               [347, 239, 300, 394, 149],
#               [347, 233, 407, 134, 168, 229],
#               [45, 8, 37, 331, 244],
#               [45, 238, 104, 2, 391, 321],
#               [45, 162, 39, 398, 224, 12, 356],
#               [45, 63, 403, 259, 387, 48],
#               [45, 178, 181, 280, 321, 389, 264],
#               [32, 16, 37, 24, 23],
#               [32, 303, 322, 63, 283, 307],
#               [32, 377, 275, 208, 177],
#               [32, 226, 47, 362, 241, 307],
#               [32, 111, 329, 397, 347],
#               [32, 228, 404, 267, 400],
#               [32, 135, 206, 294, 355, 279],
#               [77, 35, 186, 296, 57, 270],
#               [77, 317, 296, 81, 337, 394, 235],
#               [61, 155, 239, 386, 207, 243, 286],
#               [61, 276, 96, 295, 139],
#               [43, 152, 274, 324, 200],
#               [43, 197, 96, 34, 68, 169],
#               [133, 385, 201, 166, 347, 407],
#               [234, 258, 7, 236, 115, 215],
#               [234, 278, 194, 30, 126, 75, 4],
#               [234, 291, 87, 359, 154],
#               [234, 228, 292, 190, 358, 180],
#               [234, 195, 110, 267, 91, 159, 19],
#               [253, 274, 401, 43, 368],
#               [253, 170, 219, 331, 386, 162, 156],
#               [395, 360, 175, 375, 132],
#               [395, 405, 52, 131, 16],
#               [395, 172, 350, 105, 32],
#               [102, 214, 385, 342, 73, 186, 75],
#               [102, 353, 369, 190, 278],
#               [178, 59, 119, 341, 219],
#               [178, 27, 269, 149, 256],
#               [130, 296, 343, 221, 149],
#               [130, 115, 237, 61, 274, 111],
#               [130, 401, 256, 391, 256, 190, 19],
#               [130, 200, 325, 241, 47, 338],
#               [128, 41, 211, 124, 252, 73],
#               [128, 162, 115, 312, 259, 182, 159],
#               [128, 48, 330, 296, 276],
#               [261, 111, 8, 316, 220],
#               [261, 106, 137, 401, 79, 201, 335],
#               [331, 168, 49, 48, 286, 303],
#               [331, 374, 322, 180, 304, 186, 217],
#               [331, 375, 386, 147, 264],
#               [288, 68, 325, 307, 111, 347, 133],
#               [288, 347, 219, 111, 30, 137],
#               [276, 130, 223, 384, 6],
#               [67, 40, 372, 170, 230],
#               [67, 265, 369, 46, 162, 173, 136],
#               [322, 227, 367, 115, 390, 6],
#               [322, 306, 23, 309, 332],
#               [322, 15, 402, 91, 295],
#               [211, 355, 339, 406, 131, 251],
#               [211, 104, 118, 24, 178],
#               [340, 149, 237, 72, 251, 405, 200],
#               [340, 175, 260, 264, 4, 386],
#               [269, 271, 295, 10, 151, 93],
#               [269, 69, 177, 371, 154, 85],
#               [127, 266, 374, 222, 307, 272],
#               [127, 242, 189, 393, 111, 295],
#               [127, 69, 97, 19, 168, 256]]})

# %%
df_train, df_test = train_test_split(df, test_size=0.2, shuffle=True)

# %%
class CaptchaDataset:
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        data = self.df.iloc[idx]
        image = Image.open(os.path.join(path, data['image'])).convert('L')
        label = torch.tensor(data['label'], dtype=torch.int32)
        
        if self.transform is not None:
            image = self.transform(image)
        
        return image, label
        
def custom_collate_fn(batch):
    images, labels = zip(*batch)
    images = torch.stack(images, 0)

    # 对标签进行填充，使它们具有相同的长度
    labels = pad_sequence(labels, batch_first=True, padding_value=0)

    return images, labels



transform = T.Compose([
    T.ToTensor()
])

train_data = CaptchaDataset(df_train, transform)
test_data = CaptchaDataset(df_test, transform)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True, collate_fn=custom_collate_fn)
test_loader = DataLoader(test_data, batch_size=8, collate_fn=custom_collate_fn)

# %%
class Bidirectional(nn.Module):
    def __init__(self, inp, hidden, out, lstm=True):
        super(Bidirectional, self).__init__()
        if lstm:
            self.rnn = nn.LSTM(inp, hidden, bidirectional=True)
        else:
            self.rnn = nn.GRU(inp, hidden, bidirectional=True)
        self.embedding = nn.Linear(hidden*2, out)
    def forward(self, X):
        recurrent, _ = self.rnn(X)
        out = self.embedding(recurrent)     
        return out
    
    
class CRNN(nn.Module):
    def __init__(self, in_channels, output):
        super(CRNN, self).__init__()

        self.cnn = nn.Sequential(
                nn.Conv2d(in_channels, 256, 9, stride=1, padding=1),
                nn.ReLU(),
                nn.BatchNorm2d(256),
                nn.MaxPool2d(3, 3),
                nn.Conv2d(256, 256, (4, 3), stride=1, padding=1),
                nn.ReLU(),
                nn.BatchNorm2d(256))
        
        self.linear = nn.Linear(3328, 256)
        self.bn1 = nn.BatchNorm1d(256)
        self.rnn = Bidirectional(256, 1024, output+1)

    def forward(self, X, y=None, criterion = None):
        out = self.cnn(X)
        N, C, w, h = out.size()
        out = out.view(N, -1, h)
        out = out.permute(0, 2, 1)
        out = self.linear(out)

        out = out.permute(1, 0, 2)
        out = self.rnn(out)
            
        if y is not None:
            T = out.size(0)
            N = out.size(1)
        
            input_lengths = torch.full(size=(N,), fill_value=T, dtype=torch.int32)
            target_lengths = torch.full(size=(N,), fill_value=5, dtype=torch.int32)
        
            loss = criterion(out, y, input_lengths, target_lengths)
            
            return out, loss
        
        return out, None
    
    def _ConvLayer(self, inp, out, kernel, stride, padding, bn=False):
        if bn:
            conv = [
                nn.Conv2d(inp, out, kernel, stride=stride, padding=padding),
                nn.ReLU(),
                nn.BatchNorm2d(out)
            ]
        else:
            conv = [
                nn.Conv2d(inp, out, kernel, stride=stride, padding=padding),
                nn.ReLU()
            ]
        return nn.Sequential(*conv)

# %%
class Engine:
    def __init__(self, model, optimizer, criterion, epochs=30, early_stop=False, device='cpu'):
        self.model = model
        self.optimizer = optimizer
        self.criterion = criterion
        self.epochs = epochs
        self.early_stop = early_stop
        self.device = device
        
    def fit(self, dataloader):
        hist_loss = []
        for epoch in range(self.epochs):
            self.model.train()
            tk = tqdm(dataloader, total=len(dataloader))
            for data, target in tk:
                data = data.to(device=self.device)
                target = target.to(device=self.device)

                self.optimizer.zero_grad()

                out, loss = self.model(data, target, criterion=self.criterion)

                loss.backward()

                self.optimizer.step()


                tk.set_postfix({'Epoch':epoch+1, 'Loss' : loss.item()})
                
    def evaluate(self, dataloader):
        self.model.eval()
        loss = 0
        hist_loss = []
        outs = collections.defaultdict(list)
        tk = tqdm(dataloader, total=len(dataloader))
        with torch.no_grad():
            for data, target in tk:
                data = data.to(device=self.device)
                target = target.to(device=self.device)

                out, loss = self.model(data, target, criterion=self.criterion)
               
                target=target.cpu().detach().numpy()
                outs['pred'].append(out)
                outs['target'].append(target)


                hist_loss.append(loss)

                tk.set_postfix({'Loss':loss.item()})
                
        return outs, hist_loss
    
    def predict(self, image):
        image = Image.open(image).convert('L')
        image_tensor = T.ToTensor()(image)
        image_tensor = image_tensor.unsqueeze(0)        
        out, _ = self.model(image_tensor.to(device=self.device))
        out = out.permute(1, 0, 2)
        out = out.log_softmax(2)
        out = out.argmax(2)
        out = out.cpu().detach().numpy()
        
        return out

# %%
model = CRNN(in_channels=1, output=num_class).to(DEVICE)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.CTCLoss()

engine = Engine(model, optimizer, criterion, device=DEVICE)

# %%
engine.fit(train_loader)
outs, loss = engine.evaluate(test_loader)
# Out:
# 100%|██████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 21.19it/s, Epoch=1, Loss=4.78]
# 100%|██████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 25.67it/s, Epoch=2, Loss=4.29]
# 100%|██████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 25.70it/s, Epoch=3, Loss=4.79]
# 100%|██████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 25.75it/s, Epoch=4, Loss=5.11]
# 100%|██████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 25.37it/s, Epoch=5, Loss=5.27]
# 100%|██████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 25.64it/s, Epoch=6, Loss=5.46]
# 100%|██████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 25.52it/s, Epoch=7, Loss=5.61]
#  48%|█████████████████████████████▊                                | 24/50 [00:00<00:01, 25.68it/s, Epoch=8, Loss=5.64]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties

# 指定中文字体文件的路径
font_path = "F:\\project\\python\\OCR\\Recognize\\Gen\\font\\SimHei.ttf"  # 替换成你的中文字体文件路径

# 加载中文字体
myfont = FontProperties(fname=font_path)

ids = np.random.randint(len(data))

image = data[ids]
out = engine.predict(image)[0]

def show_prediction(out, image):
    gt = image.split('/')[-1].split('.')[0]
    imagePIL = Image.open(image).convert('L')

    pred = ''
    then = 0
    for x in out:
        if then != x:
            if x > 0 :
                pred += mapping_inv[x]
        then = x

    plt.figure(figsize=(15, 12))
    img_array = np.asarray(imagePIL)
    plt.title(f'Ground Truth - {gt} || Prediction - {pred}',fontproperties=myfont)
    plt.axis('off')
    plt.imshow(img_array,cmap='gray')
    
show_prediction(out, image)

# %%
saving = {'state_dict':engine.model.state_dict(),
          'optimizer':engine.optimizer.state_dict(),
         'mapping':mapping,
         'mapping_inv':mapping_inv}
torch.save(saving, './model/randlen_chinese_model.pth')
